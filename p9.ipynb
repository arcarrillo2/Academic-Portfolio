# %%
import otter
# nb_name should be the name of your notebook without the .ipynb extension
nb_name = "p9"
py_filename = nb_name + ".py"
grader = otter.Notebook(nb_name + ".ipynb")

# %%
import p9_test

# %%
# PLEASE FILL IN THE DETAILS
# Enter none if you don't have a project partner

# project: p9
# submitter: NETID1
# partner: NETID2

# %% [markdown]
# # Project 9: Analyzing the Movies

# %% [markdown]
# ## Learning Objectives:
#
# In this project, you will demonstrate your ability to:
# - Use `matplotlib` to plot bar graphs and visualize statistics
# - Process data using dictionaries and lists that you build
# - Implement binning by writing algorithms that create dictionaries
# - Custom sort a list using the keyword parameter `key`'s argument.
#
# Please go through [lab-p9](https://git.doit.wisc.edu/cdis/cs/courses/cs220/cs220-f22-projects/-/tree/main/lab-p9) before starting this project. The lab introduces some useful techniques necessary for this project.

# %% [markdown]
# ## Note on Academic Misconduct:
#
# **IMPORTANT**: p8 and p9 are two parts of the same data analysis. You **cannot** switch project partners between these two projects. That is if you partnered up with someone for p8, you have to work on p9 with the **same partner**. Now may be a good time to review [our course policies](https://cs220.cs.wisc.edu/f22/syllabus.html).

# %% [markdown]
# ## Testing your code:
#
# Along with this notebook, you must have downloaded the file `p9_test.py`. If you are curious about how we test your code, you can explore this file, and specifically the value of the variable `expected_json`, to understand the expected answers to the questions.
#
# **Important:** `p9_test.py` **cannot** verify your answers when the output is an image. Your **plots** will be **manually graded** by graders, so you must **manually** confirm that your plots look correct by comparing with the images provided in the notebook.

# %% [markdown]
# ## Introduction:
#
# In p8, you created very useful helper functions to parse the raw IMDb dataset. You also created useful data structures to store the data. In this project, you will be building on the work you did in p8 to analyze your favorite movies. This is a shorter project than usual, and **p9 will only have 10 questions for you to solve**.

# %% [markdown]
# ## Data:
#
# Between p8 and p9, the movies dataset has been updated to hold many more movies. The `movies.csv` file that you will use in p9 contains ~200,000 movies, and the `mapping.csv` file contains data on ~600,000 movie titles and people. Thankfully, the data in both files are stored in exactly the same format as the files you worked with in p8. So, all your functions should continue to work in p9. Please remember to download the [latest datasets](https://git.doit.wisc.edu/cdis/cs/courses/cs220/cs220-f22-projects/-/tree/main/p9) before starting this project.

# %% [markdown]
# ## Project Requirements:
#
# You **may not** hardcode indices or the lengths of lists in your code. We'll **manually deduct** points from your autograder score on Gradescope during code review.
#
# **Store** your final answer for each question in the **variable specified for each question**. This step is important because Otter grades your work by comparing the value of this variable against the correct answer.
#
# For some of the questions, we'll ask you to write (then use) a function to compute the answer. If you compute the answer **without** creating the function we ask you to write, we'll **manually deduct** points from your autograder score on Gradescope, even if the way you did it produced the correct answer.
#
# Required Functions:
# - `get_movies`
# - `plot_dict`
# - `bucketize`
#
# In this project, you will also be required to define certain **data structures**. If you do not create these data structures exactly as specified, we'll **manually deduct** points from your autograder score on Gradescope, even if the way you did it produced the correct answer.
#
# Required Data Structures:
# - `movies`
# - `cast_buckets`
# - `director_buckets`
# - `genre_buckets`
# - `year_buckets`
#
# You are only allowed to define these data structures **once** and we'll **manually deduct** points from your autograder score on Gradescope if you redefine the values of these variables.
#
# In this project, you will be asked to create **lists** of movies. For all such questions, **unless it is explicitly mentioned otherwise**, the movies should be in the **same order** as in the `movies.csv` file. Similarly, for each movie, the **list** of `genres`, `directors`, and `cast` members should always be in the **same order** as in the `movies.csv` file.
#
# Students are only allowed to use Python commands and concepts that have been taught in the course prior to the release of p9. We will **manually deduct** points from your autograder score on Gradescope otherwise.
#
# For more details on what will cause you to lose points during code review and specific requirements, please take a look at the [Grading rubric](https://git.doit.wisc.edu/cdis/cs/courses/cs220/cs220-f22-projects/-/blob/main/p9/rubric.md).

# %% [markdown]
# ## Project Questions and Functions:

# %%
# it is considered a good coding practice to place all import statements at the top of the notebook
# please place all your import statements in this cell if you need to import any more modules for this project
import csv
import pandas

# %% [markdown]
# ## Loading the Movies Data
#
# For all these questions, we will be looking at the movies in `mapping.csv` and `movies.csv`. You can load the list of movies using the functions you wrote in the last project.

# %% [markdown]
# Copy the functions you wrote in `p8.ipynb` to `p9.ipynb` to read the movies data. The functions you should include are `process_csv`, `get_mapping`, `get_raw_movies`, and `get_movies` along with any helper functions you used to write these. Do **not** copy/paste `find_specific_movies` here. Later in p9, we will provide you with a simpler version of that function, which does not require the use of the `copy` module.

# %%
# copy/paste the definitions of get_mapping, get_raw_movies, get_movies from p8
# as well as any helper functions used by these functions here
def process_csv(filename):
    example_file = open(filename, encoding="utf-8")
    example_reader = csv.reader(example_file)
    example_data = list(example_reader)
    example_file.close()
    return example_data


file_data = process_csv("movies.csv")
csv_header = file_data[0]
csv_rows = file_data[1:]

def get_mapping(path):
    
    mapping_rows = process_csv(path)
    
    mapping_dict = {} # initialize an empty dictionary into the variable mapping_dict
# TODO: iterate over each row of the small_mapping dataset
    for row in mapping_rows:
        key_id = row[0]
        value_name = row[1]
        mapping_dict[key_id] = value_name
    return mapping_dict

def get_movies(movies_path, mapping_path):
    movie_name = get_raw_movies(movies_path)
    mapping = get_mapping(mapping_path)
    
    for movie in movie_name:
        movie['title'] = mapping[movie['title']]
        for idx in range(len(movie['cast'])):
            movie["cast"][idx] = mapping[movie['cast'][idx]]
        for idx in range(len(movie['directors'])):
            movie['directors'][idx] = mapping[movie['directors'][idx]]
    
    return movie_name 

def get_raw_movies(path):
    
    movie_rows = process_csv(path)[1:]
    
    raw_movies_list = [] 
    
    for row_idx in range(len(movie_rows)):
        movie = {} # initialize an empty dictionary
        movie["title"] = movie_rows[row_idx][csv_header.index("title")] # extract the title of the movie
        movie["year"] = int(movie_rows[row_idx][csv_header.index("year")])
        movie["genres"] = movie_rows[row_idx][csv_header.index("genres")].split(", ")
        movie["duration"] = int(movie_rows[row_idx][csv_header.index("duration")])
        movie["directors"] = movie_rows[row_idx][csv_header.index("directors")].split(", ")
        movie["cast"] = movie_rows[row_idx][csv_header.index("cast")].split(", ")
        movie["rating"] = float(movie_rows[row_idx][csv_header.index("rating")])
         
        raw_movies_list.append(movie)
    
    return raw_movies_list
movies = get_movies("movies.csv", "mapping.csv")

# %% [markdown]
# Now, you can use `get_movies` to read the data in `movies.csv` and `mapping.csv` as you did in p8.

# %%
# create a list of dictionaries named 'movies' to store the data in 'movies.csv' and 'mapping.csv' as in p8
# do NOT display the value of this variable anywhere in this notebook

movies = get_movies('movies.csv', 'mapping.csv') 
movies
# Out:
# [{'title': 'Lejos de África',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 115,
#   'directors': ['Cecilia Bartolomé'],
#   'cast': ['Alicia Bogo', 'Xabier Elorriaga', 'Isabel Mestres', 'Carlos Cruz'],
#   'rating': 6.4},
#  {'title': 'Amityville Cult',
#   'year': 2021,
#   'genres': ['Horror'],
#   'duration': 85,
#   'directors': ['Trey Murphy'],
#   'cast': ['James Burleson',
#    'Chance Gibbs',
#    'Micha Marie Stevens',
#    'Tom Young',
#    'Patrick McAlister',
#    'Eric Oberto',
#    'Lara Williams'],
#   'rating': 2.1},
#  {'title': 'Small, Slow But Steady',
#   'year': 2022,
#   'genres': ['Drama', 'Sport'],
#   'duration': 99,
#   'directors': ['Shô Miyake'],
#   'cast': ['Yukino Kishii',
#    'Tomokazu Miura',
#    'Masaki Miura',
#    'Shinichirô Matsuura',
#    'Hiroko Nakajima',
#    'Himi Satô',
#    'Nobuko Sendô'],
#   'rating': 7.2},
#  {'title': 'Oshëtime në bregdet',
#   'year': 1966,
#   'genres': ['Drama', 'Family'],
#   'duration': 79,
#   'directors': ['Hysen Hakani'],
#   'cast': ['Marie Logoreci',
#    'Ndrek Luca',
#    'Agim Shuke',
#    'Dhimitër Pecani',
#    'Aleksandër Prosi',
#    'Elez Kadrija'],
#   'rating': 8.3},
#  {'title': 'Al otro lado del túnel',
#   'year': 1994,
#   'genres': ['Comedy'],
#   'duration': 105,
#   'directors': ['Jaime de Armiñán'],
#   'cast': ['Fernando Rey', 'Maribel Verdú', 'Gonzalo Vega', 'Amparo Baró'],
#   'rating': 5.8},
#  {'title': 'The Ladder of Progress',
#   'year': 1957,
#   'genres': ['Comedy'],
#   'duration': 120,
#   'directors': ['Parviz Khatibi'],
#   'cast': ['Parkhide',
#    'Taji Ahmadi',
#    'Ahmad Ghadakchian',
#    'Farokhlagha Hushmand',
#    'Mahvash',
#    'Mehri Meshkin',
#    'Houshang Moradi'],
#   'rating': 4.7},
#  {'title': 'Roopantharam',
#   'year': 2015,
#   'genres': ['Drama', 'Family'],
#   'duration': 96,
#   'directors': ['M.B. Padmakumar'],
#   'cast': ['Kochu Preman', 'Bharath Chand', 'Sona Nair'],
#   'rating': 7.8},
#  {'title': 'Hope',
#   'year': 2012,
#   'genres': ['Adventure', 'Drama'],
#   'duration': 80,
#   'directors': ['Todd E. Freeman'],
#   'cast': ['Robert Blanche', 'Danny Bruno', 'Laura Duyn', 'Mercedes Rose'],
#   'rating': 5.3},
#  {'title': 'Bark!',
#   'year': 2002,
#   'genres': ['Comedy', 'Drama'],
#   'duration': 94,
#   'directors': ['Kasia Adamik'],
#   'cast': ['Lee Tergesen',
#    'Heather Morgan',
#    'Lisa Kudrow',
#    "Vincent D'Onofrio"],
#   'rating': 5.0},
#  {'title': 'The Disappearance of Cari Farver',
#   'year': 2022,
#   'genres': ['Drama', 'Thriller'],
#   'duration': 86,
#   'directors': ['Danishka Esterhazy'],
#   'cast': ['Alicia Witt', 'Zach Gilford', 'Bradley Sawatzky', 'Milton Barnes'],
#   'rating': 6.6},
#  {'title': 'Mr. Novak',
#   'year': 1949,
#   'genres': ['Comedy'],
#   'duration': 88,
#   'directors': ['Borivoj Zeman'],
#   'cast': ['Jindrich Plachta',
#    'Meda Valentová',
#    'Ludmila Franková',
#    'Josef Pehr'],
#   'rating': 4.8},
#  {'title': 'Neko Atsume House',
#   'year': 2017,
#   'genres': ['Family'],
#   'duration': 92,
#   'directors': ['Masatoshi Kurakata'],
#   'cast': ['Atsushi Itô', 'Tae Kimura', 'Shioli Kutsuna', 'Tomorô Taguchi'],
#   'rating': 5.6},
#  {'title': 'Welcome Home Soldier Boys',
#   'year': 1971,
#   'genres': ['Drama'],
#   'duration': 91,
#   'directors': ['Richard Compton'],
#   'cast': ['Jennifer Billingsley',
#    'Joe Don Baker',
#    'Paul Koslo',
#    'Alan Vint',
#    'Elliott Street'],
#   'rating': 6.5},
#  {'title': 'Les irréductibles',
#   'year': 2006,
#   'genres': ['Comedy', 'Drama'],
#   'duration': 105,
#   'directors': ['Renaud Bertrand'],
#   'cast': ['Jacques Gamblin', 'Kad Merad', 'Anne Brochet', 'Rufus'],
#   'rating': 5.6},
#  {'title': "Kill Me Quick, I'm Cold",
#   'year': 1967,
#   'genres': ['Comedy', 'Crime'],
#   'duration': 99,
#   'directors': ['Francesco Maselli'],
#   'cast': ['Monica Vitti', 'Jean Sorel', 'Roberto Bisacco', 'Daniela Surina'],
#   'rating': 5.7},
#  {'title': 'Wonder',
#   'year': 2017,
#   'genres': ['Drama', 'Family'],
#   'duration': 113,
#   'directors': ['Stephen Chbosky'],
#   'cast': ['Jacob Tremblay',
#    'Owen Wilson',
#    'Izabela Vidovic',
#    'Julia Roberts'],
#   'rating': 7.9},
#  {'title': 'Forward, for the Treasures of the Hetman!',
#   'year': 1993,
#   'genres': ['Comedy'],
#   'duration': 89,
#   'directors': ['Vadim Kastelli'],
#   'cast': ['Aleksandr Bondarenko',
#    'Yuri Yevsyukov',
#    'Yuriy Mazhuga',
#    'Georgiy Drozd'],
#   'rating': 8.1},
#  {'title': 'Samjhana',
#   'year': 1983,
#   'genres': ['Drama'],
#   'duration': 106,
#   'directors': ['Shambhu Pradhan'],
#   'cast': ['Bhuwan K.C.', 'Tripti Nadakar', 'Muralidhar'],
#   'rating': 6.9},
#  {'title': 'The Killing Death',
#   'year': 2008,
#   'genres': ['Comedy', 'Horror'],
#   'duration': 65,
#   'directors': ['Ian Russell'],
#   'cast': ['Jeremy Dangerfield',
#    'Tyhr Trubiak',
#    'Neil Reimer',
#    'Darren Felbel'],
#   'rating': 5.2},
#  {'title': 'Atlihan',
#   'year': 1973,
#   'genres': ['Action', 'Fantasy', 'History'],
#   'duration': 73,
#   'directors': ['Naki Yurter'],
#   'cast': ['Oktar Durukan',
#    'Aytekin Akkaya',
#    'Abdi Algül',
#    'Giray Alpan',
#    'Ali Ardiç',
#    'Ihsan Bayraktar'],
#   'rating': 3.6},
#  {'title': 'Sahane Evlilik',
#   'year': 1989,
#   'genres': ['Romance'],
#   'duration': 80,
#   'directors': ['Sahin Gök'],
#   'cast': ['Ehat Alinçe',
#    'Serpil Çakmakli',
#    'Berhan Simsek',
#    'Hülya Erçel',
#    'Duygu Ankara',
#    'Ayten Erman'],
#   'rating': 3.4},
#  {'title': 'Aztec Revenge',
#   'year': 2015,
#   'genres': ['Fantasy', 'Horror'],
#   'duration': 80,
#   'directors': ['Aaron Crozier'],
#   'cast': ['Mil Máscaras',
#    'Kurt Mirtsching',
#    'Kirsten Olson',
#    'Jeffrey Uhlmann'],
#   'rating': 7.5},
#  {'title': 'Chattahoochee',
#   'year': 1989,
#   'genres': ['Biography', 'Drama'],
#   'duration': 98,
#   'directors': ['Mick Jackson'],
#   'cast': ['Gary Oldman', 'Dennis Hopper', 'Frances McDormand', 'Pamela Reed'],
#   'rating': 6.3},
#  {'title': 'The Last Wagon',
#   'year': 1943,
#   'genres': ['Comedy'],
#   'duration': 88,
#   'directors': ['Mario Mattoli'],
#   'cast': ['Aldo Fabrizi', 'Anna Magnani', 'Anita Durante', 'Elide Spada'],
#   'rating': 6.5},
#  {'title': 'The Omission',
#   'year': 2018,
#   'genres': ['Drama'],
#   'duration': 90,
#   'directors': ['Sebastián Schjaer'],
#   'cast': ['Sofía Brito',
#    'Lisandro Rodríguez',
#    'Malena Hernández Díaz',
#    'Victoria Raposo'],
#   'rating': 6.0},
#  {'title': "Lady Chatterley's Lover",
#   'year': 2022,
#   'genres': ['Drama', 'Romance'],
#   'duration': 126,
#   'directors': ['Laure de Clermont-Tonnerre'],
#   'cast': ['Faye Marsay', 'Emma Corrin', 'Joely Richardson', "Jack O'Connell"],
#   'rating': 7.9},
#  {'title': 'Naked Bullet',
#   'year': 1969,
#   'genres': ['Drama'],
#   'duration': 72,
#   'directors': ['Kôji Wakamatsu'],
#   'cast': ['Ken Yoshizawa',
#    'Miki Hayashi',
#    'Eri Ashikawa',
#    'Toshiyuki Tanigawa'],
#   'rating': 6.8},
#  {'title': 'Torgus',
#   'year': 1921,
#   'genres': ['Drama', 'History'],
#   'duration': 64,
#   'directors': ['Hanns Kobe'],
#   'cast': ['Hermine Straßmann-Witt',
#    'Gerd Fricke',
#    'Ferdinand Gregori',
#    'Eugen Klöpfer',
#    'Marija Leiko',
#    'Kaethe Richter',
#    'Adele Sandrock'],
#   'rating': 5.9},
#  {'title': 'Breeders',
#   'year': 1986,
#   'genres': ['Horror', 'Sci-Fi'],
#   'duration': 77,
#   'directors': ['Tim Kincaid'],
#   'cast': ['Teresa Farley',
#    'Lance Lewman',
#    'Frances Raines',
#    'Natalie Savage'],
#   'rating': 3.7},
#  {'title': 'Rows',
#   'year': 2015,
#   'genres': ['Fantasy', 'Horror', 'Mystery'],
#   'duration': 84,
#   'directors': ['David W. Warfield'],
#   'cast': ['Hannah Bernall', 'Lauren Lakis', 'Kenneth Hughes', 'Joe Basile'],
#   'rating': 3.9},
#  {'title': 'Freshly Squeezed',
#   'year': 2012,
#   'genres': ['Comedy', 'Romance'],
#   'duration': 95,
#   'directors': ['Christine Hartmann'],
#   'cast': ['Diana Amft', 'Tom Wlaschiha', 'Alexander Beyer', 'Jule Ronstedt'],
#   'rating': 4.6},
#  {'title': 'The Aspern Papers',
#   'year': 2018,
#   'genres': ['Drama'],
#   'duration': 90,
#   'directors': ['Julien Landais'],
#   'cast': ['Jonathan Rhys Meyers',
#    'Vanessa Redgrave',
#    'Joely Richardson',
#    'Lois Robbins'],
#   'rating': 4.5},
#  {'title': 'Om natten',
#   'year': 2009,
#   'genres': ['Documentary', 'Drama'],
#   'duration': 55,
#   'directors': ['Einar Bodström', 'David Dworsky', 'Victor Köhler'],
#   'cast': ['Rickard Vikström'],
#   'rating': 8.3},
#  {'title': 'Good Take!',
#   'year': 2016,
#   'genres': ['Comedy', 'Drama', 'Horror'],
#   'duration': 94,
#   'directors': ['Derek Tsang',
#    'Ching-Po Wong',
#    'Chun Wong',
#    'Henri Wong',
#    'Vernie Yeung'],
#   'cast': ['Eddie Cheung', 'Charlene Choi', 'Alex Fong', 'Hoi-Pang Lo'],
#   'rating': 6.0},
#  {'title': 'Gora',
#   'year': 1938,
#   'genres': ['Drama'],
#   'duration': 104,
#   'directors': ['Naresh Mitra'],
#   'cast': ['Protima Dasgupta',
#    'Devbala',
#    'Rajlakshmi Devi',
#    'Jiban Ganguly',
#    'Ranibala'],
#   'rating': 4.7},
#  {'title': 'Normal Life',
#   'year': 1996,
#   'genres': ['Crime', 'Drama'],
#   'duration': 101,
#   'directors': ['John McNaughton'],
#   'cast': ['Ashley Judd', 'Luke Perry', 'Bruce A. Young', 'Jim True-Frost'],
#   'rating': 6.2},
#  {'title': "In the Devil's Courthouse",
#   'year': 2011,
#   'genres': ['Horror', 'Thriller'],
#   'duration': 85,
#   'directors': ['Ken Comito'],
#   'cast': ['Ashley Marie Nelson',
#    'Dustin Webb',
#    'Kristen Snider',
#    'Patrick Ferrara'],
#   'rating': 4.8},
#  {'title': 'Tru Loved',
#   'year': 2008,
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'duration': 102,
#   'directors': ['Stewart Wade'],
#   'cast': ['Najarra Townsend',
#    'Joseph Julian Soria',
#    'Howard Booth',
#    'Jay Costelo'],
#   'rating': 5.6},
#  {'title': 'Rust',
#   'year': 2018,
#   'genres': ['Drama'],
#   'duration': 100,
#   'directors': ['Aly Muritiba'],
#   'cast': ['Giovanni de Lorenzi',
#    'Tifanny Dopke',
#    'Enrique Diaz',
#    'Clarissa Kiste'],
#   'rating': 6.3},
#  {'title': 'Robot Ninja',
#   'year': 1989,
#   'genres': ['Action', 'Drama', 'Fantasy'],
#   'duration': 82,
#   'directors': ['J.R. Bookwalter'],
#   'cast': ['Michael Todd',
#    'Bogdan Pecic',
#    'Maria Markovic',
#    'Floyd Ewing Jr.'],
#   'rating': 4.0},
#  {'title': 'The War Wagon',
#   'year': 1967,
#   'genres': ['Western'],
#   'duration': 101,
#   'directors': ['Burt Kennedy'],
#   'cast': ['John Wayne', 'Kirk Douglas', 'Howard Keel', 'Robert Walker Jr.'],
#   'rating': 6.8},
#  {'title': "Akko's Secret",
#   'year': 2012,
#   'genres': ['Comedy', 'Fantasy', 'Romance'],
#   'duration': 120,
#   'directors': ['Yasuhiro Kawamura'],
#   'cast': ['Haruka Ayase', 'Masaki Okada', 'Takeshi Kaga', 'Ren Ôsugi'],
#   'rating': 5.8},
#  {'title': 'Chori Chori',
#   'year': 2003,
#   'genres': ['Comedy', 'Drama', 'Musical'],
#   'duration': 135,
#   'directors': ['Milan Luthria'],
#   'cast': ['Ajay Devgn', 'Sonali Bendre', 'Rani Mukerji', 'Kamini Kaushal'],
#   'rating': 4.9},
#  {'title': "Emmanuel's Gift",
#   'year': 2005,
#   'genres': ['Documentary'],
#   'duration': 80,
#   'directors': ['Lisa Lax', 'Nancy Stern Winters'],
#   'cast': ['Oprah Winfrey'],
#   'rating': 7.6},
#  {'title': 'The Water Was So Clear',
#   'year': 1973,
#   'genres': ['Drama'],
#   'duration': 92,
#   'directors': ['Yôichi Takabayashi'],
#   'cast': ['Yûtarô Ban', 'Akira Nitta'],
#   'rating': 7.0},
#  {'title': "Kamen Rider Den-O: I'm Born!",
#   'year': 2007,
#   'genres': ['Action', 'Adventure', 'Comedy'],
#   'duration': 69,
#   'directors': ['Takao Nagaishi'],
#   'cast': ['Wakana Matsumoto',
#    'Takeru Satoh',
#    'Yuriko Shiratori',
#    'Rina Akiyama',
#    'Kenjirô Ishimaru'],
#   'rating': 6.3},
#  {'title': 'Cheer Up Mr. Lee',
#   'year': 2012,
#   'genres': ['Comedy', 'Drama'],
#   'duration': 94,
#   'directors': ['Byeong-heon Lee'],
#   'cast': ['Wan-pyo Hong', 'Hyun-min Yang'],
#   'rating': 6.2},
#  {'title': 'Storie di ordinaria follia',
#   'year': 1981,
#   'genres': ['Drama'],
#   'duration': 101,
#   'directors': ['Marco Ferreri'],
#   'cast': ['Ben Gazzara', 'Ornella Muti', 'Susan Tyrrell', 'Tanya Lopert'],
#   'rating': 6.7},
#  {'title': "Comin' 'Round the Mountain",
#   'year': 1936,
#   'genres': ['Western'],
#   'duration': 57,
#   'directors': ['Mack V. Wright'],
#   'cast': ['Gene Autry', 'Ann Rutherford', 'Smiley Burnette', 'LeRoy Mason'],
#   'rating': 6.2},
#  {'title': 'Fireman Sam: Set for Action!',
#   'year': 2018,
#   'genres': ['Action', 'Adventure', 'Animation'],
#   'duration': 62,
#   'directors': ['Gary Andrews', 'Clint Butler'],
#   'cast': ['John Barrowman', 'Steven Kynman', 'David Carling', 'Su Douglas'],
#   'rating': 4.9},
#  {'title': 'Three Husbands',
#   'year': 2018,
#   'genres': ['Drama', 'Fantasy'],
#   'duration': 101,
#   'directors': ['Fruit Chan'],
#   'cast': ['Chloe Maayan', 'Charm Man Chan', 'Keung Mak', 'Man-Lei Chan'],
#   'rating': 5.7},
#  {'title': 'Bed and Breakfast',
#   'year': 2003,
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'duration': 105,
#   'directors': ['Claude Duty'],
#   'cast': ['Marina Foïs',
#    'Philippe Harel',
#    'Annie Grégorio',
#    'Sebastian Barrio'],
#   'rating': 5.7},
#  {'title': 'Elveda Katya',
#   'year': 2012,
#   'genres': ['Drama'],
#   'duration': 109,
#   'directors': ['Ahmet Sönmez'],
#   'cast': ['Beliz Aksoy', 'Alev Alemdaroglu', 'Anna Andrusenko', 'Murat Asar'],
#   'rating': 6.0},
#  {'title': "That's Life",
#   'year': 1980,
#   'genres': ['Drama'],
#   'duration': 91,
#   'directors': ['Paul Vecchiali'],
#   'cast': ['Chantal Delsaux',
#    'Hélène Surgère',
#    'Jean-Christophe Bouvet',
#    'Jacques Gibert'],
#   'rating': 6.3},
#  {'title': 'Sexto A 1965',
#   'year': 1985,
#   'genres': ['Drama'],
#   'duration': 90,
#   'directors': ['Claudio Di Girolamo'],
#   'cast': ['Roberto Parada',
#    'Roberto Poblete',
#    'Eugenio Ahumada',
#    'Cristián Campos'],
#   'rating': 7.0},
#  {'title': 'When a Tree Falls',
#   'year': 2015,
#   'genres': ['Drama'],
#   'duration': 103,
#   'directors': ['Asier Altuna'],
#   'cast': ['Kandido Uranga', 'Iraia Elias', 'Amparo Badiola', 'Klara Badiola'],
#   'rating': 6.8},
#  {'title': 'Victor Young Perez',
#   'year': 2013,
#   'genres': ['Biography', 'Drama', 'History'],
#   'duration': 110,
#   'directors': ['Jacques Ouaniche'],
#   'cast': ['Brahim Asloum',
#    'Steve Suissa',
#    'Isabella de Ligne-La Trémoïlle',
#    'Patrick Bouchitey'],
#   'rating': 6.3},
#  {'title': 'Politseiskiye i vory',
#   'year': 1998,
#   'genres': ['Comedy', 'Crime', 'Drama'],
#   'duration': 90,
#   'directors': ['Nikolay Dostal'],
#   'cast': ['Sergey Batalov',
#    'Gennadiy Khazanov',
#    'Vyacheslav Nevinnyy',
#    'Elena Tsyplakova',
#    'Evgeniya Glushenko',
#    'Vladimir Zeldin'],
#   'rating': 6.0},
#  {'title': 'Piégé',
#   'year': 2014,
#   'genres': ['Thriller'],
#   'duration': 78,
#   'directors': ['Yannick Saillet'],
#   'cast': ['Pascal Elbé', 'Laurent Lucas', 'Caroline Bal', 'Arnaud Henriet'],
#   'rating': 5.0},
#  {'title': "The Women's Club",
#   'year': 1987,
#   'genres': ['Comedy'],
#   'duration': 86,
#   'directors': ['Sandra Weintraub'],
#   'cast': ['Michael Paré', 'Maud Adams', 'Eddie Velez', 'Dotty Coloroso'],
#   'rating': 4.6},
#  {'title': 'The Revolt of the Thralls',
#   'year': 1979,
#   'genres': ['Animation'],
#   'duration': 90,
#   'directors': ['Jannik Hastrup'],
#   'cast': ['Otto Brandenburg',
#    'Birgit Brüel',
#    'Jesper Klein',
#    'Hermod Knudsen'],
#   'rating': 5.8},
#  {'title': 'La trappola',
#   'year': 1922,
#   'genres': ['Comedy', 'Drama'],
#   'duration': 58,
#   'directors': ['Eugenio Perego'],
#   'cast': ['Leda Gys',
#    'Gian Paolo Rosmino',
#    'Suzanne Fabre',
#    'Carlo Reiter',
#    'E. Masucci'],
#   'rating': 6.8},
#  {'title': 'Judgment Day',
#   'year': 2013,
#   'genres': ['Comedy', 'Drama'],
#   'duration': 104,
#   'directors': ['Kuo-Sin Ong'],
#   'cast': ['Mark Lee', 'Henry Thia', 'Chia-Yen Ko', 'Tender Huang'],
#   'rating': 5.8},
#  {'title': 'Jungle Goddess',
#   'year': 1948,
#   'genres': ['Action', 'Adventure', 'Crime'],
#   'duration': 62,
#   'directors': ['Lewis D. Collins'],
#   'cast': ['George Reeves', 'Wanda McKay', 'Ralph Byrd', 'Armida'],
#   'rating': 2.1},
#  {'title': 'Tere Liye',
#   'year': 2001,
#   'genres': ['Drama', 'Family', 'Musical'],
#   'duration': 138,
#   'directors': ['Sanjay Gadhvi'],
#   'cast': ['Imran Ahmed Khan', 'Sonali Khare', 'Neelu Kohli', 'Hiten Paintal'],
#   'rating': 5.6},
#  {'title': 'The Secret of the Grain',
#   'year': 2007,
#   'genres': ['Drama'],
#   'duration': 151,
#   'directors': ['Abdellatif Kechiche'],
#   'cast': ['Habib Boufares',
#    'Hafsia Herzi',
#    'Farida Benkhetache',
#    'Abdelhamid Aktouche'],
#   'rating': 7.4},
#  {'title': 'Kevin Can Wait',
#   'year': 1983,
#   'genres': ['Drama'],
#   'duration': 51,
#   'directors': ['John Schmidt'],
#   'cast': ['Jim Schmidt', 'David Prince', 'Kevin Cushing', 'Phil Schmidt'],
#   'rating': 6.8},
#  {'title': 'Ogni volta che te ne vai',
#   'year': 2004,
#   'genres': ['Comedy', 'Music', 'Romance'],
#   'duration': 95,
#   'directors': ['Davide Cocchi'],
#   'cast': ['Giampiero Bartolini',
#    'Raoul Casadei',
#    'Giorgio Colangeli',
#    'Bruno Corazzari'],
#   'rating': 6.2},
#  {'title': 'Kobbari Bondam',
#   'year': 1991,
#   'genres': ['Comedy'],
#   'duration': 149,
#   'directors': ['Raviteja K.'],
#   'cast': ['Rajendra Prasad', 'Nirosha', 'Sudhakar', 'Kota Srinivasa Rao'],
#   'rating': 6.4},
#  {'title': 'Favor',
#   'year': 2013,
#   'genres': ['Thriller'],
#   'duration': 102,
#   'directors': ['Paul Osborne'],
#   'cast': ['Blayne Weaver', 'Patrick Day', 'Jeffrey Combs', 'Christina Rose'],
#   'rating': 6.3},
#  {'title': 'Arc de Barà',
#   'year': 2016,
#   'genres': ['Action', 'Adventure', 'Comedy'],
#   'duration': 101,
#   'directors': ['JC Ceinos'],
#   'cast': ['Trini Montoliu',
#    'Carlos Noriega',
#    'Pablo Van Der Nayar',
#    'Mikel Tamarit'],
#   'rating': 7.1},
#  {'title': 'This Special Friendship',
#   'year': 1964,
#   'genres': ['Drama'],
#   'duration': 100,
#   'directors': ['Jean Delannoy'],
#   'cast': ['Francis Lacombrade',
#    'Didier Haudepin',
#    'François Leccia',
#    'Dominique Maurin'],
#   'rating': 7.7},
#  {'title': 'TharnType Special: Our Final Love',
#   'year': 2020,
#   'genres': ['Romance'],
#   'duration': 80,
#   'directors': ['Tee Sintanaparadee'],
#   'cast': ['Thanayut Thakoonauttaya',
#    'Mew Suppasit',
#    'Kanawut Traipipattanapong',
#    'Parinya Angsanan',
#    'Tanawin Duangnate',
#    'Kittipat Kaewcharoen',
#    'Natthad Kunakornkiat',
#    'Kantheephop Sirorattanaphanit',
#    'Napat Srinakluan'],
#   'rating': 8.3},
#  {'title': 'Los Muertos',
#   'year': 2004,
#   'genres': ['Drama'],
#   'duration': 78,
#   'directors': ['Lisandro Alonso'],
#   'cast': ['Argentino Vargas',
#    'Francisco Dornez',
#    'Yolanda Galarza',
#    'Víctor Varela'],
#   'rating': 6.8},
#  {'title': 'Mertvye lastochki',
#   'year': 2018,
#   'genres': ['Thriller'],
#   'duration': 93,
#   'directors': ['Natalia Pershina'],
#   'cast': ['Evgeny Okorokov',
#    'Oleg Bilik',
#    'Valeriy Barinov',
#    'Aleksandr Bashirov'],
#   'rating': 6.3},
#  {'title': 'Glorious 39',
#   'year': 2009,
#   'genres': ['Drama', 'History', 'Mystery'],
#   'duration': 129,
#   'directors': ['Stephen Poliakoff'],
#   'cast': ['Romola Garai', 'Eddie Redmayne', 'Juno Temple', 'Toby Regbo'],
#   'rating': 6.4},
#  {'title': 'Wesens',
#   'year': 2020,
#   'genres': ['Mystery', 'Sci-Fi'],
#   'duration': 90,
#   'directors': ['Derick Muller'],
#   'cast': ['Rayno von Schlicht',
#    'Pietie Beyers',
#    'Randy Januarie',
#    'Albert Maritz',
#    'Pierre Nelson',
#    'Conradie van Heerden',
#    'Morné Visser'],
#   'rating': 6.4},
#  {'title': 'Infection',
#   'year': 2005,
#   'genres': ['Horror'],
#   'duration': 81,
#   'directors': ['Albert Pyun'],
#   'cast': ['Jenny Dare Paulin',
#    'Morgan Weisser',
#    'Alan Abelew',
#    'Tony Stewart'],
#   'rating': 4.1},
#  {'title': 'Charming Sinners',
#   'year': 1929,
#   'genres': ['Drama', 'Romance'],
#   'duration': 66,
#   'directors': ['Robert Milton', 'Dorothy Arzner'],
#   'cast': ['Ruth Chatterton', 'Clive Brook', 'Mary Nolan', 'William Powell'],
#   'rating': 6.1},
#  {'title': 'Under Sealed Orders',
#   'year': 1938,
#   'genres': ['Adventure', 'Crime'],
#   'duration': 105,
#   'directors': ['Karl Anton'],
#   'cast': ['Viktor de Kowa',
#    'Ernst Leudesdorff',
#    'Paul Hartmann',
#    'Suse Graf'],
#   'rating': 4.4},
#  {'title': 'The Bloody Lady',
#   'year': 1980,
#   'genres': ['Animation', 'Drama', 'History'],
#   'duration': 72,
#   'directors': ['Viktor Kubal'],
#   'cast': ['Jela Lukesová'],
#   'rating': 6.4},
#  {'title': 'The March on Rome',
#   'year': 2022,
#   'genres': ['Documentary'],
#   'duration': 98,
#   'directors': ['Mark Cousins'],
#   'cast': ['Alba Rohrwacher'],
#   'rating': 7.0},
#  {'title': 'Devi 2',
#   'year': 2019,
#   'genres': ['Comedy', 'Horror'],
#   'duration': 125,
#   'directors': ['A.L. Vijay'],
#   'cast': ['Prabhu Deva',
#    'Tamannaah Bhatia',
#    'Nandita Shwetha',
#    'Dimple Hayathi'],
#   'rating': 3.8},
#  {'title': 'Never Again as Before',
#   'year': 2005,
#   'genres': ['Drama'],
#   'duration': 106,
#   'directors': ['Giacomo Campiotti'],
#   'cast': ['Natalia Piatti',
#    'Marco Velluti',
#    'Federico Battilocchio',
#    "Nicola 'Max' Cipolla"],
#   'rating': 6.2},
#  {'title': 'Manolo guardia urbano',
#   'year': 1956,
#   'genres': ['Comedy'],
#   'duration': 90,
#   'directors': ['Rafael J. Salvia'],
#   'cast': ['Manolo Morán',
#    'Tony Leblanc',
#    'Ángel de Andrés',
#    'Antonio Riquelme'],
#   'rating': 6.2},
#  {'title': "L'intrépide",
#   'year': 1975,
#   'genres': ['Comedy'],
#   'duration': 90,
#   'directors': ['Jean Girault'],
#   'cast': ['Louis Velle',
#    'Claudine Auger',
#    'Juliette Mills',
#    'Michel Galabru'],
#   'rating': 4.4},
#  {'title': 'The Silent Party',
#   'year': 2019,
#   'genres': ['Action', 'Thriller'],
#   'duration': 87,
#   'directors': ['Diego Fried', 'Federico Finkielstain'],
#   'cast': ['Lautaro Aguilar',
#    'Lautaro Bettoni',
#    'Esteban Bigliardi',
#    'Gastón Cocchiarale'],
#   'rating': 5.4},
#  {'title': 'Vardi',
#   'year': 1989,
#   'genres': ['Action', 'Crime', 'Drama'],
#   'duration': 161,
#   'directors': ['Umesh Mehra'],
#   'cast': ['Sunny Deol', 'Jackie Shroff', 'Kimi Katkar', 'Madhuri Dixit'],
#   'rating': 4.6},
#  {'title': 'The Moromete Family',
#   'year': 1987,
#   'genres': ['Drama'],
#   'duration': 142,
#   'directors': ['Stere Gulea'],
#   'cast': ['Victor Rebengiuc',
#    'Luminita Gheorghiu',
#    'Gina Patrichi',
#    'Dorel Visan'],
#   'rating': 8.8},
#  {'title': '22 Shey Shraban',
#   'year': 2011,
#   'genres': ['Action', 'Crime', 'Drama'],
#   'duration': 139,
#   'directors': ['Srijit Mukherji'],
#   'cast': ['Prasenjit Chatterjee',
#    'Parambrata Chattopadhyay',
#    'Raima Sen',
#    'Abir Chatterjee'],
#   'rating': 8.1},
#  {'title': 'The Golden Yurt',
#   'year': 1961,
#   'genres': ['Adventure', 'Drama', 'Family'],
#   'duration': 79,
#   'directors': ['Ravjagiin Dorjpalam', 'Gottfried Kolditz'],
#   'cast': ['Dshambaagijn Lubsandshamdz',
#    'Zaagani Zegmed',
#    'Batsuchijn Zorig',
#    'Surengin Suchbaatar'],
#   'rating': 7.7},
#  {'title': 'William',
#   'year': 2019,
#   'genres': ['Adventure', 'Drama', 'Family'],
#   'duration': 100,
#   'directors': ['Tim Disney'],
#   'cast': ['Brody Wilkinson', 'Connor Wilkinson', 'Beth Grant', 'Obada Adnan'],
#   'rating': 5.6},
#  {'title': 'Die Auschwitz-Dialoge',
#   'year': 2007,
#   'genres': ['Documentary'],
#   'duration': 60,
#   'directors': ['Marian Ehret'],
#   'cast': ['Aleksander Kwasniewski'],
#   'rating': 6.6},
#  {'title': 'The Legend of Bloody Mary',
#   'year': 2008,
#   'genres': ['Horror', 'Thriller'],
#   'duration': 93,
#   'directors': ['John Stecenko'],
#   'cast': ['Paul Preiss',
#    'Robert J. Locke Jr.',
#    'Nicole Aiken',
#    'Brittany Miller'],
#   'rating': 2.7},
#  {'title': 'Kilma, reina de las amazonas',
#   'year': 1976,
#   'genres': ['Action', 'Adventure', 'Comedy'],
#   'duration': 83,
#   'directors': ['Miguel Iglesias'],
#   'cast': ['Verónica Miriel',
#    'Eva Miller',
#    'Frank Braña',
#    'Claudia Gravy',
#    'Luis Induni',
#    'Luis Ciges'],
#   'rating': 4.8},
#  {'title': 'Rokuroku: The Promise of the Witch',
#   'year': 2017,
#   'genres': ['Horror'],
#   'duration': 92,
#   'directors': ['Yudai Yamaguchi', 'Keita Amemiya'],
#   'cast': ['Erika Asakura',
#    'Moso Calibration',
#    'Mickey Curtis',
#    'Yukijirô Hotaru'],
#   'rating': 5.1},
#  {'title': 'Bunshinsaba: Hoichi the Earless',
#   'year': 2021,
#   'genres': ['Horror'],
#   'duration': 78,
#   'directors': ['River Huang'],
#   'cast': ['Huang Jia Jun', 'Rayna Wang', 'Guogang Yuan'],
#   'rating': 4.8},
#  {'title': 'Evangelion: 3.0+1.01 Thrice Upon a Time',
#   'year': 2021,
#   'genres': ['Action', 'Animation', 'Drama'],
#   'duration': 154,
#   'directors': ['Mahiro Maeda',
#    'Katsuichi Nakayama',
#    'Kazuya Tsurumaki',
#    'Hideaki Anno',
#    'Joe Fria'],
#   'cast': ['Megumi Ogata',
#    'Megumi Hayashibara',
#    'Yûko Miyamura',
#    'Akira Ishida'],
#   'rating': 8.0},
#  {'title': 'The Seventh Seal',
#   'year': 1957,
#   'genres': ['Drama', 'Fantasy'],
#   'duration': 96,
#   'directors': ['Ingmar Bergman'],
#   'cast': ['Max von Sydow',
#    'Gunnar Björnstrand',
#    'Bengt Ekerot',
#    'Nils Poppe'],
#   'rating': 8.1},
#  {'title': 'Lord of the Dance: Dangerous Games',
#   'year': 2014,
#   'genres': ['Music'],
#   'duration': 103,
#   'directors': ['Paul Dugdale'],
#   'cast': ['James Keegan',
#    'Thomas Cunningham',
#    'Caroline Gray',
#    'Aimee Black'],
#   'rating': 6.4},
#  {'title': 'Hot Pursuit',
#   'year': 1987,
#   'genres': ['Comedy'],
#   'duration': 93,
#   'directors': ['Steven Lisberger'],
#   'cast': ['John Cusack', 'Robert Loggia', 'Jerry Stiller', 'Wendy Gazelle'],
#   'rating': 5.7},
#  {'title': 'Rottenetter',
#   'year': 2009,
#   'genres': ['Drama'],
#   'duration': 94,
#   'directors': ['Arild Østin Ommundsen'],
#   'cast': ['Christian Rubeck',
#    'Fridtjov Såheim',
#    'Kristoffer Joner',
#    'Silje Salomonsen'],
#   'rating': 4.7},
#  {'title': 'Into the Void',
#   'year': 2000,
#   'genres': ['Drama', 'Sci-Fi'],
#   'duration': 90,
#   'directors': ['Matt Weinglass'],
#   'cast': ['Davin Anderson',
#    'Jeff Glassberg',
#    'Ryan Foland',
#    'Alexandra Ford'],
#   'rating': 7.6},
#  {'title': 'Lefteris',
#   'year': 1993,
#   'genres': ['Drama'],
#   'duration': 105,
#   'directors': ['Periklis Hoursoglou'],
#   'cast': ['Nikos Georgakis',
#    'Maria Skoula',
#    'Nikos Orfanos',
#    'Manolis Mavromatakis'],
#   'rating': 6.7},
#  {'title': 'Branded Men',
#   'year': 1931,
#   'genres': ['Western'],
#   'duration': 63,
#   'directors': ['Phil Rosen'],
#   'cast': ['Ken Maynard', 'Tarzan', 'June Clyde', 'Irving Bacon'],
#   'rating': 6.1},
#  {'title': 'One Stop for Love',
#   'year': 2020,
#   'genres': ['Comedy', 'Romance'],
#   'duration': 65,
#   'directors': ['Supriya Khan', 'Ismail Umarr Khan'],
#   'cast': ['Shweta Khanduri', 'Mousam Sharma', 'Shikha Singh', 'Richa Sinha'],
#   'rating': 8.9},
#  {'title': 'So This Is Washington',
#   'year': 1943,
#   'genres': ['Comedy'],
#   'duration': 64,
#   'directors': ['Ray McCarey'],
#   'cast': ['Chester Lauck', 'Norris Goff', 'Alan Mowbray', 'Mildred Coles'],
#   'rating': 5.5},
#  {'title': "For Christ's Sake",
#   'year': 2010,
#   'genres': ['Comedy'],
#   'duration': 90,
#   'directors': ['Jackson Douglas'],
#   'cast': ['Sara Rue', 'Alex Borstein', 'Will Sasso', 'Armin Shimerman'],
#   'rating': 5.7},
#  {'title': 'Goosed',
#   'year': 1999,
#   'genres': ['Comedy'],
#   'duration': 95,
#   'directors': ['Aleta Chappelle'],
#   'cast': ['Jennifer Tilly', 'Danielle Harris', 'Joan Rivers', 'Robert Klein'],
#   'rating': 4.2},
#  {'title': 'The Jolson Story',
#   'year': 1946,
#   'genres': ['Biography', 'Drama', 'Music'],
#   'duration': 128,
#   'directors': ['Alfred E. Green'],
#   'cast': ['Larry Parks', 'Evelyn Keyes', 'William Demarest', 'Bill Goodwin'],
#   'rating': 7.2},
#  {'title': 'The Warrant',
#   'year': 2020,
#   'genres': ['Western'],
#   'duration': 84,
#   'directors': ['Brent Christy'],
#   'cast': ['Neal McDonough',
#    'Steven R. McQueen',
#    'Casper Van Dien',
#    'Annabeth Gish'],
#   'rating': 4.6},
#  {'title': 'Suficiente coraje',
#   'year': 2016,
#   'genres': ['Drama'],
#   'duration': 71,
#   'directors': ['John Robertson'],
#   'cast': ['Natalia Dufuur',
#    'Julio Jung',
#    'Patricia Pacheco',
#    'Alexander Solórzano'],
#   'rating': 7.2},
#  {'title': 'Yellow Board',
#   'year': 2022,
#   'genres': ['Crime', 'Drama', 'Thriller'],
#   'duration': 157,
#   'directors': ['Thrilok Reddy'],
#   'cast': ['Pradeep Bogadi', 'Ahalya Suresh', 'Sadhu Kokila', 'Sneha Singh'],
#   'rating': 7.9},
#  {'title': 'The Orion',
#   'year': 2010,
#   'genres': ['Drama'],
#   'duration': 80,
#   'directors': ['Ali Zamani Esmati'],
#   'cast': ['Hamed Baraghani',
#    'Mohamad Reza Farzad',
#    'Nasim Kiani',
#    'Mehrdad Sheykhi'],
#   'rating': 6.2},
#  {'title': 'Colombo',
#   'year': 2021,
#   'genres': ['Drama'],
#   'duration': 90,
#   'directors': ['Asama Randil'],
#   'cast': ['Hemal Ranasinghe',
#    'Dharmapriya Dias',
#    'Kumara Thirimadura',
#    'Rukmal Nirosh'],
#   'rating': 7.2},
#  {'title': 'Hai Tujhe Salaam India',
#   'year': 2022,
#   'genres': ['Drama'],
#   'duration': 102,
#   'directors': ['Avanish Kumar'],
#   'cast': ['Ajaz Khan', 'Arya Babbar', 'Smita Gondkar', 'Kanwalpreet Singh'],
#   'rating': 8.1},
#  {'title': 'Hello Brother',
#   'year': 1994,
#   'genres': ['Action', 'Comedy', 'Drama'],
#   'duration': 158,
#   'directors': ['E.V.V. Satyanarayana'],
#   'cast': ['Nagarjuna Akkineni',
#    'Ramya Krishnan',
#    'Soundarya',
#    'Brahmanandam'],
#   'rating': 7.4},
#  {'title': 'Rehearsals for War',
#   'year': 1998,
#   'genres': ['Drama'],
#   'duration': 113,
#   'directors': ['Mario Martone'],
#   'cast': ['Andrea Renzi',
#    'Iaia Forte',
#    'Maurizio Bizzi',
#    'Salvatore Cantalupo'],
#   'rating': 6.7},
#  {'title': 'Karisik pizza',
#   'year': 1998,
#   'genres': ['Comedy', 'Crime', 'Thriller'],
#   'duration': 94,
#   'directors': ['Umur Turagay'],
#   'cast': ['Olgun Simsek', 'Meltem Cumbul', 'Cem Özer', 'Sait Ergenç'],
#   'rating': 5.8},
#  {'title': 'Travessia',
#   'year': 2015,
#   'genres': ['Drama'],
#   'duration': 90,
#   'directors': ['João Gabriel'],
#   'cast': ['Cristiane Ferreira',
#    'Carolina Brasil',
#    'Camilla Camargo',
#    'Caio Castro',
#    'Celso Jr.',
#    'Cyria Coentro',
#    'Chico Díaz'],
#   'rating': 4.9},
#  {'title': 'The Runestone',
#   'year': 1991,
#   'genres': ['Adventure', 'Comedy', 'Fantasy'],
#   'duration': 105,
#   'directors': ['Willard Carroll'],
#   'cast': ['Peter Riegert', 'Joan Severance', 'William Hickey', 'Tim Ryan'],
#   'rating': 4.8},
#  {'title': 'Glee: The 3D Concert Movie',
#   'year': 2011,
#   'genres': ['Documentary', 'Music'],
#   'duration': 84,
#   'directors': ['Kevin Tancharoen', 'Jennifer Arnold'],
#   'cast': ['Cory Monteith', 'Dianna Agron', 'Lea Michele', 'Chris Colfer'],
#   'rating': 5.5},
#  {'title': 'Amok',
#   'year': 2015,
#   'genres': ['Drama', 'Thriller'],
#   'duration': 76,
#   'directors': ['R.E. Rodgers'],
#   'cast': ['Josh Hamilton', 'Juliet Rylance', 'Kate Burton', 'Mason Coleman'],
#   'rating': 5.8},
#  {'title': 'The Last Attraction',
#   'year': 1929,
#   'genres': ['Drama'],
#   'duration': 79,
#   'directors': ['Ivan Pravov', 'Olga Preobrazhenskaya'],
#   'cast': ['Ivan Bykov',
#    'Yelena Maksimova',
#    'Raisa Puzhnaya',
#    'Naum Rogozhin'],
#   'rating': 6.9},
#  {'title': 'Twice Branded',
#   'year': 1936,
#   'genres': ['Crime', 'Drama'],
#   'duration': 72,
#   'directors': ['Maclean Rogers'],
#   'cast': ['Robert Rendel', 'Lucille Lisle', 'James Mason', 'Eve Gray'],
#   'rating': 5.5},
#  {'title': 'The Oil Raider',
#   'year': 1934,
#   'genres': ['Action', 'Adventure', 'Romance'],
#   'duration': 59,
#   'directors': ['Spencer Gordon Bennet'],
#   'cast': ['Buster Crabbe', 'Gloria Shea', 'George Irving', 'Max Wagner'],
#   'rating': 5.3},
#  {'title': 'America 101',
#   'year': 2005,
#   'genres': ['Comedy'],
#   'duration': 86,
#   'directors': ['Mark A. Russell'],
#   'cast': ['Miguel Castro',
#    'Richard Azurdia',
#    'Christine Carlo',
#    'Gerald Brodin'],
#   'rating': 5.5},
#  {'title': "J'ai une idée",
#   'year': 1934,
#   'genres': ['Comedy'],
#   'duration': 100,
#   'directors': ['Roger Richebé'],
#   'cast': ['Raimu', 'Georges Morton', 'Félix Oudart', 'Henri Poupon'],
#   'rating': 6.5},
#  {'title': 'Dancehall Queen',
#   'year': 1997,
#   'genres': ['Drama'],
#   'duration': 98,
#   'directors': ['Rick Elgood', 'Don Letts'],
#   'cast': ['Audrey Reid', 'Carl Davis', 'Paul Campbell', 'Mark Danvers'],
#   'rating': 6.8},
#  {'title': 'See Jane Run',
#   'year': 2007,
#   'genres': ['Horror'],
#   'duration': 86,
#   'directors': ['Ryan Webb'],
#   'cast': ['Jennifer Clary',
#    'Sasha Andreev',
#    'Joe Estevez',
#    'John Gabriel Rodriquez'],
#   'rating': 3.2},
#  {'title': 'Simplicio',
#   'year': 1978,
#   'genres': ['Drama'],
#   'duration': 100,
#   'directors': ['Franco Rubartelli'],
#   'cast': ['David Lares',
#    'Guillermo Montesinos',
#    'Antonio Rodríguez',
#    'Luis Salazar'],
#   'rating': 7.7},
#  {'title': 'Lumaban ka, Satanas',
#   'year': 1983,
#   'genres': ['Action', 'Adventure', 'Fantasy'],
#   'duration': 90,
#   'directors': ['Efren C. Piñon'],
#   'cast': ['Ramon Revilla',
#    'Elizabeth Oropesa',
#    'George Estregan',
#    'Paquito Diaz'],
#   'rating': 4.7},
#  {'title': 'Daadi Maa',
#   'year': 1966,
#   'genres': ['Action', 'Comedy', 'Drama'],
#   'duration': 171,
#   'directors': ['L.V. Prasad'],
#   'cast': ['Ashok Kumar', 'Bina Rai', 'Dilip Raj', 'Mumtaz Askari'],
#   'rating': 6.4},
#  {'title': '¡Que vivan los muertos!',
#   'year': 1998,
#   'genres': ['Comedy', 'Drama', 'Fantasy'],
#   'duration': 90,
#   'directors': ['Joaquín Bissner'],
#   'cast': ['Mauricio Herrera',
#    'Margarita Isabel',
#    'Luis de Icaza',
#    'Mario Casillas'],
#   'rating': 6.1},
#  {'title': 'California Solo',
#   'year': 2012,
#   'genres': ['Drama'],
#   'duration': 94,
#   'directors': ['Marshall Lewy'],
#   'cast': ['Robert Carlyle',
#    'Alexia Rasmussen',
#    'Kathleen Wilhoite',
#    'A Martinez'],
#   'rating': 6.2},
#  {'title': 'Furious Beauty',
#   'year': 2013,
#   'genres': ['Documentary', 'Drama', 'Family'],
#   'duration': 88,
#   'directors': ['Calvin Leung'],
#   'cast': ['Alex Almarez', 'Alex Ayon', 'Raymond Basa', 'Anthony Berry'],
#   'rating': 8.8},
#  {'title': 'Doraemon: Nobita and the Galaxy Super-express',
#   'year': 1996,
#   'genres': ['Action', 'Adventure', 'Animation'],
#   'duration': 97,
#   'directors': ['Tsutomu Shibayama'],
#   'cast': ['Nobuyo Ôyama',
#    'Noriko Ohara',
#    'Michiko Nomura',
#    'Kaneta Kimotsuki',
#    'Kazuya Tatekabe'],
#   'rating': 6.9},
#  {'title': 'From Tomorrow on, I Will',
#   'year': 2019,
#   'genres': ['Drama'],
#   'duration': 60,
#   'directors': ['Ivan Markovic', 'Linfeng Wu'],
#   'cast': ['Chuan Li', 'Luying Wang', 'Ruguang Wei'],
#   'rating': 6.8},
#  {'title': 'El pequeño coronel',
#   'year': 1960,
#   'genres': ['Adventure', 'Drama', 'Family'],
#   'duration': 85,
#   'directors': ['Antonio del Amo'],
#   'cast': ['Joselito', 'Carlos Larrañaga', 'María Mahor', 'Tomás Blanco'],
#   'rating': 5.1},
#  {'title': 'Chrysanthemum to the Beast',
#   'year': 2012,
#   'genres': ['Action', 'Comedy', 'Romance'],
#   'duration': 91,
#   'directors': ['Leo Zhang'],
#   'cast': ['Danni Liang',
#    'Ady An',
#    'Jaycee Chan',
#    'Ricky Chan',
#    'Yiheng Du',
#    'Jack Kao',
#    'Suet Lam',
#    'Shera Li'],
#   'rating': 5.6},
#  {'title': 'The Godfather Part II',
#   'year': 1974,
#   'genres': ['Crime', 'Drama'],
#   'duration': 202,
#   'directors': ['Francis Ford Coppola'],
#   'cast': ['Al Pacino', 'Robert De Niro', 'Robert Duvall', 'Diane Keaton'],
#   'rating': 9.0},
#  {'title': 'Build a Ship, Sail to Sadness',
#   'year': 2007,
#   'genres': ['Musical'],
#   'duration': 70,
#   'directors': ['Laurin Federlein'],
#   'cast': ['Magnus Aronson'],
#   'rating': 7.6},
#  {'title': 'The Winning Ticket',
#   'year': 1935,
#   'genres': ['Comedy'],
#   'duration': 70,
#   'directors': ['Charles Reisner'],
#   'cast': ['Leo Carrillo', 'Louise Fazenda', 'Ted Healy', 'Irene Hervey'],
#   'rating': 5.5},
#  {'title': 'The Road to Galena',
#   'year': 2022,
#   'genres': ['Drama'],
#   'duration': 110,
#   'directors': ['Joe Hall'],
#   'cast': ['Ben Winchell',
#    'Will Brittain',
#    'Aimee Teegarden',
#    'Alisa Allapach'],
#   'rating': 7.9},
#  {'title': 'Zero Hour',
#   'year': 1998,
#   'genres': ['War'],
#   'duration': 90,
#   'directors': ['Sterling Zielinski'],
#   'cast': ['Henry Kemp', 'Steve Hosford', 'Kalli Jonson', 'Dave James'],
#   'rating': 7.3},
#  {'title': 'Nepobedimyy',
#   'year': 1983,
#   'genres': ['Action'],
#   'duration': 69,
#   'directors': ['Yuri Boretsky'],
#   'cast': ['Andrey Rostotskiy',
#    'Khamza Umarov',
#    'Nurmukhan Zhanturin',
#    'Yedgor Sagdiyev'],
#   'rating': 6.5},
#  {'title': 'The Match King',
#   'year': 1932,
#   'genres': ['Drama'],
#   'duration': 79,
#   'directors': ['Howard Bretherton', 'William Keighley'],
#   'cast': ['Warren William',
#    'Lili Damita',
#    'Glenda Farrell',
#    'Juliette Compton'],
#   'rating': 6.9},
#  {'title': 'All About My Sisters',
#   'year': 2021,
#   'genres': ['Documentary'],
#   'duration': 174,
#   'directors': ['Qiong Wang'],
#   'cast': ['Jin Zhou',
#    'Li Wang',
#    'Xiaoqing Yan',
#    'Jianhua Wang',
#    'Sifan Wang'],
#   'rating': 6.9},
#  {'title': 'Nothing to Lose',
#   'year': 2002,
#   'genres': ['Comedy', 'Crime', 'Drama'],
#   'duration': 94,
#   'directors': ['Danny Pang'],
#   'cast': ['Arisara Wongchalee',
#    'Pierre Png',
#    'Yvonne Lim',
#    'Nimponth Chaisirikul'],
#   'rating': 5.5},
#  {'title': 'Sator',
#   'year': 2019,
#   'genres': ['Horror'],
#   'duration': 85,
#   'directors': ['Jordan Graham'],
#   'cast': ['Michael Daniel',
#    'Rachel Johnson',
#    'Aurora Lowe',
#    'Gabriel Nicholson'],
#   'rating': 5.2},
#  {'title': 'State of Play',
#   'year': 2013,
#   'genres': ['Documentary', 'Drama', 'Sport'],
#   'duration': 87,
#   'directors': ['Steven Dhoedt'],
#   'cast': ['Adam Chaffin'],
#   'rating': 6.3},
#  {'title': 'Un homme perdu',
#   'year': 2007,
#   'genres': ['Drama'],
#   'duration': 93,
#   'directors': ['Danielle Arbid'],
#   'cast': ['Melvil Poupaud',
#    'Alexander Siddig',
#    'Darina Al Joundi',
#    'Yasmine Lafitte'],
#   'rating': 5.3},
#  {'title': 'Dibujando el Cielo',
#   'year': 2018,
#   'genres': ['Drama', 'Romance'],
#   'duration': 84,
#   'directors': ['Ana Laura Calderón'],
#   'cast': ['Maite Perroni',
#    'Iván Sánchez',
#    'Christian Vazquez',
#    'Claudia Ramírez'],
#   'rating': 5.6},
#  {'title': 'Kortik',
#   'year': 1954,
#   'genres': ['Adventure', 'Family'],
#   'duration': 83,
#   'directors': ['Mikhail Shvejtser', 'Vladimir Vengerov'],
#   'cast': ['Arkadi Tolbuzin',
#    'Bruno Frejndlikh',
#    'Volodia Shakhmametiev',
#    'Boris Arakelov'],
#   'rating': 6.3},
#  {'title': 'El bruto',
#   'year': 1962,
#   'genres': ['Drama'],
#   'duration': 78,
#   'directors': ['Rubén W. Cavalloti'],
#   'cast': ['Susana Campos',
#    'Leonardo Favio',
#    'Ricardo Trigo',
#    'Eloísa Cañizares'],
#   'rating': 6.5},
#  {'title': 'Wives - Ten Years After',
#   'year': 1985,
#   'genres': ['Comedy', 'Drama'],
#   'duration': 88,
#   'directors': ['Anja Breien'],
#   'cast': ['Frøydis Armand',
#    'Katja Medbøe',
#    'Anne Marie Ottersen',
#    'Mathias Armand'],
#   'rating': 4.5},
#  {'title': 'Viharbrigád',
#   'year': 1944,
#   'genres': ['Drama'],
#   'duration': 73,
#   'directors': ['István ifj. Lázár'],
#   'cast': ['Bella Bordy', 'János Sárdy', 'Manyi Kiss', 'Endre C. Turáni'],
#   'rating': 6.6},
#  {'title': 'Crime School',
#   'year': 1938,
#   'genres': ['Crime', 'Drama'],
#   'duration': 85,
#   'directors': ['Lewis Seiler', 'William Clemens'],
#   'cast': ['Humphrey Bogart', 'The Dead End Kids', 'Gale Page', 'Billy Halop'],
#   'rating': 6.5},
#  {'title': 'The Prodigy',
#   'year': 2009,
#   'genres': ['Animation'],
#   'duration': 77,
#   'directors': ['Robert D. Hanna'],
#   'cast': ['Rhiann Woodyard',
#    'Courtnee Draper',
#    'Robby Daniels',
#    'Ray Hanna',
#    'Jeffrey Lee Hollis',
#    'Joy Michele',
#    'Patrick Pumpuang'],
#   'rating': 1.8},
#  {'title': 'Detox',
#   'year': 2009,
#   'genres': ['Crime', 'Drama'],
#   'duration': 85,
#   'directors': ['Ross Hockrow'],
#   'cast': ['Shawn Wootten',
#    'Kenya Gaines',
#    'Stephen M. Coppock',
#    'Jason Hollett'],
#   'rating': 4.3},
#  {'title': 'Tempo',
#   'year': 2003,
#   'genres': ['Crime', 'Romance', 'Thriller'],
#   'duration': 83,
#   'directors': ['Eric Styles'],
#   'cast': ['Melanie Griffith',
#    'Rachael Leigh Cook',
#    'Hugh Dancy',
#    'Malcolm McDowell'],
#   'rating': 4.6},
#  {'title': 'Baba Taraknath',
#   'year': 1977,
#   'genres': ['Drama'],
#   'duration': 159,
#   'directors': ['Sunil Bannerjee', 'Baren Chatterjee'],
#   'cast': ['Sandhya Roy',
#    'Biswajeet Chatterjee',
#    'Sulochana Chatterjee',
#    'Gurudas Bannerjee'],
#   'rating': 5.1},
#  {'title': "Dracula's Last Rites",
#   'year': 1980,
#   'genres': ['Horror'],
#   'duration': 86,
#   'directors': ['Domonic Paris'],
#   'cast': ['Patricia Lee Hammond',
#    'Gerald Fielding',
#    'Mimi Weddell',
#    'Victor Jorge'],
#   'rating': 3.7},
#  {'title': 'Sins of the Night',
#   'year': 1993,
#   'genres': ['Crime', 'Thriller'],
#   'duration': 85,
#   'directors': ['Gregory Dark'],
#   'cast': ['Nick Cassavetes',
#    'Deborah Shelton',
#    "Miles O'Keeffe",
#    'Richard Roundtree'],
#   'rating': 4.8},
#  {'title': 'Red Pearl',
#   'year': 2016,
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'duration': 77,
#   'directors': ['Stacy Barton', 'Jessica McGaugh'],
#   'cast': ['Desira Pesta', 'Iliana Barron', 'Matt Block', 'Mary Cates'],
#   'rating': 7.9},
#  {'title': 'Friends Who Kill',
#   'year': 2020,
#   'genres': ['Thriller'],
#   'duration': 86,
#   'directors': ['Richard Switzer'],
#   'cast': ['Natalie Brown',
#    'Sarah Fisher',
#    'Alexa Rose Steele',
#    'Reha Sandill'],
#   'rating': 4.8},
#  {'title': 'The Bag Man',
#   'year': 2005,
#   'genres': ['Comedy'],
#   'duration': 90,
#   'directors': ['Insane Mike Saunders'],
#   'cast': ['Chris Alexander',
#    'Jeff Alexander',
#    'Melissa Alexander',
#    'Mike Alexander'],
#   'rating': 6.2},
#  {'title': 'As Good as It Gets',
#   'year': 1997,
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'duration': 139,
#   'directors': ['James L. Brooks'],
#   'cast': ['Jack Nicholson', 'Helen Hunt', 'Greg Kinnear', 'Cuba Gooding Jr.'],
#   'rating': 7.7},
#  {'title': 'The Girl and the Press Photographer',
#   'year': 1963,
#   'genres': ['Comedy', 'Romance'],
#   'duration': 100,
#   'directors': ['Sven Methling'],
#   'cast': ['Dirch Passer', 'Ghita Nørby', 'Judy Gringer', 'Axel Strøbye'],
#   'rating': 6.1},
#  {'title': 'Yellow Cargo',
#   'year': 1936,
#   'genres': ['Action', 'Comedy', 'Crime'],
#   'duration': 63,
#   'directors': ['Crane Wilbur'],
#   'cast': ['Conrad Nagel', 'Eleanor Hunt', 'Vince Barnett', 'Jack La Rue'],
#   'rating': 5.2},
#  {'title': '9-9-81',
#   'year': 2012,
#   'genres': ['Horror'],
#   'duration': 92,
#   'directors': ['Rapeepimol Chaiyasena'],
#   'cast': ['Patitta Attayatamavitaya',
#    'Supachai Girdsuwan',
#    'Setsit Limkasitdej',
#    'Thiti Vechabul'],
#   'rating': 5.3},
#  {'title': 'Together',
#   'year': 2009,
#   'genres': ['Drama'],
#   'duration': 100,
#   'directors': ['Matias Armand Jordal'],
#   'cast': ['Catrin Larell Eide',
#    'Jonathan Espolin-Johnson',
#    'Mona Grenne',
#    'Trond Halbo'],
#   'rating': 6.6},
#  {'title': 'Hello, Mr. Kivi',
#   'year': 1984,
#   'genres': ['Drama'],
#   'duration': 88,
#   'directors': ['Timo Linnasalo'],
#   'cast': ['Kristiina Elstelä',
#    'Markku Huhtamo',
#    'Ragni Grönblom',
#    'Antti Litja'],
#   'rating': 4.7},
#  {'title': 'Eu, tu si Ovidiu',
#   'year': 1978,
#   'genres': ['Comedy', 'Musical'],
#   'duration': 108,
#   'directors': ['Geo Saizescu'],
#   'cast': ['Florin Piersic',
#    'Violeta Andrei',
#    'Sebastian Papaiani',
#    'Dem Radulescu'],
#   'rating': 6.6},
#  {'title': 'Henry Fool',
#   'year': 1997,
#   'genres': ['Comedy', 'Drama'],
#   'duration': 137,
#   'directors': ['Hal Hartley'],
#   'cast': ['Thomas Jay Ryan',
#    'James Urbaniak',
#    'Parker Posey',
#    'Maria Porter'],
#   'rating': 7.2},
#  {'title': 'Souvenir',
#   'year': 1994,
#   'genres': ['Comedy'],
#   'duration': 90,
#   'directors': ['Rosa Vergés'],
#   'cast': ['Futoshi Kasagawa', 'Emma Suárez', 'Anna Lizaran', 'Pepa López'],
#   'rating': 6.1},
#  {'title': 'The Linguini Incident',
#   'year': 1991,
#   'genres': ['Comedy', 'Crime'],
#   'duration': 108,
#   'directors': ['Richard Shepard'],
#   'cast': ['Rosanna Arquette',
#    'David Bowie',
#    'Eszter Balint',
#    'Andre Gregory'],
#   'rating': 6.2},
#  {'title': 'Elizabeth: The Golden Age',
#   'year': 2007,
#   'genres': ['Biography', 'Drama', 'History'],
#   'duration': 114,
#   'directors': ['Shekhar Kapur'],
#   'cast': ['Cate Blanchett', 'Clive Owen', 'Geoffrey Rush', 'Jordi Mollà'],
#   'rating': 6.8},
#  {'title': 'Cowboys',
#   'year': 2020,
#   'genres': ['Drama'],
#   'duration': 86,
#   'directors': ['Anna Kerrigan'],
#   'cast': ['Steve Zahn', 'Jillian Bell', 'Sasha Knight', 'Ann Dowd'],
#   'rating': 6.4},
#  {'title': 'The Sword and the Lute',
#   'year': 1967,
#   'genres': ['Action', 'Adventure', 'Drama'],
#   'duration': 87,
#   'directors': ['Teng-Hung Hsu'],
#   'cast': ['Jimmy Wang Yu', 'Ping Chin', 'Margaret Hsing Hui'],
#   'rating': 6.8},
#  {'title': "A Woman's Kingdom",
#   'year': 1968,
#   'genres': ['Drama', 'War'],
#   'duration': 97,
#   'directors': ['Aleksei Saltykov'],
#   'cast': ['Rimma Markova',
#    'Svetlana Sukhovey',
#    'Svetlana Zhgun',
#    'Vitali Solomin'],
#   'rating': 7.3},
#  {'title': 'Throuple',
#   'year': 2015,
#   'genres': ['Comedy', 'Drama'],
#   'duration': 97,
#   'directors': ['Phillips Payson'],
#   'cast': ['Mikaal Bates',
#    'Caitlin Holcombe',
#    'Ayinde Howell',
#    'Todd Litzinger'],
#   'rating': 5.2},
#  {'title': "L'amore molesto",
#   'year': 1995,
#   'genres': ['Drama', 'Mystery', 'Romance'],
#   'duration': 104,
#   'directors': ['Mario Martone'],
#   'cast': ['Anna Bonaiuto', 'Angela Luce', 'Gianni Cajafa', 'Peppe Lanzetta'],
#   'rating': 6.5},
#  {'title': 'Balakrishnudu',
#   'year': 2017,
#   'genres': ['Action', 'Comedy', 'Romance'],
#   'duration': 130,
#   'directors': ['Pavan Mallela'],
#   'cast': ['Chitti',
#    'Mahesh Achanta',
#    'Ajay',
#    'Raghu Babu',
#    'Piaa Bajpai',
#    'Regina Cassandra'],
#   'rating': 4.6},
#  {'title': 'Strength in Numbers',
#   'year': 2011,
#   'genres': ['Thriller'],
#   'duration': 52,
#   'directors': ['Robby Starbuck'],
#   'cast': ['Adam Dutkiewicz',
#    'Austin Foster',
#    'Mercedes Foster',
#    'Sheron Henry-Smith'],
#   'rating': 6.6},
#  {'title': 'The Secret of Convict Lake',
#   'year': 1951,
#   'genres': ['Western'],
#   'duration': 83,
#   'directors': ['Michael Gordon'],
#   'cast': ['Glenn Ford', 'Gene Tierney', 'Ethel Barrymore', 'Zachary Scott'],
#   'rating': 6.9},
#  {'title': 'Rebound',
#   'year': 1931,
#   'genres': ['Drama'],
#   'duration': 89,
#   'directors': ['Edward H. Griffith'],
#   'cast': ['Ina Claire', 'Robert Ames', 'Myrna Loy', 'Hedda Hopper'],
#   'rating': 5.7},
#  {'title': 'Pirates of the High Seas',
#   'year': 1950,
#   'genres': ['Action', 'Crime', 'Family'],
#   'duration': 260,
#   'directors': ['Spencer Gordon Bennet', 'Thomas Carr'],
#   'cast': ['Buster Crabbe', 'Lois Hall', 'Tommy Farrell', 'Gene Roth'],
#   'rating': 7.0},
#  {'title': 'Kaptein Caprivi',
#   'year': 1972,
#   'genres': ['Action', 'Adventure', 'War'],
#   'duration': 85,
#   'directors': ['Albie Venter'],
#   'cast': ['Will Sealie', 'Norman C. Smith', 'Ken Hare', 'Jannie Hanzen'],
#   'rating': 5.1},
#  {'title': 'Vacancy',
#   'year': 2005,
#   'genres': ['Drama'],
#   'duration': 52,
#   'directors': ['Steve Hosford'],
#   'cast': ['Jordan Anderson',
#    'Elise Robertson',
#    'Robert C. Pullman',
#    'Gina DeVivo'],
#   'rating': 7.0},
#  {'title': 'World War III',
#   'year': 2022,
#   'genres': ['Adventure', 'War'],
#   'duration': 117,
#   'directors': ['Houman Seyyedi'],
#   'cast': ['Mohsen Tanabandeh',
#    'Mahsa Hejazi',
#    'Neda Jebraeili',
#    'Navid Nosrati'],
#   'rating': 8.5},
#  {'title': 'Dirty Laundry',
#   'year': 1987,
#   'genres': ['Comedy', 'Thriller'],
#   'duration': 79,
#   'directors': ['William Webb'],
#   'cast': ['Leigh McCloskey',
#    "Jeanne O'Brien",
#    'Robbie Rist',
#    'Frankie Valli'],
#   'rating': 4.0},
#  {'title': "Orpheus' Song",
#   'year': 2019,
#   'genres': ['Adventure'],
#   'duration': 75,
#   'directors': ['Tor Iben'],
#   'cast': ['Sascha Weingarten',
#    'Julien Lickert',
#    'Henry Morales',
#    'Kristina Kostiv'],
#   'rating': 5.7},
#  {'title': 'Half Piece of Map',
#   'year': 1981,
#   'genres': ['Action', 'Fantasy'],
#   'duration': 85,
#   'directors': ['Hyeok-su Lee'],
#   'cast': ['Ian Han', 'Jeong-lee Hwang', 'Jung-il Nam', 'Ae-kyeong Park'],
#   'rating': 4.9},
#  {'title': 'Bring Me the Head of Mavis Davis',
#   'year': 1997,
#   'genres': ['Comedy', 'Crime'],
#   'duration': 100,
#   'directors': ['John Henderson'],
#   'cast': ['Daniel Abineri', 'Danny Aiello', 'Justin Avoth', 'Nick Bartlett'],
#   'rating': 5.2},
#  {'title': 'Just Bea',
#   'year': 2004,
#   'genres': ['Drama'],
#   'duration': 86,
#   'directors': ['Petter Næss'],
#   'cast': ['Kaia Foss',
#    'Kamilla Grønli Hartvig',
#    'Ida Thurman-Moe',
#    'Maria Brinch'],
#   'rating': 5.4},
#  {'title': 'So Undercover',
#   'year': 2012,
#   'genres': ['Action', 'Comedy', 'Crime'],
#   'duration': 94,
#   'directors': ['Tom Vaughan'],
#   'cast': ['Miley Cyrus', 'Jeremy Piven', "Mike O'Malley", 'Josh Bowman'],
#   'rating': 5.0},
#  {'title': 'Electra',
#   'year': 1996,
#   'genres': ['Action', 'Sci-Fi', 'Thriller'],
#   'duration': 87,
#   'directors': ['Julian Grant'],
#   'cast': ['Shannon Tweed', 'Joe Tabb', 'Sten Eirik', 'Katie Griffin'],
#   'rating': 3.4},
#  {'title': "I'm Obsessed with You (But You've Got to Leave Me Alone)",
#   'year': 2014,
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'duration': 99,
#   'directors': ['Jon Goracy'],
#   'cast': ['Rachel Brosnahan', 'Jason Ralph', 'Manish Dayal', 'Neil Casey'],
#   'rating': 6.5},
# ...
#    'Hiroko Sakuramachi'],
#   'rating': 7.2},
#  {'title': 'American Cuisine',
#   'year': 1998,
#   'genres': ['Comedy'],
#   'duration': 92,
#   'directors': ['Jean-Yves Pitoun'],
#   'cast': ['Jason Lee',
#    'Eddy Mitchell',
#    'Irène Jacob',
#    'Isabelle Petit-Jacques'],
#   'rating': 6.2},
#  {'title': 'A Desperate Adventure',
#   'year': 1924,
#   'genres': ['Western'],
#   'duration': 50,
#   'directors': ['J.P. McGowan'],
#   'cast': ['Franklyn Farnum', 'Marie Walcamp', 'Priscilla Bonner'],
#   'rating': 5.9},
#  {'title': 'Garbage, the City and Death',
#   'year': 2012,
#   'genres': ['Drama'],
#   'duration': 74,
#   'directors': ['Jan Hrebejk'],
#   'cast': ['Jirí Cerný',
#    'Stefan Chovanec',
#    'Martin Finger',
#    'Stanislav Majer'],
#   'rating': 6.3},
#  {'title': 'Revenge of the Calendar Girls',
#   'year': 1995,
#   'genres': ['Comedy', 'Horror'],
#   'duration': 88,
#   'directors': ['James Hill'],
#   'cast': ['Leigh Betchley',
#    'Cleo Crutchfield Jr.',
#    'Hajib Entessari',
#    'Butch Goodwich'],
#   'rating': 4.5},
#  {'title': 'Rokovaya oshibka',
#   'year': 1989,
#   'genres': ['Crime', 'Drama'],
#   'duration': 104,
#   'directors': ['Nikita Khubov'],
#   'cast': ['Larisa Pavlova',
#    'Natalya Androsik',
#    'Olga Ageyeva',
#    'Irina Kashaliyeva'],
#   'rating': 6.2},
#  {'title': 'Maayon',
#   'year': 2022,
#   'genres': ['Mystery', 'Thriller'],
#   'duration': 131,
#   'directors': ['Kishore'],
#   'cast': ['Sibiraj', 'Tanya S Ravichandran', 'Radha Ravi', 'K.S. Ravikumar'],
#   'rating': 9.1},
#  {'title': 'Mint Julep',
#   'year': 2010,
#   'genres': ['Comedy', 'Drama'],
#   'duration': 99,
#   'directors': ['Kathy Fehl', 'Ian Teal'],
#   'cast': ['Angelica Page', 'David Morse', 'James Gandolfini', 'Susan Aston'],
#   'rating': 5.9},
#  {'title': 'While You Are Here',
#   'year': 2006,
#   'genres': ['Drama'],
#   'duration': 77,
#   'directors': ['Stefan Westerwelle'],
#   'cast': ['Michael Gempart', 'Leander Lichti'],
#   'rating': 5.7},
#  {'title': 'Coluche',
#   'year': 2008,
#   'genres': ['Biography', 'Comedy', 'Drama'],
#   'duration': 100,
#   'directors': ['Antoine de Caunes'],
#   'cast': ['François-Xavier Demaison',
#    'Léa Drucker',
#    'Olivier Gourmet',
#    'Laurent Bateau'],
#   'rating': 5.6},
#  {'title': 'Dublerzy',
#   'year': 2006,
#   'genres': ['Action', 'Comedy'],
#   'duration': 110,
#   'directors': ['Marcin Ziebinski'],
#   'cast': ['Violetta Arlak',
#    'Bartlomiej Bobrowski',
#    'Janusz Chabior',
#    'Beata Chruscinska'],
#   'rating': 3.8},
#  {'title': "It Knows You're Alone",
#   'year': 2021,
#   'genres': ['Horror'],
#   'duration': 46,
#   'directors': ['Chris Alexander'],
#   'cast': ['Ali Chappell', 'Brandy Dawley'],
#   'rating': 3.5},
#  {'title': 'Joe Palooka in Winner Take All',
#   'year': 1948,
#   'genres': ['Comedy', 'Drama', 'Family'],
#   'duration': 64,
#   'directors': ['Reginald Le Borg'],
#   'cast': ['Joe Kirkwood Jr.',
#    'Elyse Knox',
#    'William Frawley',
#    'Stanley Clements'],
#   'rating': 6.2},
#  {'title': 'Embers',
#   'year': 2015,
#   'genres': ['Drama', 'Mystery', 'Sci-Fi'],
#   'duration': 85,
#   'directors': ['Claire Carré'],
#   'cast': ['Jason Ritter',
#    'Iva Gocheva',
#    'Greta Fernández',
#    'Tucker Smallwood'],
#   'rating': 5.3},
#  {'title': 'Psychosia',
#   'year': 2019,
#   'genres': ['Drama', 'Mystery'],
#   'duration': 87,
#   'directors': ['Marie Grahtø Sørensen'],
#   'cast': ['Lisa Carlehed',
#    'Vic Carmen Sonne',
#    'Trine Dyrholm',
#    'Bebiane Ivalo Kreutzmann'],
#   'rating': 5.5},
#  {'title': 'Boomerang',
#   'year': 1976,
#   'genres': ['Crime', 'Drama'],
#   'duration': 100,
#   'directors': ['José Giovanni'],
#   'cast': ['Alain Delon', 'Carla Gravina', 'Dora Doll', 'Louis Julien'],
#   'rating': 6.1},
#  {'title': 'The Old Maid',
#   'year': 1972,
#   'genres': ['Comedy'],
#   'duration': 85,
#   'directors': ['Jean-Pierre Blanc'],
#   'cast': ['Annie Girardot', 'Philippe Noiret', 'Marthe Keller', 'Edith Scob'],
#   'rating': 6.7},
#  {'title': 'Love and Troubles',
#   'year': 1958,
#   'genres': ['Comedy', 'Romance'],
#   'duration': 87,
#   'directors': ['Angelo Dorigo'],
#   'cast': ['Marcello Mastroianni',
#    'Richard Basehart',
#    'Valentina Cortese',
#    'Maurizio Arena'],
#   'rating': 6.3},
#  {'title': 'Metehan',
#   'year': 1969,
#   'genres': ['Adventure', 'History'],
#   'duration': 76,
#   'directors': ['Mehmet Aslan'],
#   'cast': ['Yilmaz Köksal', 'Figen Say', 'Nuri Kirgeç', 'Melek Görgün'],
#   'rating': 3.6},
#  {'title': 'My Tiny Universe',
#   'year': 2004,
#   'genres': ['Comedy', 'Drama'],
#   'duration': 92,
#   'directors': ['Lucy Phillips', 'Glen Scantlebury'],
#   'cast': ['Andy Comeau', 'John Heard', 'Debi Mazar', 'Lesley Ann Warren'],
#   'rating': 5.3},
#  {'title': "The Eagle's Brood",
#   'year': 1935,
#   'genres': ['Western'],
#   'duration': 61,
#   'directors': ['Howard Bretherton'],
#   'cast': ['William Boyd',
#    'James Ellison',
#    'William Farnum',
#    "George 'Gabby' Hayes"],
#   'rating': 6.7},
#  {'title': 'Aos Ventos que Virão',
#   'year': 2013,
#   'genres': ['Drama'],
#   'duration': 94,
#   'directors': ['Hermanno Penna'],
#   'cast': ['Emanuelle Araújo',
#    'Hermes Baroli',
#    'Carlos Betão',
#    'Neusa Borges'],
#   'rating': 5.9},
#  {'title': 'Chûshingura',
#   'year': 1910,
#   'genres': ['Action', 'Drama'],
#   'duration': 76,
#   'directors': ['Shôzô Makino'],
#   'cast': ['Chojuro Kataoka',
#    'Matsunosuke Onoe',
#    'Ichinomasa Kataoka',
#    'Kitsuraku Arashi',
#    'Kijaku Ôtani',
#    'Ichitarô Kataoka',
#    'Tomosaburo Otomo',
#    'Yoshio Mizutani',
#    'Shôen Kataoka'],
#   'rating': 6.4},
#  {'title': 'Propios y extraños',
#   'year': 2010,
#   'genres': ['Drama'],
#   'duration': 98,
#   'directors': ['Manolo González'],
#   'cast': ['Enrique Alcides',
#    'Enrique Asenjo',
#    'Elena Ballesteros',
#    'Jorge Bosso'],
#   'rating': 6.2},
#  {'title': 'Limp',
#   'year': 1999,
#   'genres': ['Comedy', 'Romance'],
#   'duration': 90,
#   'directors': ['Duane Lavold'],
#   'cast': ['Sean Allen', 'Jason Bothe', 'Michael Bothe', 'Sean Bowers'],
#   'rating': 7.1},
#  {'title': 'María Morena',
#   'year': 1952,
#   'genres': ['Drama', 'Musical'],
#   'duration': 75,
#   'directors': ['José María Forqué', 'Pedro Lazaga'],
#   'cast': ['Paquita Rico',
#    'José María Mompín',
#    'Rafael Luis Calvo',
#    'Félix de Pomés'],
#   'rating': 4.2},
#  {'title': "The Liars' Club",
#   'year': 1994,
#   'genres': ['Drama', 'Thriller'],
#   'duration': 95,
#   'directors': ['Jeffrey Porter'],
#   'cast': ['Wil Wheaton',
#    'Brian Krause',
#    'Michael Cudlitz',
#    'Soleil Moon Frye'],
#   'rating': 5.5},
#  {'title': 'Rumba',
#   'year': 1935,
#   'genres': ['Drama', 'Music', 'Romance'],
#   'duration': 71,
#   'directors': ['Marion Gering'],
#   'cast': ['George Raft', 'Carole Lombard', 'Lynne Overman', 'Margo'],
#   'rating': 5.7},
#  {'title': 'Little Bruno',
#   'year': 2007,
#   'genres': ['Crime', 'Mystery', 'Thriller'],
#   'duration': 87,
#   'directors': ['Dan Frank'],
#   'cast': ['Ryan Burgess',
#    'Renzo Lewis',
#    'Tim Thunderhorse Halpin',
#    'Larry Laverty'],
#   'rating': 4.7},
#  {'title': "Don't Play the Fool...",
#   'year': 1997,
#   'genres': ['Adventure', 'Comedy', 'Crime'],
#   'duration': 98,
#   'directors': ['Valeri Chikov'],
#   'cast': ['Mikhail Evdokimov',
#    'Valeriy Zolotukhin',
#    'Sergei Agapitov',
#    'Lev Durov'],
#   'rating': 6.6},
#  {'title': 'The Silent Swordsman',
#   'year': 1967,
#   'genres': ['Action', 'Adventure', 'Drama'],
#   'duration': 94,
#   'directors': ['Li Kao'],
#   'cast': ['Yi Chang', 'Jeanette Yu Wei', 'Pei-Pei Shu', 'Chiao Chiao'],
#   'rating': 5.9},
#  {'title': 'Antarctica',
#   'year': 1995,
#   'genres': ['Crime', 'Drama'],
#   'duration': 106,
#   'directors': ['Manuel Huerga'],
#   'cast': ['Ariadna Gil',
#    'Carlos Fuentes',
#    'José Manuel Lorenzo',
#    'Francis Lorenzo'],
#   'rating': 5.9},
#  {'title': 'The Romance of Book and Sword',
#   'year': 1987,
#   'genres': ['Action', 'Drama'],
#   'duration': 180,
#   'directors': ['Ann Hui'],
#   'cast': ['Nuo Ai', 'Shichang Da', 'Jie Deng', 'Cuihua Ding'],
#   'rating': 6.6},
#  {'title': 'Ben Topraktan Bir Canim',
#   'year': 1980,
#   'genres': ['Drama', 'Music'],
#   'duration': 91,
#   'directors': ['Osman F. Seden'],
#   'cast': ['Sümer Tilmaç',
#    'Orhan Gencebay',
#    'Necla Nazir',
#    'Yildirim Gencer',
#    'Semra Türel',
#    'Kadir Savun',
#    'Aliye Rona'],
#   'rating': 5.4},
#  {'title': 'Intruders',
#   'year': 2013,
#   'genres': ['Comedy', 'Mystery', 'Thriller'],
#   'duration': 99,
#   'directors': ['Young-seok Noh'],
#   'cast': ['Tae-kyung Oh'],
#   'rating': 6.5},
#  {'title': 'The Rose',
#   'year': 1979,
#   'genres': ['Drama', 'Music', 'Romance'],
#   'duration': 125,
#   'directors': ['Mark Rydell'],
#   'cast': ['Bette Midler',
#    'Alan Bates',
#    'Frederic Forrest',
#    'Harry Dean Stanton'],
#   'rating': 6.9},
#  {'title': 'Border',
#   'year': 1980,
#   'genres': ['Action', 'War'],
#   'duration': 114,
#   'directors': ['Jamshid Heydari'],
#   'cast': ['Saeed Rad', 'Ahu Kheradmand', 'Davoud Rashidi', 'Ali Sabet'],
#   'rating': 4.8},
#  {'title': 'Gion matsuri',
#   'year': 1968,
#   'genres': ['Drama'],
#   'duration': 168,
#   'directors': ['Daisuke Itô', 'Tetsuya Yamanouchi'],
#   'cast': ['Kinnosuke Nakamura',
#    'Toshirô Mifune',
#    'Shima Iwashita',
#    'Yûnosuke Itô'],
#   'rating': 7.8},
#  {'title': 'Aladdin and His Magic Lamp',
#   'year': 1967,
#   'genres': ['Adventure', 'Fantasy', 'Romance'],
#   'duration': 84,
#   'directors': ['Boris Rytsarev'],
#   'cast': ['Boris Bystrov',
#    'Dodo Chogovadze',
#    'Andrey Fayt',
#    'Otar Koberidze'],
#   'rating': 6.7},
#  {'title': 'The Last Stage',
#   'year': 1948,
#   'genres': ['Drama'],
#   'duration': 105,
#   'directors': ['Wanda Jakubowska'],
#   'cast': ['Barbara Drapinska',
#    'Wanda Bartówna',
#    'Huguette Faget',
#    'Tatyana Guretskaya',
#    'Antonina Gordon-Górecka',
#    'Mariya Vinogradova'],
#   'rating': 7.1},
#  {'title': 'Apatride',
#   'year': 2018,
#   'genres': ['Drama'],
#   'duration': 114,
#   'directors': ['Narjiss Nejjar'],
#   'cast': ['Ghalia Benzaouia',
#    'Avishay Benazra',
#    'Aziz El Fadili',
#    'Nadia Niazi'],
#   'rating': 6.7},
#  {'title': 'Buck Naked Arson',
#   'year': 2001,
#   'genres': ['Comedy', 'Drama'],
#   'duration': 85,
#   'directors': ['Amy Snow'],
#   'cast': ['Rider Strong', 'Azura Skye', 'Christine Lakin', 'William Russ'],
#   'rating': 5.8},
#  {'title': 'En ven i bolignøden',
#   'year': 1965,
#   'genres': ['Comedy'],
#   'duration': 88,
#   'directors': ['Annelise Reenberg'],
#   'cast': ['Birgit Sadolin',
#    'Ebbe Langberg',
#    'Morten Grunwald',
#    'Ove Sprogøe'],
#   'rating': 6.3},
#  {'title': 'Cloud Capped Star',
#   'year': 2013,
#   'genres': ['Biography', 'Drama'],
#   'duration': 154,
#   'directors': ['Kamaleswar Mukherjee'],
#   'cast': ['Saswata Chatterjee',
#    'Ananya Chatterjee',
#    'Abir Chatterjee',
#    'Rahul Banerjee'],
#   'rating': 8.2},
#  {'title': 'Cement',
#   'year': 2000,
#   'genres': ['Crime', 'Drama'],
#   'duration': 97,
#   'directors': ['Adrian Pasdar'],
#   'cast': ['Chris Penn', 'Jeffrey Wright', 'Anthony DeSando', 'Sherilyn Fenn'],
#   'rating': 5.7},
#  {'title': 'Pismak',
#   'year': 1985,
#   'genres': ['Drama'],
#   'duration': 120,
#   'directors': ['Wojciech Has'],
#   'cast': ['Wojciech Wysocki',
#    'Gustaw Holoubek',
#    'Janusz Michalowski',
#    'Jan Peszek'],
#   'rating': 6.5},
#  {'title': 'Super Mouse and the Roborats',
#   'year': 1989,
#   'genres': ['Action', 'Comedy', 'Fantasy'],
#   'duration': 99,
#   'directors': ['Tony Y. Reyes'],
#   'cast': ['Joey de Leon',
#    'Rene Requiestas',
#    'Manilyn Reynes',
#    'Carmina Villaroel'],
#   'rating': 7.2},
#  {'title': 'Troublesome Night 3',
#   'year': 1998,
#   'genres': ['Comedy', 'Horror'],
#   'duration': 99,
#   'directors': ['Herman Yau'],
#   'cast': ['Frankie Chi-Hung Ng',
#    'Louis Koo',
#    'Fennie Yuen',
#    'Simon Lui',
#    'Allen Ting',
#    'Emotion Cheung',
#    'Kar Lok Chin'],
#   'rating': 5.2},
#  {'title': 'Zalacaín el aventurero',
#   'year': 1955,
#   'genres': ['Adventure'],
#   'duration': 95,
#   'directors': ['Juan de Orduña'],
#   'cast': ['Virgilio Teixeira',
#    'Elena Espejo',
#    'Margarita Andrey',
#    'Jesús Tordesillas'],
#   'rating': 6.1},
#  {'title': 'Ruya gibi',
#   'year': 1971,
#   'genres': ['Romance'],
#   'duration': 62,
#   'directors': ['Lütfi Akad'],
#   'cast': ['Engin Tara',
#    'Zeki Müren',
#    'Arzu Okay',
#    'Esen Püsküllü',
#    'Kadir Savun'],
#   'rating': 7.0},
#  {'title': 'Princess Cyd',
#   'year': 2017,
#   'genres': ['Drama', 'Romance'],
#   'duration': 96,
#   'directors': ['Stephen Cone'],
#   'cast': ['Marika Mashburn',
#    'Jessie Pinnick',
#    'Paul Brian Fagen',
#    'Keith Kupferer'],
#   'rating': 6.7},
#  {'title': "Rewi's Last Stand",
#   'year': 1940,
#   'genres': ['Drama'],
#   'duration': 112,
#   'directors': ['Rudall Hayward'],
#   'cast': ['Bernard Britain', 'Phoebe Clarke', 'A.J.C. Fisher', 'John Gordon'],
#   'rating': 5.6},
#  {'title': 'Death Driver',
#   'year': 1977,
#   'genres': ['Drama'],
#   'duration': 93,
#   'directors': ['Jimmy Huston'],
#   'cast': ['Worth Keeter', 'Earl Owensby', 'Mike Allen', 'Mary Ann Hearn'],
#   'rating': 3.3},
#  {'title': 'Doble',
#   'year': 2017,
#   'genres': ['Comedy'],
#   'duration': 100,
#   'directors': ['Felipe Martínez Amador'],
#   'cast': ['Albi De Abreu', 'Salvador del Solar', 'Fran Fiol', 'Majida Issa'],
#   'rating': 6.3},
#  {'title': 'Dragon: The Bruce Lee Story',
#   'year': 1993,
#   'genres': ['Action', 'Biography', 'Drama'],
#   'duration': 120,
#   'directors': ['Rob Cohen'],
#   'cast': ['Jason Scott Lee',
#    'Lauren Holly',
#    'Robert Wagner',
#    'Michael Learned'],
#   'rating': 7.0},
#  {'title': 'Paradoxical',
#   'year': 2017,
#   'genres': ['Drama', 'Sci-Fi'],
#   'duration': 108,
#   'directors': ['Mu-Ming Tsai'],
#   'cast': ['Yu-Chen He', 'Helena Hsu', 'Yu-Lin Yen', 'Wen-Hsueh Lu'],
#   'rating': 6.2},
#  {'title': 'La gallina clueca',
#   'year': 1941,
#   'genres': ['Drama'],
#   'duration': 124,
#   'directors': ['Fernando de Fuentes'],
#   'cast': ['Sara García', 'Domingo Soler', 'Emma Roldán', 'David Silva'],
#   'rating': 6.3},
#  {'title': 'The New Morning of Billy the Kid',
#   'year': 1986,
#   'genres': ['Action', 'Comedy', 'Crime'],
#   'duration': 109,
#   'directors': ['Naoto Yamakawa'],
#   'cast': ['Yoshiki Arizono',
#    'Makoto Ayukawa',
#    'Yoshio Harada',
#    'Toshiyuki Hosokawa'],
#   'rating': 5.5},
#  {'title': 'Poor Europe',
#   'year': 2017,
#   'genres': ['Documentary'],
#   'duration': 52,
#   'directors': ['Mirella Pappalardo'],
#   'cast': ['Matthias Klages'],
#   'rating': 6.8},
#  {'title': 'Moors and Christians',
#   'year': 1987,
#   'genres': ['Comedy'],
#   'duration': 116,
#   'directors': ['Luis García Berlanga'],
#   'cast': ['Luis Escobar',
#    'Fernando Fernán Gómez',
#    'Verónica Forqué',
#    'Agustín González'],
#   'rating': 5.8},
#  {'title': 'Tahytita kai agapi',
#   'year': 1985,
#   'genres': ['Crime', 'Drama'],
#   'duration': 72,
#   'directors': ['Takis Simonetatos'],
#   'cast': ['Giorgos Floros',
#    'Teta Douzou',
#    'Giorgos Polyhroniadis',
#    'Hristos Kaloou',
#    'Marina Roma',
#    'Steve Douzos'],
#   'rating': 5.5},
#  {'title': 'Comeback',
#   'year': 1982,
#   'genres': ['Drama'],
#   'duration': 105,
#   'directors': ['Christel Buschmann'],
#   'cast': ['Eric Burdon',
#    'Julie Carmen',
#    'Michael Cavanaugh',
#    'Jörg Pfennigwerth'],
#   'rating': 6.0},
#  {'title': 'The Bull',
#   'year': 1994,
#   'genres': ['Comedy', 'Drama'],
#   'duration': 105,
#   'directors': ['Carlo Mazzacurati'],
#   'cast': ['Diego Abatantuono',
#    'Roberto Citran',
#    'Marco Messeri',
#    'Marco Paolini'],
#   'rating': 6.7},
#  {'title': 'Date Night',
#   'year': 2010,
#   'genres': ['Comedy', 'Crime', 'Romance'],
#   'duration': 88,
#   'directors': ['Shawn Levy'],
#   'cast': ['Steve Carell', 'Tina Fey', 'Mark Wahlberg', 'Taraji P. Henson'],
#   'rating': 6.3},
#  {'title': 'Yesterday',
#   'year': 2009,
#   'genres': ['Action', 'Comedy', 'Drama'],
#   'duration': 95,
#   'directors': ['Rob Grant'],
#   'cast': ['Graham Wardle', 'P. Lynn Johnson', 'Bill Murdoch', 'Mike Kovac'],
#   'rating': 5.2},
#  {'title': 'Fiesta en el corazón',
#   'year': 1958,
#   'genres': ['Comedy', 'Musical', 'Romance'],
#   'duration': 94,
#   'directors': ['Jaime Salvador'],
#   'cast': ['Antonio Aguilar',
#    'Fernando Casanova',
#    'Sonia Furió',
#    'Verónica Loyo'],
#   'rating': 6.4},
#  {'title': 'Skús ma objat',
#   'year': 1991,
#   'genres': ['Drama'],
#   'duration': 180,
#   'directors': ['Miloslav Luther'],
#   'cast': ['Juraj Chmel',
#    'Václav Vydra',
#    'Veronika Zilková',
#    'Jan Vodnanský',
#    'Juraj Deák',
#    'Andrea Timková'],
#   'rating': 7.0},
#  ...]

# %% [markdown]
# There should be *198610* **dictionaries** in the **list** `movies` and the first entry of `movies` should be a **dictionary** that looks as follows:
#
# ```python
# {'title': 'Lejos de África',
#  'year': 1996,
#  'duration': 115,
#  'genres': ['Drama'],
#  'rating': 6.4,
#  'directors': ['Cecilia Bartolomé'],
#  'cast': ['Alicia Bogo', 'Xabier Elorriaga', 'Isabel Mestres', 'Carlos Cruz']}
# ```
#
# **Warning:** At this stage, it is expected that the function `get_movies` works correctly, and that `movies` is defined as it was in p8. If not, your code will run into issues in p9. So, make sure that this function works properly before you start p9. You can do that by **inserting a new cell** in Jupyter below this cell and verifying that the size of your variable `movies`, and that the first **dictionary** in `movies` are as they should be.

# %% [markdown]
# Now, copy over the functions `plot_dict`, `median` and `year_to_decade` from lab-p9.

# %%
# copy/paste the definitions of plot_dict, median, year_to_decade from lab-p9
# as well as any helper functions used by these functions here
def plot_dict(d, label="Please Label Me!"):
    """plot_dict(d, label) creates a bar plot using the 
    dictionary 'd' and labels the y-axis as 'label'"""
    ax = pandas.Series(d).sort_index().plot.bar(color="black", fontsize=16)
    ax.set_ylabel(label, fontsize=16)
    
def median(items):
    items.sort()
    length = len(items)
    if length % 2 == 1:
        return items[length//2]
    else:
        first_mid = items[length//2 - 1]
        second_mid = items[length//2]
        median = (first_mid + second_mid)/2
        return median
    
def year_to_decade(year):
    if year % 10 == 0:
        decade = str(year - 9) + ' to ' + str(year)
    else:
        year = year - (year%10)
        decade = str(year + 1) + ' to ' + str(year + 10)
    return decade

# %% [markdown]
# In p8, you were provided with a function `find_specific_movies` which functioned as some sort of a 'search bar' for the movies dataset. However, in order to use that function properly, you had to used the `copy` module to pass a *copy* of your list of movies to `find_specific_movies`. Making copies frequently is **not** a good coding practice. For this project, we will provide **a new version** of `find_specific_movies` that does **not** require `copy`. Please go through the following function:

# %%
# modified find_specific_movies (doesn't require using copy module)
def find_specific_movies(movies, keyword):
    """
    find_specific_movies(movies, keyword) takes a list of movie dictionaries 
    and a keyword; it returns a list of movies that contain the keyword
    in either its title, genre, cast or directors.
    """
    movies_with_keyword = []
    for movie in movies:
        if (keyword in movie['title']) or (keyword in movie['genres']) \
            or (keyword in movie['directors']) or (keyword in movie['cast']):
            movies_with_keyword.append(movie)
    return movies_with_keyword

# %% [markdown]
# **Important:** Even when you are not explicitly prompted to do so, using the `find_specific_movies` function cleverly can simplify your code significantly. Keep an eye out for how you can simplify your code by making use of `find_specific_movies`.

# %% [markdown]
# ### Analyzing the Movies data

# %% [markdown]
# **Question 1:** What is the **median** `rating` of the *Harry Potter* movies directed by *David Yates*?
#
# You **must** consider movies which have *Harry Potter* as a substring of the `title` **and** also have *David Yates* as one of the `directors`.

# %%
# compute and store the answer in the variable 'median_hp_rating', then display it
david_yates_movies = []
harry_potter_movies = []

for movie in movies:
    if "Harry Potter" in movie["title"]:
        harry_potter_movies.append(movie)

# harry_potter_movies = find_specific_movies(movies, "Harry Potter")
for movie in harry_potter_movies:
    if "David Yates" in movie["directors"]:
        david_yates_movies.append(movie)

hp_rating = []
for movie in david_yates_movies:
    hp_rating.append(movie['rating'])

median_hp_rating = median(hp_rating)
median_hp_rating
# Out:
# 7.65

# %%
grader.check("q1")
# Out:
# q1 results: All test cases passed!

# %% [markdown]
# **Question 2:** Among all the *Avengers* movies, which ones are the **highest** rated?
#
# Your output **must** be a **list** of **dictionaries**. You **must** consider all movies which have *Avengers* as a substring of their `title`.
#
# **Hint:** You could first find the **highest** `rating` that any *Avengers* movie received, and then find all the *Avengers* movies that received that `rating`.

# %%
# compute and store the answer in the variable 'highest_rated_avengers_movies', then display it
highest_rated_avengers_movies = []
avenger_movies = find_specific_movies(movies, "Avengers")
rating = None
for movie in avenger_movies:
    if rating == None or rating < movie['rating']:
        rating = movie['rating']
        highest_rated_avengers_movies = [movie]
    elif rating == movie['rating']:
        highest_rated_avengers_movies.append(movie)
highest_rated_avengers_movies
# Out:
# [{'title': 'Avengers: Endgame',
#   'year': 2019,
#   'genres': ['Action', 'Adventure', 'Drama'],
#   'duration': 181,
#   'directors': ['Anthony Russo', 'Joe Russo'],
#   'cast': ['Robert Downey Jr.',
#    'Chris Evans',
#    'Mark Ruffalo',
#    'Chris Hemsworth'],
#   'rating': 8.4},
#  {'title': 'Avengers: Infinity War',
#   'year': 2018,
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'duration': 149,
#   'directors': ['Anthony Russo', 'Joe Russo'],
#   'cast': ['Robert Downey Jr.',
#    'Chris Hemsworth',
#    'Mark Ruffalo',
#    'Chris Evans'],
#   'rating': 8.4}]

# %%
grader.check("q2")
# Out:
# q2 results: All test cases passed!

# %% [markdown]
# ### Function 1: `bucketize(movies_list, category)`
#
# This function should take in a **list** of movie **dictionaries** as well as a **category** (i.e. `title`, `year`, `duration`, `genres`, `rating`, `directors`, or `cast`), and *bucketize* the **list** of movie **dictionaries** by this **category**.
#
# For example, the output of `bucketize(movies, 'rating')` should be a **dictionary** so that all the unique values of `rating` of the movies in `movies` are the **keys** and the correspoding **values** would be a **list** of all movie **dictionaries** with that rating (e.g., the value of the key *6.4* should be the **list** of movie dictionaries with `rating` of *6.4*).
#
# The output of `bucketize(movies, 'rating')` should look like this:
#
# ```python
# {6.4: [{'title': 'Lejos de África',
#    'year': 1996,
#    'duration': 115,
#    'genres': ['Drama'],
#    'rating': 6.4,
#    'directors': ['Cecilia Bartolomé'],
#    'cast': ['Alicia Bogo',
#     'Xabier Elorriaga',
#     'Isabel Mestres',
#     'Carlos Cruz']},
#   {'title': 'Kobbari Bondam',
#    'year': 1991,
#    'duration': 149,
#    'genres': ['Comedy'],
#    'rating': 6.4,
#    'directors': ['Raviteja K.'],
#    'cast': ['Rajendra Prasad', 'Nirosha', 'Sudhakar', 'Kota Srinivasa Rao']},
#        ...
#       ],
#  2.1: [{'title': 'Amityville Cult',
#   'year': 2021,
#   'duration': 85,
#   'genres': ['Horror'],
#   'rating': 2.1,
#   'directors': ['Trey Murphy'],
#   'cast': ['James Burleson',
#    'Chance Gibbs',
#    'Micha Marie Stevens',
#    'Tom Young',
#    'Patrick McAlister',
#    'Eric Oberto',
#    'Lara Williams']},
#  {'title': 'Jungle Goddess',
#   'year': 1948,
#   'duration': 62,
#   'genres': ['Action', 'Adventure', 'Crime'],
#   'rating': 2.1,
#   'directors': ['Lewis D. Collins'],
#   'cast': ['George Reeves', 'Wanda McKay', 'Ralph Byrd', 'Armida']},
#        ...
#       ],
#  ...
# }
# ```
#
# Similarly, the output of `bucketize(movies, 'cast')` should be a **dictionary** so that all the unique `cast` members of the movies in `movies` are the **keys** and the correspoding **values** would be a **list** of all movie **dictionaries** with that cast member as one of their `cast` (e.g., the value of the key *Kate Winslet* should be the **list** of movie dictionaries with *Kate Winslet* as one of their `cast` members).
#
# The output of `bucketize(movies, 'cast')` should look like this:
#
# ```python
# {'Alicia Bogo': [{'title': 'Lejos de África',
#    'year': 1996,
#    'duration': 115,
#    'genres': ['Drama'],
#    'rating': 6.4,
#    'directors': ['Cecilia Bartolomé'],
#    'cast': ['Alicia Bogo',
#     'Xabier Elorriaga',
#     'Isabel Mestres',
#     'Carlos Cruz']}],
#  'Xabier Elorriaga': [{'title': 'Lejos de África',
#    'year': 1996,
#    'duration': 115,
#    'genres': ['Drama'],
#    'rating': 6.4,
#    'directors': ['Cecilia Bartolomé'],
#    'cast': ['Alicia Bogo',
#     'Xabier Elorriaga',
#     'Isabel Mestres',
#     'Carlos Cruz']},
#   {'title': 'Companys, procés a Catalunya',
#    'year': 1979,
#    'duration': 125,
#    'genres': ['Biography', 'Drama', 'History'],
#    'rating': 6.2,
#    'directors': ['Josep Maria Forn'],
#    'cast': ['Luis Iriondo',
#     'Marta Angelat',
#     'Montserrat Carulla',
#     'Xabier Elorriaga']},
#      ...
#     ],
#  ...
# }
# ```
#
# **Hints:** Note that depending on whether or not the `category` represents a **list** or not, your function will have to behave differently. In p8, you created a function `bucketize_by_genre` that *bucketized* the list of movies by their genre. Take a moment to find that function; it will help you here. Also, take a moment to look at the buckets you made in lab-p9.

# %%
# replace the ... with your code to finish the definition of bucketize

def bucketize(movie_list, category):
    buckets = {}
    for movie in movie_list:
        category_value = movie[category] #TODO: Access the category value from a movie
        if type(category_value) == list:
            for key in category_value:
                if key not in buckets:
                    buckets[key] = []
                buckets[key].append(movie)
        else:
            if category_value not in buckets:
                buckets[category_value] = []
            buckets[category_value].append(movie)
    return buckets

# %% [markdown]
# **Important:** Just like `get_movies`, `bucketize` is quite a time-consuming function to run. Hence, you do **not** want to call `bucketize` on the same list of movies and category **more than once**. Throughout the project, we will frequently use bucketized lists of movies organized by their `cast`, `directors`, `genre`, and `year`. Rather than calling `bucketize` several times, we will store the bucketized lists in following variables:

# %%
# define buckets for categories mentioned below, but do NOT display any of them

cast_buckets = bucketize(movies, "cast")
# bucketize the full list of movies by their directors.
director_buckets = bucketize(movies, "directors")
# bucketize the full list of movies by their genre.
genre_buckets = bucketize(movies, "genres")
# bucketize the full list of movies by their year.
year_buckets = bucketize(movies, "year")

# %% [markdown]
# Even when you are not explicitly prompted to do so, using these data structures and the `bucketize` function cleverly can simplify your code significantly. Keep an eye out for how you can simplify your code by making use of these data structures and the `bucketize` function.

# %% [markdown]
# **Question 3:** List the movies that *Viola Davis* was `cast` in?
#
# Your output **must** be a **list** of **dictionaries**. You **must** answer this question by accessing the **value** of the correct **key** from the correct **bucket** defined in the previous cell.

# %%
# compute and store the answer in the variable 'viola_movies', then display it
viola_movies = cast_buckets["Viola Davis"]
viola_movies
# Out:
# [{'title': 'Eat Pray Love',
#   'year': 2010,
#   'genres': ['Biography', 'Drama', 'Romance'],
#   'duration': 133,
#   'directors': ['Ryan Murphy'],
#   'cast': ['Julia Roberts', 'Javier Bardem', 'Richard Jenkins', 'Viola Davis'],
#   'rating': 5.8},
#  {'title': "Won't Back Down",
#   'year': 2012,
#   'genres': ['Drama'],
#   'duration': 121,
#   'directors': ['Daniel Barnz'],
#   'cast': ['Viola Davis', 'Maggie Gyllenhaal', 'Holly Hunter', 'Oscar Isaac'],
#   'rating': 6.4},
#  {'title': 'Get on Up',
#   'year': 2014,
#   'genres': ['Biography', 'Drama', 'Music'],
#   'duration': 139,
#   'directors': ['Tate Taylor'],
#   'cast': ['Chadwick Boseman', 'Nelsan Ellis', 'Dan Aykroyd', 'Viola Davis'],
#   'rating': 6.9},
#  {'title': 'The Disappearance of Eleanor Rigby: Them',
#   'year': 2014,
#   'genres': ['Drama', 'Romance'],
#   'duration': 123,
#   'directors': ['Ned Benson'],
#   'cast': ['James McAvoy', 'Jessica Chastain', 'Viola Davis', 'Bill Hader'],
#   'rating': 6.3},
#  {'title': 'Suicide Squad',
#   'year': 2016,
#   'genres': ['Action', 'Adventure', 'Fantasy'],
#   'duration': 123,
#   'directors': ['David Ayer'],
#   'cast': ['Will Smith', 'Jared Leto', 'Margot Robbie', 'Viola Davis'],
#   'rating': 5.9},
#  {'title': 'Blackhat',
#   'year': 2015,
#   'genres': ['Action', 'Crime', 'Thriller'],
#   'duration': 133,
#   'directors': ['Michael Mann'],
#   'cast': ['Chris Hemsworth', 'Viola Davis', 'Leehom Wang'],
#   'rating': 5.4},
#  {'title': 'Widows',
#   'year': 2018,
#   'genres': ['Crime', 'Drama', 'Thriller'],
#   'duration': 129,
#   'directors': ['Steve McQueen'],
#   'cast': ['Viola Davis', 'Michelle Rodriguez', 'Elizabeth Debicki'],
#   'rating': 6.8},
#  {'title': 'The Woman King',
#   'year': 2022,
#   'genres': ['Action', 'Drama', 'History'],
#   'duration': 135,
#   'directors': ['Gina Prince-Bythewood'],
#   'cast': ['Viola Davis', 'Thuso Mbedu', 'Sheila Atim'],
#   'rating': 6.8},
#  {'title': 'Black Theater Today: 2005',
#   'year': 2005,
#   'genres': ['Documentary', 'Family'],
#   'duration': 60,
#   'directors': ['Thea Marie Perkins'],
#   'cast': ['Virginia Capers', 'Keith David', 'Viola Davis', 'Richard Gant'],
#   'rating': 6.1},
#  {'title': "Ma Rainey's Black Bottom",
#   'year': 2020,
#   'genres': ['Drama', 'Music'],
#   'duration': 94,
#   'directors': ['George C. Wolfe'],
#   'cast': ['Viola Davis',
#    'Chadwick Boseman',
#    'Glynn Turman',
#    'Colman Domingo'],
#   'rating': 6.9},
#  {'title': 'Troop Zero',
#   'year': 2019,
#   'genres': ['Comedy', 'Drama', 'Family'],
#   'duration': 94,
#   'directors': ['Bert', 'Bertie'],
#   'cast': ['Mckenna Grace', 'Viola Davis', 'Jim Gaffigan', 'Allison Janney'],
#   'rating': 6.8},
#  {'title': 'The Architect',
#   'year': 2006,
#   'genres': ['Crime', 'Drama', 'Romance'],
#   'duration': 82,
#   'directors': ['Matt Tauber'],
#   'cast': ['Anthony LaPaglia',
#    'Viola Davis',
#    'Isabella Rossellini',
#    'Hayden Panettiere'],
#   'rating': 5.5},
#  {'title': 'Nights in Rodanthe',
#   'year': 2008,
#   'genres': ['Drama', 'Romance'],
#   'duration': 97,
#   'directors': ['George C. Wolfe'],
#   'cast': ['Diane Lane', 'Richard Gere', 'Christopher Meloni', 'Viola Davis'],
#   'rating': 6.0},
#  {'title': 'Custody',
#   'year': 2016,
#   'genres': ['Drama'],
#   'duration': 104,
#   'directors': ['James Lapine'],
#   'cast': ['Viola Davis',
#    'Hayden Panettiere',
#    'Catalina Sandino Moreno',
#    'Tony Shalhoub'],
#   'rating': 6.5},
#  {'title': 'The Unforgivable',
#   'year': 2021,
#   'genres': ['Crime', 'Drama'],
#   'duration': 112,
#   'directors': ['Nora Fingscheidt'],
#   'cast': ['Sandra Bullock',
#    'Viola Davis',
#    "Vincent D'Onofrio",
#    'Jon Bernthal'],
#   'rating': 7.1},
#  {'title': 'Prisoners',
#   'year': 2013,
#   'genres': ['Crime', 'Drama', 'Mystery'],
#   'duration': 153,
#   'directors': ['Denis Villeneuve'],
#   'cast': ['Hugh Jackman', 'Jake Gyllenhaal', 'Viola Davis', 'Melissa Leo'],
#   'rating': 8.1},
#  {'title': 'The Help',
#   'year': 2011,
#   'genres': ['Drama'],
#   'duration': 146,
#   'directors': ['Tate Taylor'],
#   'cast': ['Viola Davis',
#    'Emma Stone',
#    'Octavia Spencer',
#    'Bryce Dallas Howard'],
#   'rating': 8.1},
#  {'title': 'Beautiful Creatures',
#   'year': 2013,
#   'genres': ['Drama', 'Fantasy', 'Romance'],
#   'duration': 124,
#   'directors': ['Richard LaGravenese'],
#   'cast': ['Alice Englert',
#    'Viola Davis',
#    'Emma Thompson',
#    'Alden Ehrenreich'],
#   'rating': 6.1},
#  {'title': 'Lila & Eve',
#   'year': 2015,
#   'genres': ['Crime', 'Drama', 'Thriller'],
#   'duration': 94,
#   'directors': ['Charles Stone III'],
#   'cast': ['Viola Davis', 'Aml Ameen', 'Ron Caldwell', 'Yolonda Ross'],
#   'rating': 5.8},
#  {'title': 'The Disappearance of Eleanor Rigby: Her',
#   'year': 2013,
#   'genres': ['Drama', 'Romance'],
#   'duration': 100,
#   'directors': ['Ned Benson'],
#   'cast': ['Jessica Chastain', 'James McAvoy', 'Nina Arianda', 'Viola Davis'],
#   'rating': 6.9},
#  {'title': 'The Disappearance of Eleanor Rigby: Him',
#   'year': 2013,
#   'genres': ['Drama', 'Romance'],
#   'duration': 89,
#   'directors': ['Ned Benson'],
#   'cast': ['James McAvoy', 'Jessica Chastain', 'Nina Arianda', 'Viola Davis'],
#   'rating': 6.8},
#  {'title': 'Solaris',
#   'year': 2002,
#   'genres': ['Drama', 'Mystery', 'Romance'],
#   'duration': 99,
#   'directors': ['Steven Soderbergh'],
#   'cast': ['George Clooney',
#    'Natascha McElhone',
#    'Ulrich Tukur',
#    'Viola Davis'],
#   'rating': 6.2},
#  {'title': 'Beyond Babyland',
#   'year': 2010,
#   'genres': ['Documentary'],
#   'duration': 56,
#   'directors': ['David Appleby', 'Craig Leake'],
#   'cast': ['Viola Davis'],
#   'rating': 4.9},
#  {'title': 'Doubt',
#   'year': 2008,
#   'genres': ['Drama', 'Mystery'],
#   'duration': 104,
#   'directors': ['John Patrick Shanley'],
#   'cast': ['Meryl Streep',
#    'Philip Seymour Hoffman',
#    'Amy Adams',
#    'Viola Davis'],
#   'rating': 7.5}]

# %%
grader.check("q3")
# Out:
# q3 results: All test cases passed!

# %% [markdown]
# **Question 4:** **Plot** the **number** of movies in each *genre* as a **bar graph**.
#
# You **must** first compute a **dictionary** which maps each **genre** to the **number** of movies in that **genre**. Then, you may use `plot_dict` to plot the data in that dictionary.
#
# **Important Warning:** `p9_test.py` can check that the **dictionary** has the correct key/value pairs, but it **cannot** check if your plot appears on the screen, or whether the axes are correctly labelled. Your plots will be **manually graded**, and you will **lose points** if your plot is not visible, or if it is not properly labelled.
#
# Your plot should look like this:
# <div><img src="attachment:num_genres.PNG" width="400"/></div>

# %%
# first compute and store the dictionary in the variable 'genre_num', then display it
genre_num = {genre: len(genre_buckets[genre]) for genre in genre_buckets}
genre_num
# Out:
# {'Drama': 106162,
#  'Horror': 16606,
#  'Sport': 2157,
#  'Family': 8993,
#  'Comedy': 57265,
#  'Adventure': 14666,
#  'Thriller': 20144,
#  'Crime': 20655,
#  'Action': 23495,
#  'Fantasy': 7038,
#  'History': 5183,
#  'Romance': 26780,
#  'Biography': 4946,
#  'Sci-Fi': 5677,
#  'Mystery': 9397,
#  'Documentary': 10038,
#  'Western': 4595,
#  'Musical': 5198,
#  'Animation': 3780,
#  'Music': 4002,
#  'War': 4873,
#  'News': 152,
#  'Film-Noir': 818,
#  'Short': 12,
#  'Reality-TV': 17,
#  'Game-Show': 1,
#  'Talk-Show': 1}

# %%
# now plot 'genre_num' with the y-axis labelled 'number of movies'

plot_dict(genre_num, label="number of movies")

# %%
grader.check("q4")
# Out:
# q4 results: All test cases passed!

# %% [markdown]
# **Food for thought:** Can you tell what the most popular **genres** are from the plot? Do you see anything surprising here?

# %%
# this is an entirely OPTIONAL exercise
# you may leave your thoughts here as a comment if you wish to

# %% [markdown]
# **Question 5:** **Plot** the **number** of movies **directed** by *Akira Kurosawa* in each *genre* as a **bar graph**.
#
# You **must** only include those `genres` in which *Akira Kurosawa* has directed **at least** one movie, in your plot.
#
# You **must** first compute a **dictionary** which maps each **genre** to the **number** of movies in that **genre** directed by *Akira Kurosawa*. Then, you may use `plot_dict` to plot the data in that dictionary.
#
# **Important Warning:** `p9_test.py` can check that the **dictionary** has the correct key/value pairs, but it **cannot** check if your plot appears on the screen, or whether the axes are correctly labelled. Your plots will be **manually graded**, and you will **lose points** if your plot is not visible, or if it is not properly labelled.
#
# Your plot should look like this:
# <div><img src="attachment:kurosawa_films.PNG" width="400"/></div>

# %%
# first compute and store the dictionary in the variable 'kurosawa_genres', then display it
akira_movies = director_buckets["Akira Kurosawa"]
kurosawa = bucketize(akira_movies, "genres") # key genre, value list of movies
kurosawa_genres = {genre: len(kurosawa[genre]) for genre in kurosawa}
kurosawa_genres
# Out:
# {'Action': 8,
#  'Drama': 32,
#  'War': 2,
#  'Thriller': 4,
#  'Adventure': 5,
#  'Fantasy': 1,
#  'Biography': 1,
#  'History': 3,
#  'Crime': 5,
#  'Mystery': 2,
#  'Film-Noir': 1,
#  'Romance': 3}

# %%
# now plot 'kurosawa_genres' with the y-axis labelled 'number of movies'
plot_dict(kurosawa_genres, label="number of movies")

# %%
grader.check("q5")
# Out:
# q5 results: All test cases passed!

# %% [markdown]
# **Food for thought:** Can you similarly **plot** the **number** of films directed by your favorite director or starring your favorite cast member in each **genre**?

# %%
# this is an entirely OPTIONAL exercise
# you may leave your thoughts here as a comment if you wish to

# %% [markdown]
# **Question 6:** **Plot** the **number** of movies released in each *decade* as a **bar graph**.
#
# You **must** first compute a **dictionary** which maps each **decade** to the **number** of movies in released in that **decade**. This dictionary should look like this:
#
# ```python
# {'1991 to 2000': 18496,
#  '2021 to 2030': 9173,
#  '1961 to 1970': 14216,
#  '1951 to 1960': 10981,
#  '2011 to 2020': 59249,
#  '2001 to 2010': 33658,
#  '1941 to 1950': 7807,
#  '1971 to 1980': 15556,
#  '1981 to 1990': 17181,
#  '1921 to 1930': 3014,
#  '1931 to 1940': 8201,
#  '1911 to 1920': 1068,
#  '1901 to 1910': 9,
#  '1891 to 1900': 1}
# ```
#
# Then, you may use `plot_dict` to plot the data in that dictionary.
#
# **Important Warning:** `p9_test.py` can check that the **dictionary** has the correct key/value pairs, but it **cannot** check if your plot appears on the screen, or whether the axes are correctly labelled. Your plots will be **manually graded**, and you will **lose points** if your plot is not visible, or if it is not properly labelled.
#
# Your plot should look like this:
# <div><img src="attachment:num_decade.PNG" width="400"/></div>

# %%
year_buckets[1996]
# Out:
# [{'title': 'Lejos de África',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 115,
#   'directors': ['Cecilia Bartolomé'],
#   'cast': ['Alicia Bogo', 'Xabier Elorriaga', 'Isabel Mestres', 'Carlos Cruz'],
#   'rating': 6.4},
#  {'title': 'Normal Life',
#   'year': 1996,
#   'genres': ['Crime', 'Drama'],
#   'duration': 101,
#   'directors': ['John McNaughton'],
#   'cast': ['Ashley Judd', 'Luke Perry', 'Bruce A. Young', 'Jim True-Frost'],
#   'rating': 6.2},
#  {'title': 'Doraemon: Nobita and the Galaxy Super-express',
#   'year': 1996,
#   'genres': ['Action', 'Adventure', 'Animation'],
#   'duration': 97,
#   'directors': ['Tsutomu Shibayama'],
#   'cast': ['Nobuyo Ôyama',
#    'Noriko Ohara',
#    'Michiko Nomura',
#    'Kaneta Kimotsuki',
#    'Kazuya Tatekabe'],
#   'rating': 6.9},
#  {'title': 'Electra',
#   'year': 1996,
#   'genres': ['Action', 'Sci-Fi', 'Thriller'],
#   'duration': 87,
#   'directors': ['Julian Grant'],
#   'cast': ['Shannon Tweed', 'Joe Tabb', 'Sten Eirik', 'Katie Griffin'],
#   'rating': 3.4},
#  {'title': 'A Trança Feiticeira',
#   'year': 1996,
#   'genres': ['History', 'Romance'],
#   'duration': 105,
#   'directors': ['Yuanyuan Cai'],
#   'cast': ['Roberto Candeias',
#    'Ricardo Carriço',
#    'Manuel Cavaco',
#    'Filomena Gonçalves',
#    'Jing Ning'],
#   'rating': 7.4},
#  {'title': 'The Square Circle',
#   'year': 1996,
#   'genres': ['Drama', 'Music', 'Romance'],
#   'duration': 107,
#   'directors': ['Amol Palekar'],
#   'cast': ['Nirmal Pandey', 'Sonali Kulkarni', 'Faiyyaz', 'Rekha Sahay'],
#   'rating': 7.4},
#  {'title': 'Viva Erotica',
#   'year': 1996,
#   'genres': ['Comedy', 'Drama'],
#   'duration': 99,
#   'directors': ['Tung-Shing Yee', 'Chi-Leung Law'],
#   'cast': ['Leslie Cheung', 'Karen Mok', 'Shu Qi', 'Ching Wan Lau'],
#   'rating': 6.7},
#  {'title': 'The Coney Island of Lawrence Ferlinghetti',
#   'year': 1996,
#   'genres': ['Documentary'],
#   'duration': 60,
#   'directors': ['Christopher Felver'],
#   'cast': ['Gregory Corso',
#    'Allen Ginsberg',
#    'Kenneth Rexroth',
#    'Gary Snyder'],
#   'rating': 7.4},
#  {'title': 'Alexander',
#   'year': 1996,
#   'genres': ['Action'],
#   'duration': 125,
#   'directors': ['K.R.'],
#   'cast': ['Prakash Raj',
#    'Nizhalgal Ravi',
#    'Sangeetha',
#    'Srihari',
#    'Vadivukkarasi',
#    'Vijayakanth'],
#   'rating': 6.5},
#  {'title': 'PremGranth',
#   'year': 1996,
#   'genres': ['Action', 'Drama', 'Musical'],
#   'duration': 156,
#   'directors': ['Rajeev Kapoor'],
#   'cast': ['Shammi Kapoor', 'Rishi Kapoor', 'Madhuri Dixit', 'Anupam Kher'],
#   'rating': 5.0},
#  {'title': 'Snowriders',
#   'year': 1996,
#   'genres': ['Documentary', 'Sport'],
#   'duration': 96,
#   'directors': ['Kurt Miller', 'Peter Speek'],
#   'cast': ['Warren Miller', 'Suzanne Sawyer', 'Paul Miller'],
#   'rating': 7.7},
#  {'title': 'Night of the Flood',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 91,
#   'directors': ['Bernar Hébert'],
#   'cast': ['Geneviève Rochette',
#    'Julie McClemens',
#    'Jacques Godin',
#    'Estelle Clareton'],
#   'rating': 7.3},
#  {'title': 'A három testör Afrikában',
#   'year': 1996,
#   'genres': ['Adventure', 'Comedy', 'Romance'],
#   'duration': 84,
#   'directors': ['István Bujtor'],
#   'cast': ['Gábor Koncz', 'Zoltán Rátóti', 'Béla Stenczer', 'Ferenc Kállai'],
#   'rating': 5.2},
#  {'title': "Reggie's Prayer",
#   'year': 1996,
#   'genres': ['Drama', 'Sport'],
#   'duration': 94,
#   'directors': ['Paul McKellips'],
#   'cast': ['Cylk Cozart', 'Allan Creel', 'Emilio Delgado', 'Brett Favre'],
#   'rating': 4.5},
#  {'title': 'God of Gamblers 3: The Early Stage',
#   'year': 1996,
#   'genres': ['Action', 'Drama'],
#   'duration': 110,
#   'directors': ['Jing Wong'],
#   'cast': ['Leon Lai', 'Anita Yuen', 'Jordan Chan', 'Gigi Leung'],
#   'rating': 6.2},
#  {'title': 'Jack',
#   'year': 1996,
#   'genres': ['Comedy', 'Drama', 'Fantasy'],
#   'duration': 113,
#   'directors': ['Francis Ford Coppola'],
#   'cast': ['Robin Williams', 'Diane Lane', 'Brian Kerwin', 'Jennifer Lopez'],
#   'rating': 5.8},
#  {'title': 'Senrei',
#   'year': 1996,
#   'genres': ['Crime', 'Drama', 'Horror'],
#   'duration': 93,
#   'directors': ['Kenichi Yoshihara'],
#   'cast': ['Rie Imamura', 'Lisa Akikawa', 'Mie Yoshida', 'Chihiro Tago'],
#   'rating': 5.4},
#  {'title': 'The Undercover Kid',
#   'year': 1996,
#   'genres': ['Family'],
#   'duration': 80,
#   'directors': ['Linda Shayne'],
#   'cast': ['Bradley Pierce',
#    'Melora Hardin',
#    'Nicolas Surovy',
#    'Susan Dolan Stevens'],
#   'rating': 4.3},
#  {'title': 'Sacred Silence',
#   'year': 1996,
#   'genres': ['Crime', 'Drama'],
#   'duration': 114,
#   'directors': ['Antonio Capuano'],
#   'cast': ['Fabrizio Bentivoglio',
#    'Emanuele Gargiulo',
#    'Tonino Taiuti',
#    'Rosaria De Cicco'],
#   'rating': 6.3},
#  {'title': 'Birds in Neutral',
#   'year': 1996,
#   'genres': ['Comedy', 'Romance'],
#   'duration': 96,
#   'directors': ['Galit Eshkol', 'Eyal Shiray'],
#   'cast': ['Dana Berger', 'Tsaki Bochlin', 'Maor Cohen', 'Eli Habakouk'],
#   'rating': 5.1},
#  {'title': 'In a Strange City',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 107,
#   'directors': ['Chi Yin'],
#   'cast': ['Kuei-Mei Yang', 'Winston Chao', 'Angela Chang', 'Kuo-Chu Chang'],
#   'rating': 6.0},
#  {'title': "That's Cunning! Shijo saidai no sakusen",
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 99,
#   'directors': ['Hiroshi Sugawara'],
#   'cast': ['Masaaki Takarai',
#    'Tatsuya Yamaguchi',
#    'Namie Amuro',
#    'Sadatora Araki',
#    'Tarô Yamamoto'],
#   'rating': 6.5},
#  {'title': 'Le violon de Rothschild',
#   'year': 1996,
#   'genres': ['Biography', 'Music'],
#   'duration': 101,
#   'directors': ['Edgardo Cozarinsky'],
#   'cast': ['Sergey Makovetskiy',
#    'Dainius Kazlauskas',
#    'Tõnu Kark',
#    'Tarmo Männard'],
#   'rating': 6.8},
#  {'title': 'Albergo Roma',
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 84,
#   'directors': ['Ugo Chiti'],
#   'cast': ['Alessandro Benvenuti',
#    'Claudio Bisio',
#    'Debora Caprioglio',
#    'Tchéky Karyo'],
#   'rating': 6.1},
#  {'title': 'Vol-au-vent',
#   'year': 1996,
#   'genres': ['Comedy', 'Romance'],
#   'duration': 88,
#   'directors': ['John McKenzie'],
#   'cast': ['Brian Mitchell',
#    'Dennis Waterman',
#    'Julia McKenzie',
#    'Lisa Coleman',
#    'Joanne Engelsman',
#    'Jo Wyatt',
#    'John Hug'],
#   'rating': 6.3},
#  {'title': 'Rockabilly Vampire',
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 90,
#   'directors': ['Lee Bennett Sobel'],
#   'cast': ['Stephen Blackehart',
#    'Paul Stevenson',
#    'Margaret Lancaster',
#    'Valentine Miele'],
#   'rating': 3.9},
#  {'title': 'Stormy Nights',
#   'year': 1996,
#   'genres': ['Drama', 'Thriller'],
#   'duration': 87,
#   'directors': ['Alberto Vidaurri'],
#   'cast': ['Shannon Tweed',
#    'Brett Baxter Clark',
#    'Tracy Spaulding',
#    'Myke Michaels'],
#   'rating': 3.8},
#  {'title': 'The World Against Me',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 105,
#   'directors': ['Beda Docampo Feijóo'],
#   'cast': ['Mirta Busnelli',
#    'Daniel Fanego',
#    'Jorge Marrale',
#    'Carolina Papaleo'],
#   'rating': 4.9},
#  {'title': 'Out of the Present',
#   'year': 1996,
#   'genres': ['Documentary'],
#   'duration': 96,
#   'directors': ['Andrei Ujica'],
#   'cast': ['Anatoli Arzebarski',
#    'Sergei Krikalev',
#    'Helen Sharman',
#    'Aleksandr Volkov'],
#   'rating': 7.1},
#  {'title': 'Four Tales of Two Cities',
#   'year': 1996,
#   'genres': ['Comedy', 'Drama'],
#   'duration': 93,
#   'directors': ['Illeana Douglas',
#    'Griffin Dunne',
#    'Adrienne Shelly',
#    'Fisher Stevens'],
#   'cast': ['Patrick Breen',
#    'Kevin Breznahan',
#    'Kate Capshaw',
#    'Chris Chavkin'],
#   'rating': 5.6},
#  {'title': 'Terminal Justice',
#   'year': 1996,
#   'genres': ['Action', 'Sci-Fi', 'Thriller'],
#   'duration': 94,
#   'directors': ['Rick King'],
#   'cast': ['Lorenzo Lamas', 'Chris Sarandon', 'Peter Coyote', 'Kari Wuhrer'],
#   'rating': 4.4},
#  {'title': 'Unforgettable',
#   'year': 1996,
#   'genres': ['Drama', 'Mystery', 'Sci-Fi'],
#   'duration': 117,
#   'directors': ['John Dahl'],
#   'cast': ['Ray Liotta',
#    'Linda Fiorentino',
#    'Peter Coyote',
#    'Christopher McDonald'],
#   'rating': 6.0},
#  {'title': 'Wild Side',
#   'year': 1996,
#   'genres': ['Action', 'Thriller'],
#   'duration': 96,
#   'directors': ['Donald Cammell'],
#   'cast': ['Christopher Walken', 'Joan Chen', 'Steven Bauer', 'Anne Heche'],
#   'rating': 5.6},
#  {'title': 'Goodbye, Father',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 85,
#   'directors': ['Luís Filipe Rocha'],
#   'cast': ['Afonso Pimentel',
#    'João Lagarto',
#    'Laura Soveral',
#    'Natália Luiza'],
#   'rating': 7.0},
#  {'title': 'Mars Attacks!',
#   'year': 1996,
#   'genres': ['Comedy', 'Sci-Fi'],
#   'duration': 106,
#   'directors': ['Tim Burton'],
#   'cast': ['Jack Nicholson',
#    'Pierce Brosnan',
#    'Sarah Jessica Parker',
#    'Annette Bening'],
#   'rating': 6.4},
#  {'title': 'A Step Toward Tomorrow',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 93,
#   'directors': ['Deborah Reinisch'],
#   'cast': ['Judith Light', 'Tom Irwin', 'Christopher Reeve', 'Alfre Woodard'],
#   'rating': 6.8},
#  {'title': 'Overkill',
#   'year': 1996,
#   'genres': ['Action', 'Thriller'],
#   'duration': 88,
#   'directors': ['Dean Raphael Ferrandini'],
#   'cast': ['Aaron Norris',
#    'Michael Nouri',
#    'Kenneth Moskow',
#    'Pamela Dickerson'],
#   'rating': 4.4},
#  {'title': 'Beautiful Thing',
#   'year': 1996,
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'duration': 90,
#   'directors': ['Hettie Macdonald'],
#   'cast': ['Glen Berry', 'Linda Henry', 'Scott Neal', 'Tameka Empson'],
#   'rating': 7.6},
#  {'title': "The Rich Man's Wife",
#   'year': 1996,
#   'genres': ['Thriller'],
#   'duration': 95,
#   'directors': ['Amy Holden Jones'],
#   'cast': ['Halle Berry',
#    'Christopher McDonald',
#    'Peter Greene',
#    'Clive Owen'],
#   'rating': 5.2},
#  {'title': 'Leonardo Pareja',
#   'year': 1996,
#   'genres': ['Documentary'],
#   'duration': 117,
#   'directors': ['Regis Faria'],
#   'cast': ['Milhem Cortaz', 'Reginaldo Faria', 'Otávio Müller'],
#   'rating': 8.2},
#  {'title': 'Matías, juez de línea',
#   'year': 1996,
#   'genres': ['Comedy', 'Sport'],
#   'duration': 94,
#   'directors': ['Santiago Aguilar', 'Luis Guridi'],
#   'cast': ['Carlos de Gabriel',
#    'Ramón Barea',
#    'Alicia Sánchez',
#    'Francisco Algora'],
#   'rating': 4.9},
#  {'title': 'Adrenalin: Fear the Rush',
#   'year': 1996,
#   'genres': ['Action', 'Sci-Fi', 'Thriller'],
#   'duration': 77,
#   'directors': ['Albert Pyun'],
#   'cast': ['Christopher Lambert',
#    'Natasha Henstridge',
#    'Norbert Weisser',
#    'Elizabeth Barondes'],
#   'rating': 3.8},
#  {'title': 'Whipping Boy',
#   'year': 1996,
#   'genres': ['Crime', 'Drama', 'Thriller'],
#   'duration': 96,
#   'directors': ['Di Drew'],
#   'cast': ['Sigrid Thornton',
#    'Temuera Morrison',
#    'Tammy Macintosh',
#    'Treffyn Koreshoff'],
#   'rating': 6.2},
#  {'title': 'Tsuki to kyabetsu',
#   'year': 1996,
#   'genres': ['Drama', 'Romance'],
#   'duration': 100,
#   'directors': ['Tetsuo Shinohara'],
#   'cast': ['Masayoshi Yamazaki', 'Masumi Sanada', 'Shingo Tsurumi', 'Duncan'],
#   'rating': 6.0},
#  {'title': 'The Spitfire Grill',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 117,
#   'directors': ['Lee David Zlotoff'],
#   'cast': ['Alison Elliott',
#    'Ellen Burstyn',
#    'Marcia Gay Harden',
#    'Will Patton'],
#   'rating': 7.0},
#  {'title': 'The Imp',
#   'year': 1996,
#   'genres': ['Horror'],
#   'duration': 96,
#   'directors': ['Kai-Ming Lai'],
#   'cast': ['Diana Pang', 'Mark Cheng', 'Emiko Ishizuka', 'Dick Lau'],
#   'rating': 4.4},
#  {'title': 'Fargo',
#   'year': 1996,
#   'genres': ['Crime', 'Thriller'],
#   'duration': 98,
#   'directors': ['Joel Coen', 'Ethan Coen'],
#   'cast': ['William H. Macy',
#    'Frances McDormand',
#    'Steve Buscemi',
#    'Peter Stormare'],
#   'rating': 8.1},
#  {'title': 'Joyeux Calvaire',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 89,
#   'directors': ['Denys Arcand'],
#   'cast': ['Lorne Brass', 'Gaston Lepage', 'Benoît Brière', 'André Melançon'],
#   'rating': 7.0},
#  {'title': 'Sotto Voce',
#   'year': 1996,
#   'genres': ['Drama', 'Mystery'],
#   'duration': 88,
#   'directors': ['Mario Levin'],
#   'cast': ['Lito Cruz',
#    'Norma Pons',
#    'Martín Adjemián',
#    'Daniel Martinez Castro'],
#   'rating': 7.2},
#  {'title': 'President i ego zhenshchina',
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 91,
#   'directors': ['Elena Rayskaya'],
#   'cast': ['Elena Safonova', 'Boris Tokarev', 'Michael Gor', 'Yana Rayskaya'],
#   'rating': 5.2},
#  {'title': 'Journey to Wisdom',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 127,
#   'directors': ['Jayaraaj'],
#   'cast': ['Master Kumar',
#    'Vijayaraghavan',
#    'Mini Nair',
#    'Unnikrishnan Nampoothiri'],
#   'rating': 7.8},
#  {'title': 'Kratka',
#   'year': 1996,
#   'genres': ['Comedy', 'Family'],
#   'duration': 50,
#   'directors': ['Pawel Lozinski'],
#   'cast': ['Jerzy Kamas',
#    'Michal Michalak',
#    'Jadwiga Bukowska',
#    'Jolanta Czaplinska'],
#   'rating': 6.8},
#  {'title': "Devil's Island",
#   'year': 1996,
#   'genres': ['Comedy', 'Drama'],
#   'duration': 99,
#   'directors': ['Friðrik Þór Friðriksson'],
#   'cast': ['Baltasar Kormákur',
#    'Gísli Halldórsson',
#    'Sigurveig Jónsdóttir',
#    'Halldóra Geirharðsdóttir'],
#   'rating': 7.1},
#  {'title': 'Dragon from Shaolin',
#   'year': 1996,
#   'genres': ['Action', 'Adventure', 'Comedy'],
#   'duration': 89,
#   'directors': ['Sai Hung Fung'],
#   'cast': ['Biao Yuen', 'Vivian Hsu', 'Kara Wai', 'Ashton Chen'],
#   'rating': 5.4},
#  {'title': 'No One Could Protect Her',
#   'year': 1996,
#   'genres': ['Biography', 'Crime', 'Drama'],
#   'duration': 97,
#   'directors': ['Larry Shaw'],
#   'cast': ['Joanna Kerns', 'Tony Denison', 'Peter MacNeill', 'Lori Hallier'],
#   'rating': 5.6},
#  {'title': 'Snakes and Arrows',
#   'year': 1996,
#   'genres': ['Action'],
#   'duration': 111,
#   'directors': ['Eric R. Williams'],
#   'cast': ['Rick Baldwin', 'Amanda Barnum', 'Brian Beverly', 'Jason Clayton'],
#   'rating': 5.5},
#  {'title': 'Geisha',
#   'year': 1996,
#   'genres': ['Crime', 'Mystery', 'Thriller'],
#   'duration': 92,
#   'directors': ['Rodrigo Ortiz', 'Eduardo Raspo'],
#   'cast': ['Ana Álvarez', 'Manuel Bandera', 'Arturo Maly', 'Jorge Marrale'],
#   'rating': 5.5},
#  {'title': 'Oishinbo',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 105,
#   'directors': ['Azuma Morisaki'],
#   'cast': ['Rentarô Mikuni', 'Kôichi Satô', 'Michiko Hada', 'Shinsuke Ashida'],
#   'rating': 6.2},
#  {'title': 'Privet, duralei!',
#   'year': 1996,
#   'genres': ['Comedy', 'Romance'],
#   'duration': 112,
#   'directors': ['Eldar Ryazanov'],
#   'cast': ['Boris Shcherbakov',
#    'Tatyana Drubich',
#    'Vyacheslav Polunin',
#    'Tatyana Dogileva'],
#   'rating': 5.2},
#  {'title': 'Tunnu Ki Tina',
#   'year': 1996,
#   'genres': ['Comedy', 'Drama'],
#   'duration': 120,
#   'directors': ['Paresh Kamdar'],
#   'cast': ['Sunil Barve',
#    'Rohini Hattangadi',
#    'Rajeshwari Sachdev',
#    'Niraj Sah'],
#   'rating': 6.5},
#  {'title': 'Papa Kahte Hain',
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 143,
#   'directors': ['Mahesh Bhatt'],
#   'cast': ['Johny Bakshi',
#    'Anupam Kher',
#    'Mayuri Kango',
#    'Mayuri Kango',
#    'Jugal Hansraj',
#    'Navni Parihar',
#    'Abhimanyu Singh'],
#   'rating': 4.9},
#  {'title': 'Two Dads and One Mom',
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 90,
#   'directors': ['Jean-Marc Longval'],
#   'cast': ['Smaïn', 'Arielle Dombasle', 'Antoine de Caunes', 'Julie Gayet'],
#   'rating': 2.9},
#  {'title': 'Kingpin',
#   'year': 1996,
#   'genres': ['Comedy', 'Sport'],
#   'duration': 114,
#   'directors': ['Bobby Farrelly', 'Peter Farrelly'],
#   'cast': ['Woody Harrelson', 'Randy Quaid', 'Bill Murray', 'Vanessa Angel'],
#   'rating': 6.9},
#  {'title': 'Familia',
#   'year': 1996,
#   'genres': ['Comedy', 'Drama'],
#   'duration': 98,
#   'directors': ['Fernando León de Aranoa'],
#   'cast': ['Raquel Rodrigo',
#    'Juan Luis Galiardo',
#    'Amparo Muñoz',
#    'Ágata Lys',
#    'Chete Lera',
#    'Elena Anaya'],
#   'rating': 7.2},
#  {'title': 'Omega Doom',
#   'year': 1996,
#   'genres': ['Drama', 'Sci-Fi', 'Thriller'],
#   'duration': 84,
#   'directors': ['Albert Pyun'],
#   'cast': ['Rutger Hauer', 'Shannon Whirry', 'Norbert Weisser', 'Tina Cote'],
#   'rating': 4.0},
#  {'title': "Mama's proefkonijn",
#   'year': 1996,
#   'genres': ['Family'],
#   'duration': 45,
#   'directors': ['Monique van de Ven'],
#   'cast': ['Mirte de Kok',
#    'Ina van Faassen',
#    'Alice Reys',
#    'Mark Rietman',
#    'Johanna ter Steege',
#    'Olivier Tuinier'],
#   'rating': 6.8},
#  {'title': 'Shooting Lily',
#   'year': 1996,
#   'genres': ['Comedy', 'Drama'],
#   'duration': 82,
#   'directors': ['Arthur Borman'],
#   'cast': ['Matt Winston', 'Amy Smallman', 'Roy Jenkins', 'Richard Raddon'],
#   'rating': 7.9},
#  {'title': 'Taxi',
#   'year': 1996,
#   'genres': ['Crime', 'Drama', 'Romance'],
#   'duration': 110,
#   'directors': ['Carlos Saura'],
#   'cast': ['Ingrid Rubio',
#    'Carlos Fuentes',
#    'Ágata Lys',
#    'Ángel de Andrés López'],
#   'rating': 6.5},
#  {'title': 'La Moños',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 109,
#   'directors': ['Mireia Ros'],
#   'cast': ['Julieta Serrano',
#    'Eufemia Román',
#    'Carles Sabater',
#    'Claudia Molina'],
#   'rating': 7.6},
#  {'title': 'Fatal Frames',
#   'year': 1996,
#   'genres': ['Horror', 'Mystery'],
#   'duration': 125,
#   'directors': ['Al Festa'],
#   'cast': ['Stefania Stella', 'Rick Gianasi', 'David Warbeck', 'Ugo Pagliai'],
#   'rating': 3.9},
#  {'title': 'Tie naisen sydämeen',
#   'year': 1996,
#   'genres': ['Comedy', 'Mystery', 'Thriller'],
#   'duration': 109,
#   'directors': ['Pekka Parikka'],
#   'cast': ['Timo Torikka', 'Satu Silvo', 'Peter Franzén', 'Merja Larivaara'],
#   'rating': 6.1},
#  {'title': 'Things I Never Told You',
#   'year': 1996,
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'duration': 93,
#   'directors': ['Isabel Coixet'],
#   'cast': ['Andrew McCarthy', 'Lili Taylor', 'Peggy West', 'Leslie Mann'],
#   'rating': 6.7},
#  {'title': 'Sombras y luces: Cien años de cine español',
#   'year': 1996,
#   'genres': ['Documentary'],
#   'duration': 103,
#   'directors': ['Antonio Giménez Rico'],
#   'cast': ['Imperio Argentina', 'Aurora Bautista', 'Javier Dotú'],
#   'rating': 5.5},
#  {'title': "When the Cat's Away",
#   'year': 1996,
#   'genres': ['Comedy', 'Romance'],
#   'duration': 91,
#   'directors': ['Cédric Klapisch'],
#   'cast': ['Garance Clavel',
#    'Zinedine Soualem',
#    'Renée Le Calm',
#    'Olivier Py'],
#   'rating': 6.8},
#  {'title': 'Looking for Trouble',
#   'year': 1996,
#   'genres': ['Adventure', 'Drama', 'Family'],
#   'duration': 79,
#   'directors': ['Jay Aubrey', 'Peter Tors'],
#   'cast': ['Holly Butler', 'J. Kelly Dennehy', 'Tad Doyle', 'Lloyd Ennis'],
#   'rating': 6.4},
#  {'title': 'Tiré à part',
#   'year': 1996,
#   'genres': ['Drama', 'Thriller'],
#   'duration': 85,
#   'directors': ['Bernard Rapp'],
#   'cast': ['Terence Stamp',
#    'Daniel Mesguich',
#    'Maria de Medeiros',
#    'Jean-Claude Dreyfus'],
#   'rating': 6.5},
#  {'title': 'Bikini Goddesses',
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 82,
#   'directors': ['David DeCoteau'],
#   'cast': ['Alton Butler', 'Claudiu Trandafir', 'James Edwards'],
#   'rating': 3.6},
#  {'title': 'Janumada Jodi',
#   'year': 1996,
#   'genres': ['Drama', 'Romance'],
#   'duration': 140,
#   'directors': ['T.S. Nagabharana'],
#   'cast': ['Shivarajkumar', 'Chippy', 'Mysuru Anand', 'Ashok'],
#   'rating': 8.7},
#  {'title': 'Les Bidochon',
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 81,
#   'directors': ['Serge Korber'],
#   'cast': ['Anémone',
#    'Jean-François Stévenin',
#    'Annie Girardot',
#    'Elie Semoun'],
#   'rating': 3.3},
#  {'title': 'The Days Without Lei Feng',
#   'year': 1996,
#   'genres': ['Biography', 'Drama'],
#   'duration': 100,
#   'directors': ['Ning Kang', 'Xianhe Lei'],
#   'cast': ['Peiqi Liu', 'Chunli Song', 'Xin Liu', 'Dongqi Zhou'],
#   'rating': 6.3},
#  {'title': 'Subash',
#   'year': 1996,
#   'genres': ['Action'],
#   'duration': 150,
#   'directors': ['Udhayakumar'],
#   'cast': ['Arjun Sarja'],
#   'rating': 7.0},
#  {'title': "I'm Not Fascinating",
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 49,
#   'directors': ['Danny Plotnick'],
#   'cast': ['Anthony Bedard', 'Shea Bond', 'Chris Enright', 'Jonathan Swift'],
#   'rating': 6.2},
#  {'title': 'Legend of the Devil',
#   'year': 1996,
#   'genres': ['Action', 'History'],
#   'duration': 90,
#   'directors': ['Masaru Tsushima'],
#   'cast': ['Masaki Kyômoto',
#    'Atsuo Nakamura',
#    'Daisuke Ryû',
#    'Takeshi Yamato'],
#   'rating': 5.0},
#  {'title': 'Between Marx and a Naked Woman',
#   'year': 1996,
#   'genres': ['Biography', 'Drama'],
#   'duration': 92,
#   'directors': ['Camilo Luzuriaga'],
#   'cast': ['Felipe Teran',
#    'Aristides Vargas',
#    'Lissette Cabrera',
#    'Maia Koulieva'],
#   'rating': 6.8},
#  {'title': 'The Children of Captain Grant',
#   'year': 1996,
#   'genres': ['Adventure', 'Drama', 'Family'],
#   'duration': 115,
#   'directors': ['Donovan Scott'],
#   'cast': ['Chris Browning',
#    'Cassie Branham',
#    'Adam Gregor',
#    'Sonny Carl Davis'],
#   'rating': 7.9},
#  {'title': 'Kaalapani',
#   'year': 1996,
#   'genres': ['Action', 'Drama', 'History'],
#   'duration': 178,
#   'directors': ['Priyadarshan'],
#   'cast': ['Mohanlal', 'Amrish Puri', 'Prabhu', 'Tabu'],
#   'rating': 8.5},
#  {'title': 'Masseuse',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 93,
#   'directors': ['Fred Olen Ray'],
#   'cast': ['Griffin Drew', 'Tim Abell', 'Monique Parent', 'Matt Tanner'],
#   'rating': 3.3},
#  {'title': 'Jerusalem',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 168,
#   'directors': ['Bille August'],
#   'cast': ['Maria Bonnevie', 'Ulf Friberg', 'Pernilla August', 'Lena Endre'],
#   'rating': 6.9},
#  {'title': 'Eleatis Xenos',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 132,
#   'directors': ['Dimos Theos'],
#   'cast': ['Regina Remencius',
#    'Tealemachos Krevaikas',
#    'Tonia Botonaki',
#    'Ilias Gekas'],
#   'rating': 5.6},
#  {'title': 'Executive Decision',
#   'year': 1996,
#   'genres': ['Action', 'Adventure', 'Thriller'],
#   'duration': 133,
#   'directors': ['Stuart Baird'],
#   'cast': ['Kurt Russell', 'Halle Berry', 'John Leguizamo', 'Oliver Platt'],
#   'rating': 6.5},
#  {'title': 'Carpool',
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 89,
#   'directors': ['Arthur Hiller'],
#   'cast': ['Tom Arnold', 'David Paymer', 'Rhea Perlman', 'Rod Steiger'],
#   'rating': 4.9},
#  {'title': 'Clando',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 98,
#   'directors': ['Jean-Marie Téno'],
#   'cast': ['Paulin Fodouop',
#    'Henriette Fenda',
#    'Caroline Redl',
#    'Avs Bodule Moukilo'],
#   'rating': 6.9},
#  {'title': 'Showgirl Murders',
#   'year': 1996,
#   'genres': ['Action', 'Thriller'],
#   'duration': 82,
#   'directors': ['Dave Payne'],
#   'cast': ['Maria Ford', 'Jeffrey Douglas', 'Matt Preston', 'D.S. Case'],
#   'rating': 3.7},
#  {'title': 'Peanuts - Die Bank zahlt alles',
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 95,
#   'directors': ['Carlo Rola'],
#   'cast': ['Ulrich Mühe', 'Iris Berben', 'Marita Marschall', 'Rufus Beck'],
#   'rating': 5.7},
#  {'title': 'Jaan',
#   'year': 1996,
#   'genres': ['Action', 'Drama', 'Romance'],
#   'duration': 170,
#   'directors': ['Raj Kanwar'],
#   'cast': ['Ajay Devgn', 'Twinkle Khanna', 'Amrish Puri', 'Rakhee Gulzar'],
#   'rating': 4.2},
#  {'title': 'Eko Eko Azarak II: Birth of the Wizard',
#   'year': 1996,
#   'genres': ['Horror'],
#   'duration': 83,
#   'directors': ['Shimako Sato'],
#   'cast': ['Kimika Yoshino',
#    'Wataru Shihôdô',
#    'Chieko Shiratori',
#    'Akira Otani'],
#   'rating': 5.7},
#  {'title': 'Drifting Clouds',
#   'year': 1996,
#   'genres': ['Comedy', 'Drama'],
#   'duration': 97,
#   'directors': ['Aki Kaurismäki'],
#   'cast': ['Kati Outinen', 'Kari Väänänen', 'Elina Salo', 'Sakari Kuosmanen'],
#   'rating': 7.6},
#  {'title': 'Milk & Money',
#   'year': 1996,
#   'genres': ['Comedy', 'Romance'],
#   'duration': 86,
#   'directors': ['Michael Bergmann'],
#   'cast': ['Robert Petkoff', 'Harsh Nayyar', 'Sarah Winkler', 'Denise Faye'],
#   'rating': 5.1},
#  {'title': 'Naughty Guide to Tokyo Nightlife',
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 79,
#   'directors': ['Satoshi Kaneda'],
#   'cast': ['Vincent Bagnell',
#    'Timothy Breese Miller',
#    'Jessica Calvello',
#    'Ringo Farkas'],
#   'rating': 6.5},
#  {'title': 'The Money Shot',
#   'year': 1996,
#   'genres': ['Documentary', 'Drama'],
#   'duration': 86,
#   'directors': ['Ric Esther Bienstock', 'Matthew Mailer'],
#   'cast': ['Robert Alexander',
#    'Randy Cabrera',
#    'David Deblinger',
#    'Khalid Gonçalves'],
#   'rating': 3.3},
#  {'title': 'Kissing a Dream',
#   'year': 1996,
#   'genres': ['Thriller'],
#   'duration': 91,
#   'directors': ['Eric Gibson'],
#   'cast': ['Shari Eckert',
#    'Erin Lanza',
#    'Stephen Michael Pace',
#    'Tracy Dali',
#    'Simon Page'],
#   'rating': 4.3},
#  {'title': 'Beim nächsten Kuß knall ich ihn nieder',
#   'year': 1996,
#   'genres': ['Biography', 'Drama'],
#   'duration': 82,
#   'directors': ['Hans-Christoph Blumenberg'],
#   'cast': ['Peter Fitz', 'Bettina Kupfer', 'Jörg Holm', 'Lutz Herkenrath'],
#   'rating': 6.8},
#  {'title': 'Bullet',
#   'year': 1996,
#   'genres': ['Action', 'Crime', 'Drama'],
#   'duration': 96,
#   'directors': ['Julien Temple'],
#   'cast': ['Mickey Rourke', 'Frank Senger', 'Adrien Brody', 'John Enos III'],
#   'rating': 6.4},
#  {'title': 'Too Fast Too Young',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 90,
#   'directors': ['Tim Everitt'],
#   'cast': ['Michael Ironside',
#    'Katarzyna Figura',
#    'James Wellington',
#    'Patrick Tiller'],
#   'rating': 4.9},
#  {'title': 'Bwana',
#   'year': 1996,
#   'genres': ['Comedy', 'Drama'],
#   'duration': 80,
#   'directors': ['Imanol Uribe'],
#   'cast': ['Andrés Pajares',
#    'María Barranco',
#    'Emilio Buale',
#    'Alejandro Martínez'],
#   'rating': 5.8},
#  {'title': 'Al Horoob Ela Al Qemma',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 111,
#   'directors': ['Adel El Aassar'],
#   'cast': ['Hassan El Deib',
#    'Nour El-Sherif',
#    'Ilham Shaheen',
#    'Aida Riyad',
#    'Saeed Abdulghani',
#    'Nabil Al-Halafawy',
#    'Ateya Owiss',
#    'Ahmed Abo Abeya'],
#   'rating': 4.1},
#  {'title': 'Blue Mountain',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 97,
#   'directors': ['Thomas Tanner'],
#   'cast': ['Chandra Goetz', 'Sabina Lüthi', 'Eva Scheurer', 'Wolf Hofer'],
#   'rating': 7.5},
#  {'title': 'Queens of the Big Time',
#   'year': 1996,
#   'genres': ['Documentary'],
#   'duration': 75,
#   'directors': ['Adriana Trigiani'],
#   'cast': ['Sarah Saveri', 'Marino Saveri'],
#   'rating': 8.2},
#  {'title': 'Pesadilla para un rico',
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 96,
#   'directors': ['Fernando Fernán Gómez'],
#   'cast': ['Carlos Larrañaga',
#    'Beatriz Rico',
#    'Álvaro de Luna',
#    'Carme Elias'],
#   'rating': 5.1},
#  {'title': 'Si mian xia wa',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 100,
#   'directors': ['Kwok-Leung Kam'],
#   'cast': ['Fai-Hung Chan', 'Ping Ha', 'Eric Kot', 'Jan Lamb'],
#   'rating': 5.9},
#  {'title': 'Brigands-Chapter VII',
#   'year': 1996,
#   'genres': ['Comedy', 'Drama'],
#   'duration': 129,
#   'directors': ['Otar Iosseliani'],
#   'cast': ['Amiran Amiranashvili',
#    'Davit Gogibedashvili',
#    'Giorgi Tsintsadze',
#    'Nino Orjonikidze'],
#   'rating': 7.1},
#  {'title': 'Revizor',
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 100,
#   'directors': ['Sergey Gazarov'],
#   'cast': ['Nikita Mikhalkov',
#    'Marina Neyolova',
#    'Anna Mikhalkova',
#    'Zinoviy Gerdt'],
#   'rating': 6.2},
#  {'title': 'Original Gangstas',
#   'year': 1996,
#   'genres': ['Action', 'Crime', 'Drama'],
#   'duration': 99,
#   'directors': ['Larry Cohen'],
#   'cast': ['Fred Williamson', 'Jim Brown', 'Pam Grier', 'Paul Winfield'],
#   'rating': 5.7},
#  {'title': 'Captain Nuke and the Bomber Boys',
#   'year': 1996,
#   'genres': ['Comedy', 'Thriller'],
#   'duration': 90,
#   'directors': ['Charles Gale'],
#   'cast': ['Joe Mantegna', 'Martin Sheen', 'Joanna Pacula', 'Rod Steiger'],
#   'rating': 4.7},
#  {'title': 'Far Harbor',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 99,
#   'directors': ['John Huddles'],
#   'cast': ['Edward Atterton',
#    'Jennifer Connelly',
#    'Dan Futterman',
#    'Marcia Gay Harden'],
#   'rating': 4.7},
#  {'title': 'Gran Slalom',
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 84,
#   'directors': ['Jaime Chávarri'],
#   'cast': ['Juanjo Puigcorbé',
#    'Laura del Sol',
#    'Santiago Ramos',
#    'Josep Maria Pou'],
#   'rating': 4.7},
#  {'title': 'Fled',
#   'year': 1996,
#   'genres': ['Action', 'Adventure', 'Crime'],
#   'duration': 98,
#   'directors': ['Kevin Hooks'],
#   'cast': ['Laurence Fishburne',
#    'Stephen Baldwin',
#    'Will Patton',
#    'Robert John Burke'],
#   'rating': 5.4},
#  {'title': 'To Have & to Hold',
#   'year': 1996,
#   'genres': ['Mystery', 'Thriller'],
#   'duration': 99,
#   'directors': ['John Hillcoat'],
#   'cast': ['Tchéky Karyo',
#    'Rachel Griffiths',
#    'Steve Jacobs',
#    'Anni Finsterer'],
#   'rating': 5.6},
#  {'title': 'Baby Face Nelson',
#   'year': 1996,
#   'genres': ['Action', 'Crime', 'Drama'],
#   'duration': 93,
#   'directors': ['Scott P. Levy'],
#   'cast': ['C. Thomas Howell', 'Lisa Zane', 'Doug Wert', 'F. Murray Abraham'],
#   'rating': 5.1},
#  {'title': 'Doble indemnización',
#   'year': 1996,
#   'genres': ['Action', 'Comedy', 'Drama'],
#   'duration': 90,
#   'directors': ['Raúl Araiza'],
#   'cast': ['Héctor Bonilla',
#    'María Rojo',
#    'Leticia Perdigón',
#    'Rodolfo de Anda'],
#   'rating': 7.5},
#  {'title': 'Tri-Star',
#   'year': 1996,
#   'genres': ['Comedy', 'Crime', 'Romance'],
#   'duration': 106,
#   'directors': ['Hark Tsui'],
#   'cast': ['Leslie Cheung',
#    'Anita Yuen',
#    'Ching Wan Lau',
#    'Catherine Yan Hung'],
#   'rating': 6.1},
#  {'title': 'Umm Kulthum',
#   'year': 1996,
#   'genres': ['Documentary'],
#   'duration': 67,
#   'directors': ['Michal Goldman'],
#   'cast': ['Tawfik Badawi', 'Amal Fahmy', 'Omar Sharif'],
#   'rating': 7.8},
#  {'title': 'Bao gao ban zhang 5',
#   'year': 1996,
#   'genres': ['Adventure', 'Comedy'],
#   'duration': 84,
#   'directors': ['Yen-Ping Chu'],
#   'cast': ['Min Wu',
#    'Cheng-Yung Chang',
#    'Li-Wei Chang',
#    'Te-Chih Wang',
#    'Chi-Lung Wu'],
#   'rating': 2.5},
#  {'title': 'The Career of Arturo Ui: New Version',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 102,
#   'directors': ['Boris Blank'],
#   'cast': ['Aleksandr Filippenko',
#    'Vyacheslav Nevinnyy',
#    'Valentin Gaft',
#    'Aleksandr Pashutin'],
#   'rating': 6.1},
#  {'title': "Marvin's Room",
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 98,
#   'directors': ['Jerry Zaks'],
#   'cast': ['Meryl Streep',
#    'Leonardo DiCaprio',
#    'Diane Keaton',
#    'Robert De Niro'],
#   'rating': 6.7},
#  {'title': 'Advocaat van de Hanen',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 109,
#   'directors': ['Gerrit van Elst'],
#   'cast': ['Pierre Bokma', 'Margo Dames', 'Jaap Spijkers', 'Peter Oosthoek'],
#   'rating': 5.7},
#  {'title': 'Love and Other Catastrophes',
#   'year': 1996,
#   'genres': ['Comedy', 'Romance'],
#   'duration': 76,
#   'directors': ['Emma-Kate Croghan'],
#   'cast': ["Frances O'Connor",
#    'Alice Garner',
#    'Matt Day',
#    'Matthew Dyktynski'],
#   'rating': 6.5},
#  {'title': 'Ninne Pelladatha',
#   'year': 1996,
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'duration': 146,
#   'directors': ['Krishna Vamsi', 'Y.V.S. Chowdary'],
#   'cast': ['Nagarjuna Akkineni', 'Tabu', 'Chalapathi Rao', 'Chandramohan'],
#   'rating': 7.7},
#  {'title': 'Kathapurushan',
#   'year': 1996,
#   'genres': ['Biography', 'Drama'],
#   'duration': 107,
#   'directors': ['Adoor Gopalakrishnan'],
#   'cast': ['Vishwanathan', 'Mini Nair', 'Aranmulla Ponnamma', 'Urmila Unni'],
#   'rating': 7.3},
#  {'title': 'Cassiopeia',
#   'year': 1996,
#   'genres': ['Adventure', 'Animation', 'Family'],
#   'duration': 80,
#   'directors': ['Clóvis Vieira'],
#   'cast': ['Osmar Prado', 'Jonas Mello', 'Aldo César', 'Marcelo Campos'],
#   'rating': 6.9},
#  {'title': 'Dead of Night',
#   'year': 1996,
#   'genres': ['Horror'],
#   'duration': 95,
#   'directors': ['Kristoffer Tabori'],
#   'cast': ['John Enos III',
#    'Kathleen Kinmont',
#    'Robert Knepper',
#    'Alex Rocco'],
#   'rating': 4.2},
#  {'title': 'The Life and Times of the Red Dog Saloon',
#   'year': 1996,
#   'genres': ['Documentary', 'Music'],
#   'duration': 91,
#   'directors': ['Mary Works'],
#   'cast': ['Howard Hesseman'],
#   'rating': 7.8},
#  {'title': 'Eu sunt Adam!',
#   'year': 1996,
#   'genres': ['Drama', 'Fantasy'],
#   'duration': 108,
#   'directors': ['Dan Pita'],
#   'cast': ['Stefan Iordache',
#    'Marius Stanescu',
#    'Cristian Iacob',
#    'Irina Movila'],
#   'rating': 8.2},
#  {'title': 'Love Is All There Is',
#   'year': 1996,
#   'genres': ['Comedy', 'Romance'],
#   'duration': 105,
#   'directors': ['Renée Taylor'],
#   'cast': ['Lainie Kazan',
#    'Paul Sorvino',
#    'Barbara Carrera',
#    'Joseph Bologna'],
#   'rating': 5.1},
#  {'title': 'Few of Us',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 105,
#   'directors': ['Sharunas Bartas'],
#   'cast': ['Alex Descas',
#    'Yekaterina Golubeva',
#    'Piotr Kishteev',
#    'Eimuntas Nekroshius'],
#   'rating': 7.2},
#  {'title': 'All Dogs Go to Heaven 2',
#   'year': 1996,
#   'genres': ['Adventure', 'Animation', 'Family'],
#   'duration': 82,
#   'directors': ['Larry Leker', 'Paul Sabella'],
#   'cast': ['Charlie Sheen', 'Sheena Easton', 'Dom DeLuise', 'Ernest Borgnine'],
#   'rating': 5.4},
#  {'title': 'Within the Lines',
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 85,
#   'directors': ['Bill Johnson'],
#   'cast': ['Paul Michael Robinson',
#    'Noah Blake',
#    'Rochelle Swanson',
#    'Cameron Gray'],
#   'rating': 2.4},
#  {'title': 'Saint-Ex',
#   'year': 1996,
#   'genres': ['Biography', 'Drama', 'Fantasy'],
#   'duration': 82,
#   'directors': ['Anand Tucker'],
#   'cast': ['Bruno Ganz', 'Miranda Richardson', 'Janet McTeer', 'Ken Stott'],
#   'rating': 5.2},
#  {'title': 'Ben Annemin Kiziyim - Ich bin Tochter meiner Mutter',
#   'year': 1996,
#   'genres': ['Documentary'],
#   'duration': 89,
#   'directors': ['Seyhan Derin'],
#   'cast': ['Ilknur Bahadir', 'Emine Sevgi Özdamar'],
#   'rating': 6.7},
#  {'title': 'Precious Find',
#   'year': 1996,
#   'genres': ['Adventure', 'Sci-Fi', 'Western'],
#   'duration': 90,
#   'directors': ['Philippe Mora'],
#   'cast': ['Rutger Hauer', 'Joan Chen', 'Harold Pruett', 'Brion James'],
#   'rating': 3.6},
#  {'title': 'Down Periscope',
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 92,
#   'directors': ['David S. Ward'],
#   'cast': ['Kelsey Grammer',
#    'Lauren Holly',
#    'Rob Schneider',
#    'Harry Dean Stanton'],
#   'rating': 6.1},
#  {'title': 'A Journey Through the Dark Side',
#   'year': 1996,
#   'genres': ['Drama', 'War'],
#   'duration': 129,
#   'directors': ['Davor Zmegac'],
#   'cast': ['Goran Navojec', 'Edita Majic', 'Vedran Lulic', 'Zarko Savic'],
#   'rating': 6.7},
#  {'title': 'Slayers Return',
#   'year': 1996,
#   'genres': ['Animation', 'Comedy', 'Fantasy'],
#   'duration': 61,
#   'directors': ['Hiroshi Watanabe', 'Kunihiko Yuyama'],
#   'cast': ['Megumi Hayashibara',
#    'Maria Kawamura',
#    'Akiko Hiramatsu',
#    'Akio Ôtsuka'],
#   'rating': 6.9},
#  {'title': 'Stories of Love, Madness and Death',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 100,
#   'directors': ['Nemesio Juárez'],
#   'cast': ['Cristina Banegas',
#    'Ulises Dumont',
#    'Inés Estévez',
#    'Víctor Laplace'],
#   'rating': 5.8},
#  {'title': 'Aquí llega Condemor, el pecador de la pradera',
#   'year': 1996,
#   'genres': ['Comedy', 'Musical', 'Western'],
#   'duration': 90,
#   'directors': ['Álvaro Sáenz de Heredia'],
#   'cast': ['Chiquito de la Calzada',
#    'Bigote Arrocet',
#    'Sol Abad',
#    'Naim Thomas'],
#   'rating': 2.7},
#  {'title': 'Erreur sur la personne',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 95,
#   'directors': ['Gilles Noël'],
#   'cast': ['Michel Côté', 'Macha Grenon', 'Paul Doucet', 'Robert Gravel'],
#   'rating': 5.4},
#  {'title': 'Ransom',
#   'year': 1996,
#   'genres': ['Action', 'Crime', 'Thriller'],
#   'duration': 121,
#   'directors': ['Ron Howard'],
#   'cast': ['Mel Gibson', 'Gary Sinise', 'Rene Russo', 'Brawley Nolte'],
#   'rating': 6.7},
#  {'title': 'Oblivion 2: Backlash',
#   'year': 1996,
#   'genres': ['Adventure', 'Comedy', 'Sci-Fi'],
#   'duration': 83,
#   'directors': ['Sam Irvin'],
#   'cast': ['Richard Joseph Paul',
#    'Jackie Swanson',
#    'Andrew Divoff',
#    'Meg Foster'],
#   'rating': 5.0},
#  {'title': 'Shoemaker',
#   'year': 1996,
#   'genres': ['Drama', 'Romance'],
#   'duration': 80,
#   'directors': ['Colleen Murphy'],
#   'cast': ['Maggie Huculak',
#    'George Buza',
#    'Reginald Doresa',
#    'Neil Foster',
#    'Ellen-Ray Hennessy'],
#   'rating': 7.2},
#  {'title': 'Mary Reilly',
#   'year': 1996,
#   'genres': ['Drama', 'Horror', 'Romance'],
#   'duration': 108,
#   'directors': ['Stephen Frears'],
#   'cast': ['Julia Roberts', 'John Malkovich', 'George Cole', 'Michael Gambon'],
#   'rating': 5.8},
#  {'title': "Joe's So Mean to Josephine",
#   'year': 1996,
#   'genres': ['Crime', 'Drama', 'Romance'],
#   'duration': 89,
#   'directors': ['Peter Wellington'],
#   'cast': ['Eric Thal', 'Sarah Polley', 'Don McKellar', 'Waneta Storms'],
#   'rating': 6.3},
#  {'title': 'One Fine Day',
#   'year': 1996,
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'duration': 108,
#   'directors': ['Michael Hoffman'],
#   'cast': ['Michelle Pfeiffer',
#    'George Clooney',
#    'Mae Whitman',
#    'Alex D. Linz'],
#   'rating': 6.5},
#  {'title': 'Driven',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 103,
#   'directors': ['Michael Shoob'],
#   'cast': ['Metin Bereketli',
#    'Xander Berkeley',
#    'Joseph Culp',
#    'Diane DiLascio'],
#   'rating': 6.0},
#  {'title': 'Cachito',
#   'year': 1996,
#   'genres': ['Adventure', 'Crime', 'Drama'],
#   'duration': 95,
#   'directors': ['Enrique Urbizu'],
#   'cast': ['Jorge Perugorría',
#    'Sancho Gracia',
#    'Amara Carmona',
#    'Elvira Mínguez'],
#   'rating': 5.5},
#  {'title': 'Multiplicity',
#   'year': 1996,
#   'genres': ['Comedy', 'Romance', 'Sci-Fi'],
#   'duration': 117,
#   'directors': ['Harold Ramis'],
#   'cast': ['Michael Keaton',
#    'Andie MacDowell',
#    'Zack Duhame',
#    'Katie Schlossberg'],
#   'rating': 6.1},
#  {'title': 'Shastra',
#   'year': 1996,
#   'genres': ['Action', 'Comedy', 'Drama'],
#   'duration': 144,
#   'directors': ['Sanjay Khanna'],
#   'cast': ['Suniel Shetty', 'Anjali Jathar', 'Anupam Kher', 'Danny Denzongpa'],
#   'rating': 5.0},
#  {'title': 'Call Girl',
#   'year': 1996,
#   'genres': ['Thriller'],
#   'duration': 100,
#   'directors': ['Carlo Vanzina'],
#   'cast': ['Raz Degan', 'Jennifer Driver', 'Paul Freeman', 'Bianca Koedam'],
#   'rating': 2.9},
#  {'title': "Passage à l'acte",
#   'year': 1996,
#   'genres': ['Thriller'],
#   'duration': 105,
#   'directors': ['Francis Girod'],
#   'cast': ['Daniel Auteuil',
#    'Patrick Timsit',
#    'Anne Parillaud',
#    'Michèle Laroque'],
#   'rating': 5.8},
#  {'title': "Layin' Low",
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 96,
#   'directors': ['Danny Leiner'],
#   'cast': ['Jeremy Piven', 'Louise Lasser', 'Edie Falco', 'Frank John Hughes'],
#   'rating': 5.0},
#  {'title': 'A Web of War',
#   'year': 1996,
#   'genres': ['Documentary', 'War'],
#   'duration': 51,
#   'directors': ['Brian McKenna'],
#   'cast': ['Terence McKenna', 'Andreas Apergis', 'Tamara Gorski'],
#   'rating': 7.7},
#  {'title': 'Los vuelcos del corazón',
#   'year': 1996,
#   'genres': ['Drama', 'Romance'],
#   'duration': 130,
#   'directors': ['Mitl Valdez'],
#   'cast': ['Martin Barraza',
#    'Arturo Beristáin',
#    'Rosa María Bianchi',
#    'Juan Carlos Colombo'],
#   'rating': 6.1},
#  {'title': 'Arcane Sorcerer',
#   'year': 1996,
#   'genres': ['Horror'],
#   'duration': 96,
#   'directors': ['Pupi Avati'],
#   'cast': ['Carlo Cecchi',
#    'Stefano Dionisi',
#    'Arnaldo Ninchi',
#    'Andrea Scorzoni'],
#   'rating': 6.8},
#  {'title': 'Last Days: Hype or Hope?',
#   'year': 1996,
#   'genres': ['Documentary'],
#   'duration': 59,
#   'directors': ['André van Heerden'],
#   'cast': ['Gareth Bond'],
#   'rating': 4.9},
#  {'title': 'Everything Must Go',
#   'year': 1996,
#   'genres': ['Comedy', 'Drama'],
#   'duration': 105,
#   'directors': ['Jan Verheyen'],
#   'cast': ['Stany Crets',
#    'Peter Van den Begin',
#    'Bart De Pauw',
#    'Jaak Van Assche'],
#   'rating': 6.8},
#  {'title': 'Kill the Love',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 106,
#   'directors': ['Jong-jae Im'],
#   'cast': ['Lee Byung-hun',
#    'Seon-kyeong Jeong',
#    'Oh-seong Yu',
#    'Geun-hyeong Park'],
#   'rating': 5.6},
#  {'title': 'Heavy Weather',
#   'year': 1996,
#   'genres': ['Comedy', 'Drama'],
#   'duration': 105,
#   'directors': ['Jean Marboeuf'],
#   'cast': ['Catherine Arditi',
#    'Françoise Arnoul',
#    'Evelyne Bouix',
#    'Fabienne Chaudat'],
#   'rating': 5.1},
#  {'title': 'Orpheus Descending',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 110,
#   'directors': ['George Zervoulakos'],
#   'cast': ['Vana Barba',
#    'Nikos Xanthopoulos',
#    'Michalis Papagellidis',
#    'Christos Kalavrouzos'],
#   'rating': 6.2},
#  {'title': "I'm Not Rappaport",
#   'year': 1996,
#   'genres': ['Comedy', 'Drama'],
#   'duration': 135,
#   'directors': ['Herb Gardner'],
#   'cast': ['Walter Matthau', 'Ossie Davis', 'Amy Irving', 'Craig T. Nelson'],
#   'rating': 6.5},
#  {'title': 'El anzuelo',
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 85,
#   'directors': ['Ernesto Rimoch'],
#   'cast': ['Bruno Bichir',
#    'Mariana Lecuona',
#    'Álvaro Guerrero',
#    'Damián Alcázar'],
#   'rating': 6.9},
#  {'title': 'Ooru naito ronga 3: Sanji',
#   'year': 1996,
#   'genres': ['Horror'],
#   'duration': 76,
#   'directors': ['Katsuya Matsumura'],
#   'cast': ['Yûjin Kitagawa', 'Ryôka Yuzuki', 'Tomorô Taguchi', 'Meika Seri'],
#   'rating': 5.4},
#  {'title': 'Mørkeleg',
#   'year': 1996,
#   'genres': ['Horror'],
#   'duration': 90,
#   'directors': ['Martin Schmidt'],
#   'cast': ['Line Kruse',
#    'Christian Grønvall',
#    'Mari-Anne Jespersen',
#    'Karl Bille'],
#   'rating': 4.7},
#  {'title': 'Phantom Pain',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 83,
#   'directors': ['Neil Matsumoto'],
#   'cast': ['Tina Alexis Allen',
#    'Holly Woodlawn',
#    'Sean Cory Cooper',
#    'Wendy Bryan Michaels',
#    'Scott Ramirez'],
#   'rating': 5.4},
#  {'title': 'Nodir Naam Modhumoti',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 130,
#   'directors': ['Tanvir Mokammel'],
#   'cast': ['Tauquir Ahmed', 'Aly Zaker', 'Raisul Islam Asad', 'Sara Zaker'],
#   'rating': 8.0},
#  {'title': 'Is Raat Ki Subah Nahin',
#   'year': 1996,
#   'genres': ['Crime', 'Thriller'],
#   'duration': 131,
#   'directors': ['Sudhir Mishra'],
#   'cast': ['Murad Ali',
#    'Tarun Kumar Chatterjee',
#    'Tara Deshpande',
#    'Kishore Kadam'],
#   'rating': 7.0},
#  {'title': 'Patriots',
#   'year': 1996,
#   'genres': ['Thriller'],
#   'duration': 83,
#   'directors': ['Frank Kerr'],
#   'cast': ['Richard Alger',
#    'Linda Amendola',
#    'Mark Newell',
#    'Aidan Parkinson',
#    'Dermott Petty',
#    "Carmel O'Reilly",
#    'Luke Seavers'],
#   'rating': 5.7},
#  {'title': 'Fistful of Flies',
#   'year': 1996,
#   'genres': ['Drama', 'Thriller'],
#   'duration': 85,
#   'directors': ['Monica Pellizzari'],
#   'cast': ['Dina Panozzo', 'John Lucantonio', 'Anna Volska', 'Tasma Walton'],
#   'rating': 6.5},
#  {'title': 'E=mc2',
#   'year': 1996,
#   'genres': ['Comedy', 'Romance'],
#   'duration': 94,
#   'directors': ['Benjamin Fry'],
#   'cast': ['Jeremy Piven', 'Kelli Williams', 'Liza Walker', 'James Villiers'],
#   'rating': 5.2},
#  {'title': 'Enakkoru Magan Pirappan',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 150,
#   'directors': ['Keyaar'],
#   'cast': ['Sundarrajan',
#    'Anju Aravind',
#    'Chinni Jayanth',
#    'Kushboo',
#    'Venniradai Moorthy',
#    'Pandu',
#    'Ramki',
#    'Senthil'],
#   'rating': 5.1},
#  {'title': 'I virtuali',
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 78,
#   'directors': ['Luca Mazzieri'],
#   'cast': ['Marco Mazzieri',
#    'Andrea Galeazzi',
#    'Laura Cleri',
#    'Alessandro Pini'],
#   'rating': 7.3},
#  {'title': 'Temptress Moon',
#   'year': 1996,
#   'genres': ['Drama', 'Romance'],
#   'duration': 130,
#   'directors': ['Kaige Chen'],
#   'cast': ['Leslie Cheung', 'Gong Li', 'Kevin Lin', 'Saifei He'],
#   'rating': 6.7},
#  {'title': 'Lalla Hobby',
#   'year': 1996,
#   'genres': ['Adventure', 'Comedy', 'Family'],
#   'duration': 95,
#   'directors': ['Mohamed Abderrahman Tazi'],
#   'cast': ['Amidou', 'Samia Akarriou', 'Pierre Lekeux'],
#   'rating': 6.4},
#  {'title': 'Darklands',
#   'year': 1996,
#   'genres': ['Drama', 'Horror', 'Thriller'],
#   'duration': 90,
#   'directors': ['Julian Richards'],
#   'cast': ['Craig Fairbrass', 'Rowena King', 'Jon Finch', 'Roger Nott'],
#   'rating': 4.6},
#  {'title': 'Si ge 32A he yi ge xiang jiao shao nian',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 101,
#   'directors': ['Eric Tsang'],
#   'cast': ['Lai Na Kong',
#    'Chi-Shing Chan',
#    'Jordan Chan',
#    'Julian Cheung',
#    'Anna Kamiyama'],
#   'rating': 6.6},
#  {'title': "Ed's Next Move",
#   'year': 1996,
#   'genres': ['Comedy', 'Romance'],
#   'duration': 88,
#   'directors': ['John Walsh'],
#   'cast': ['Matt Ross', 'Catherine Curtin', 'Timothy Pilato', 'Ramon Moses'],
#   'rating': 6.4},
#  {'title': 'Un samedi sur la terre',
#   'year': 1996,
#   'genres': ['Comedy', 'Drama'],
#   'duration': 95,
#   'directors': ['Diane Bertrand'],
#   'cast': ['Elsa Zylberstein', 'Éric Caravaca', 'Johan Leysen', 'Kent'],
#   'rating': 7.2},
#  {'title': "Party at Sam's",
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 89,
#   'directors': ['Douglas J. Eboch'],
#   'cast': ['Thomas Ballatore',
#    'Meghan Beals',
#    'Cinnamon Brown',
#    'Paul Douglas Brown'],
#   'rating': 7.2},
#  {'title': 'La chica',
#   'year': 1996,
#   'genres': ['Comedy', 'Drama'],
#   'duration': 88,
#   'directors': ['Bruno Gantillon'],
#   'cast': ['Jorge Losada',
#    'Marine Delterme',
#    'Bruno Wolkowitch',
#    'Wojciech Pszoniak',
#    'Frédéric Tokarz',
#    'Mario Balmaseda',
#    'Elio Mesa'],
#   'rating': 6.9},
#  {'title': 'Hong Kong Show Girls',
#   'year': 1996,
#   'genres': ['Comedy', 'Horror'],
#   'duration': 90,
#   'directors': ['John Hau'],
#   'cast': ['Veronica Yip', 'Diana Pang', 'Pauline Chan', 'Ka-Tung Lam'],
#   'rating': 3.7},
#  {'title': 'Hit Me',
#   'year': 1996,
#   'genres': ['Crime', 'Drama', 'Thriller'],
#   'duration': 125,
#   'directors': ['Steven Shainberg'],
#   'cast': ['Elias Koteas', 'Laure Marsac', 'Jay Leggett', 'Bruce Ramsay'],
#   'rating': 5.4},
#  {'title': 'Lulu',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 96,
#   'directors': ['Srinivas Krishna'],
#   'cast': ['Kim Lieu', 'Clark Johnson', 'Michael Rhoades', 'Manuel Aranguiz'],
#   'rating': 5.6},
#  {'title': 'Xiao jiao qi mou sheng ji',
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 90,
#   'directors': ['Shujun Shi'],
#   'cast': ['Xun Zhou', 'Li Cao', 'Chunxiao Liu', 'Qi Zhang'],
#   'rating': 4.8},
#  {'title': 'Un asunto privado',
#   'year': 1996,
#   'genres': ['Drama', 'Thriller'],
#   'duration': 98,
#   'directors': ['Imanol Arias'],
#   'cast': ['Jorge Perugorría',
#    'Antonio Valero',
#    'Pastora Vega',
#    'Fabián Vena'],
#   'rating': 3.4},
#  {'title': 'Ullathai Allitha',
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 149,
#   'directors': ['Sundar C.'],
#   'cast': ['Goundamani', 'Karthik', 'Rambha'],
#   'rating': 7.7},
#  {'title': 'Two Cops 2',
#   'year': 1996,
#   'genres': ['Action', 'Comedy'],
#   'duration': 117,
#   'directors': ['Woo-Suk Kang'],
#   'cast': ['Joong-Hoon Park', 'Bo-sung Kim', 'Su-Won Ji', 'Seong-jin Kang'],
#   'rating': 5.7},
#  {'title': 'The Stendhal Syndrome',
#   'year': 1996,
#   'genres': ['Horror', 'Mystery', 'Thriller'],
#   'duration': 120,
#   'directors': ['Dario Argento'],
#   'cast': ['Asia Argento',
#    'Thomas Kretschmann',
#    'Marco Leonardi',
#    'Luigi Diberti'],
#   'rating': 6.0},
#  {'title': 'Shiloh',
#   'year': 1996,
#   'genres': ['Drama', 'Family'],
#   'duration': 93,
#   'directors': ['Dale Rosenbloom'],
#   'cast': ['Blake Heron',
#    'Michael Moriarty',
#    'Scott Wilson',
#    'Bonnie Bartlett'],
#   'rating': 6.3},
#  {'title': 'Brittle Glory',
#   'year': 1996,
#   'genres': ['Comedy', 'Drama'],
#   'duration': 84,
#   'directors': ['Stewart Schill'],
#   'cast': ['Tony Curtis', 'Arye Gross', 'Ally Walker', 'Paul Sand'],
#   'rating': 5.2},
#  {'title': "The Preacher's Wife",
#   'year': 1996,
#   'genres': ['Comedy', 'Drama', 'Fantasy'],
#   'duration': 123,
#   'directors': ['Penny Marshall'],
#   'cast': ['Denzel Washington',
#    'Whitney Houston',
#    'Courtney B. Vance',
#    'Gregory Hines'],
#   'rating': 5.6},
#  {'title': 'American Strays',
#   'year': 1996,
#   'genres': ['Action', 'Comedy'],
#   'duration': 97,
#   'directors': ['Michael Covert'],
#   'cast': ['Scott Plank', 'Melora Walters', 'John Savage', 'Brion James'],
#   'rating': 5.2},
#  {'title': 'Safety Zone',
#   'year': 1996,
#   'genres': ['Action', 'Sci-Fi'],
#   'duration': 82,
#   'directors': ['Randy Butcher'],
#   'cast': ['Loren Avedon',
#    'Brad Connolly',
#    'Elizabeth Nijjar',
#    'Frank Martin'],
#   'rating': 4.0},
#  {'title': 'Tres minutos en la oscuridad',
#   'year': 1996,
#   'genres': ['Crime', 'Drama', 'Mystery'],
#   'duration': 92,
# ...
#   'year': 1996,
#   'genres': ['Action', 'Crime', 'Thriller'],
#   'duration': 91,
#   'directors': ['Benny Chan'],
#   'cast': ['Ching Wan Lau', 'Jordan Chan', 'Tat-Ming Cheung', 'Theresa Lee'],
#   'rating': 6.7},
#  {'title': 'Killer Barbys',
#   'year': 1996,
#   'genres': ['Horror'],
#   'duration': 90,
#   'directors': ['Jesús Franco'],
#   'cast': ['Santiago Segura',
#    'Mariangela Giordano',
#    'Aldo Sambrell',
#    'Charlie S. Chaplin'],
#   'rating': 3.7},
#  {'title': 'Gopala Gopala',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 155,
#   'directors': ['Pandiarajan'],
#   'cast': ['Anju',
#    'Charlie',
#    'Janakaraj',
#    'Kushboo',
#    'Manivannan',
#    'Venniradai Moorthy',
#    'Kovai Sarala',
#    'Malaysia Vasudevan'],
#   'rating': 5.9},
#  {'title': 'New Jin Pin Mei II',
#   'year': 1996,
#   'genres': ['Romance'],
#   'duration': 88,
#   'directors': ['Yui-Ming Tam'],
#   'cast': ['Yu-Yao Chang',
#    'Si-Man Yeung',
#    'Lap-Man Tan',
#    'Miyû Ohmori',
#    'Hui Chao',
#    'Sin-Yi Yip'],
#   'rating': 4.9},
#  {'title': "Lover's Tears",
#   'year': 1996,
#   'genres': ['Drama', 'Romance'],
#   'duration': 91,
#   'directors': ['Kwok-Lap Lee'],
#   'cast': ['Tung-Shing Yee',
#    'Henry Fong',
#    'Carman Lee',
#    'Paulyn Sun',
#    'Yat-Ming Ting',
#    'Tsung-Hua Tou'],
#   'rating': 5.0},
#  {'title': 'Dangerous Dowry',
#   'year': 1996,
#   'genres': ['Action', 'Romance'],
#   'duration': 100,
#   'directors': ['Dennis Satin'],
#   'cast': ['Katja Riemann',
#    'Hannes Jaenicke',
#    'Heinz Hoenig',
#    'Daniela Amavia'],
#   'rating': 5.9},
#  {'title': 'Fantôme avec chauffeur',
#   'year': 1996,
#   'genres': ['Adventure', 'Comedy', 'Fantasy'],
#   'duration': 78,
#   'directors': ['Gérard Oury'],
#   'cast': ['Philippe Noiret',
#    'Gérard Jugnot',
#    'Jean-Luc Bideau',
#    'Charlotte Kady'],
#   'rating': 4.9},
#  {'title': 'Alles nur Tarnung',
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 90,
#   'directors': ['Peter Zingler'],
#   'cast': ['Mario Adorf', 'Ben Becker', 'Elke Sommer', 'Muriel Baumeister'],
#   'rating': 5.1},
#  {'title': 'Dipu Number 2',
#   'year': 1996,
#   'genres': ['Adventure', 'Family'],
#   'duration': 154,
#   'directors': ['Morshedul Islam'],
#   'cast': ['Shafquat', 'Arun Saha', 'Shubashish', 'Bulbul Ahmed', 'Bobita'],
#   'rating': 8.9},
#  {'title': 'Puja',
#   'year': 1996,
#   'genres': ['Drama', 'Musical'],
#   'duration': 140,
#   'directors': ['Subhash Sen'],
#   'cast': ['Anil Chatterjee',
#    'Manoj Mitra',
#    'Sreela Majumdar',
#    'Haradhan Bannerjee'],
#   'rating': 7.1},
#  {'title': "Paul Monette: The Brink of Summer's End",
#   'year': 1996,
#   'genres': ['Biography', 'Documentary'],
#   'duration': 90,
#   'directors': ['Monte Bramer'],
#   'cast': ['Jonathan Fried', 'Linda Hunt'],
#   'rating': 8.0},
#  {'title': 'Le bel été 1914',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 117,
#   'directors': ['Christian de Chalonge'],
#   'cast': ['Claude Rich',
#    'Maria Pacôme',
#    'Hippolyte Girardot',
#    'Judith Henry'],
#   'rating': 6.2},
#  {'title': 'Mi nombre es sombra',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 90,
#   'directors': ['Gonzalo Suárez'],
#   'cast': ['François-Eric Gendron',
#    'Amparo Larrañaga',
#    'Jean-Claude Adelin',
#    'Elena Bagutta'],
#   'rating': 6.2},
#  {'title': 'Mr. Wrong',
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 96,
#   'directors': ['Nick Castle'],
#   'cast': ['Ellen DeGeneres', 'Bill Pullman', 'Joan Cusack', 'Dean Stockwell'],
#   'rating': 3.8},
#  {'title': 'Ai xuoi van ly',
#   'year': 1996,
#   'genres': ['Drama', 'War'],
#   'duration': 90,
#   'directors': ['Hoang Le'],
#   'cast': ['Mien Moc', 'Cong Ninh Nguyen'],
#   'rating': 6.1},
#  {'title': 'Unhook the Stars',
#   'year': 1996,
#   'genres': ['Drama', 'Romance'],
#   'duration': 103,
#   'directors': ['Nick Cassavetes'],
#   'cast': ['Gena Rowlands', 'Marisa Tomei', 'Gérard Depardieu', 'Jake Lloyd'],
#   'rating': 6.5},
#  {'title': 'Lucas me quería a mí',
#   'year': 1996,
#   'genres': ['Comedy', 'Mystery'],
#   'duration': 87,
#   'directors': ['Dunia Ayaso', 'Félix Sabroso'],
#   'cast': ['Jordi Mollà', 'Pepón Nieto', 'Roberto Correcher', 'Lucina Gil'],
#   'rating': 5.6},
#  {'title': 'Nan yang di yi xie jiang',
#   'year': 1996,
#   'genres': ['Comedy', 'Fantasy', 'Horror'],
#   'duration': 96,
#   'directors': ['Otto Chan'],
#   'cast': ['Lan Law',
#    'Elvis Tsui',
#    'Miu-Ying Chan',
#    'Ben Ngai-Cheung Ng',
#    'Ivy Leung',
#    'Cammy Choi'],
#   'rating': 6.3},
#  {'title': 'For Ever Mozart',
#   'year': 1996,
#   'genres': ['Comedy', 'Drama', 'War'],
#   'duration': 84,
#   'directors': ['Jean-Luc Godard'],
#   'cast': ['Madeleine Assas',
#    'Ghalya Lacroix',
#    'Bérangère Allaux',
#    'Vicky Messica'],
#   'rating': 6.1},
#  {'title': 'Mnága - Happy End',
#   'year': 1996,
#   'genres': ['Comedy', 'Music'],
#   'duration': 62,
#   'directors': ['Petr Zelenka'],
#   'cast': ['Christopher Clarke',
#    'Martin Knor',
#    'Karel Mikus',
#    'Lukas Filip',
#    'Petr Nekuza',
#    'Radek Koutny'],
#   'rating': 7.3},
#  {'title': 'Naked Songs: The Life & Times of Rickie Lee Jones',
#   'year': 1996,
#   'genres': ['Biography', 'Documentary', 'Music'],
#   'duration': 69,
#   'directors': ['Ethan A. Russell'],
#   'cast': ['Temple Shea'],
#   'rating': 7.0},
#  {'title': 'Ightiyal',
#   'year': 1996,
#   'genres': ['Crime'],
#   'duration': 110,
#   'directors': ['Nader Galal'],
#   'cast': ['Adel Ammar',
#    'Ashraf Abdel Baky',
#    'Rubi Abdulaziz',
#    'El-Arabi Abdulfadhil',
#    'Izzat Abu-Of',
#    'Abir Adel',
#    'Amirah'],
#   'rating': 3.3},
#  {'title': 'The Sunchaser',
#   'year': 1996,
#   'genres': ['Crime', 'Drama'],
#   'duration': 122,
#   'directors': ['Michael Cimino'],
#   'cast': ['Woody Harrelson',
#    'Jon Seda',
#    'Anne Bancroft',
#    'Alexandra Tydings'],
#   'rating': 6.1},
#  {'title': 'Solitaire',
#   'year': 1996,
#   'genres': ['Drama', 'Thriller'],
#   'duration': 94,
#   'directors': ["Gareth O'Neil"],
#   'cast': ['Palmer Lee Todd',
#    "Kehli O'Byrne",
#    'Ken Fording',
#    'Lori Jo Hendrix'],
#   'rating': 4.1},
#  {'title': 'Silent Night',
#   'year': 1996,
#   'genres': ['Drama', 'Romance'],
#   'duration': 83,
#   'directors': ['Dani Levy'],
#   'cast': ['Maria Schrader',
#    'Mark Schlichter',
#    'Jürgen Vogel',
#    'Ingrid Caven'],
#   'rating': 6.2},
#  {'title': 'Get on the Bus',
#   'year': 1996,
#   'genres': ['Adventure', 'Drama', 'History'],
#   'duration': 120,
#   'directors': ['Spike Lee'],
#   'cast': ['Ossie Davis',
#    'Charles S. Dutton',
#    'Andre Braugher',
#    'Richard Belzer'],
#   'rating': 6.9},
#  {'title': 'Muqaddar',
#   'year': 1996,
#   'genres': ['Crime'],
#   'duration': 181,
#   'directors': ['T.L.V. Prasad'],
#   'cast': ['Hemant Birje',
#    'Mithun Chakraborty',
#    'Ayesha Jhulka',
#    'Rohit Kumar Sharma',
#    'Simran',
#    'Puneet Issar'],
#   'rating': 6.0},
#  {'title': 'Tokyo Mafia: Battle for Shinjuku',
#   'year': 1996,
#   'genres': ['Action', 'Crime', 'Drama'],
#   'duration': 85,
#   'directors': ['Takeshi Miyasaka'],
#   'cast': ['Riki Takeuchi', 'Masayuki Imai', 'Asami Sawaki'],
#   'rating': 5.9},
#  {'title': 'Talaashi',
#   'year': 1996,
#   'genres': ['Crime', 'Drama'],
#   'duration': 157,
#   'directors': ['Shyam Ramsay', 'Tulsi Ramsay'],
#   'cast': ['Jackie Shroff', 'Juhi Chawla', 'Mukesh Khanna', 'Ekta Sohini'],
#   'rating': 4.2},
#  {'title': 'Nethaji',
#   'year': 1996,
#   'genres': ['Action', 'Romance'],
#   'duration': 150,
#   'directors': ['Muthu Krishnan'],
#   'cast': ['Sarath Kumar', 'Lisa Ray', 'Manivannan', 'Babu Antony'],
#   'rating': 3.8},
#  {'title': 'The Dog in the Manger',
#   'year': 1996,
#   'genres': ['Comedy', 'Romance'],
#   'duration': 119,
#   'directors': ['Pilar Miró'],
#   'cast': ['Emma Suárez', 'Carmelo Gómez', 'Fernando Conde', 'Ana Duato'],
#   'rating': 6.8},
#  {'title': 'Diamonds in the Rough',
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 100,
#   'directors': ['Serge Rodnunsky'],
#   'cast': ['Jim Gray', 'David Richard', 'Michelle Mitchell', 'Gina La Piana'],
#   'rating': 5.5},
#  {'title': 'Sgt. Bilko',
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 93,
#   'directors': ['Jonathan Lynn'],
#   'cast': ['Steve Martin', 'Dan Aykroyd', 'Phil Hartman', 'Glenne Headly'],
#   'rating': 5.8},
#  {'title': 'Female Perversions',
#   'year': 1996,
#   'genres': ['Drama', 'Fantasy', 'Thriller'],
#   'duration': 120,
#   'directors': ['Susan Streitfeld'],
#   'cast': ['Tilda Swinton', 'Amy Madigan', 'Karen Sillas', 'Frances Fisher'],
#   'rating': 5.4},
#  {'title': "J'ai eu dur!",
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 92,
#   'directors': ['Gérald Frydman'],
#   'cast': ['Michel Carcan',
#    'Catherine Claeys',
#    'Michel de Warzee',
#    'Bruce Ellison'],
#   'rating': 5.7},
#  {'title': 'Remue-ménage',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 59,
#   'directors': ['Paul Thinel'],
#   'cast': ['France Arbour',
#    'Gary Boudreault',
#    'Melissa Dion',
#    'Robert Gravel'],
#   'rating': 7.3},
#  {'title': 'Niki de Saint Phalle',
#   'year': 1996,
#   'genres': ['Biography', 'Documentary'],
#   'duration': 93,
#   'directors': ['Peter Schamoni'],
#   'cast': ['Niki De Saint Phalle', 'Jean Tinguely'],
#   'rating': 7.2},
#  {'title': "L'homme idéal",
#   'year': 1996,
#   'genres': ['Comedy', 'Romance'],
#   'duration': 110,
#   'directors': ['George Mihalka'],
#   'cast': ['Marie-Lise Pilote',
#    'Roy Dupuis',
#    'Macha Grenon',
#    'Carmen Ferland'],
#   'rating': 6.1},
#  {'title': 'Corsarios del chip',
#   'year': 1996,
#   'genres': ['Action', 'Adventure', 'Comedy'],
#   'duration': 96,
#   'directors': ['Rafael Alcázar'],
#   'cast': ['Fernando Guillén Cuervo',
#    'Karra Elejalde',
#    'Cayetana Guillén Cuervo',
#    'Paulina Gálvez'],
#   'rating': 5.2},
#  {'title': 'Razones sentimentales',
#   'year': 1996,
#   'genres': ['Drama', 'Romance'],
#   'duration': 106,
#   'directors': ['Antonio A. Farré'],
#   'cast': ['Javier Albalá', 'Anna Azcona', 'Alex Brendemühl', 'Abel Folk'],
#   'rating': 6.3},
#  {'title': 'Almost Blue',
#   'year': 1996,
#   'genres': ['Drama', 'Thriller'],
#   'duration': 85,
#   'directors': ['Keoni Waxman'],
#   'cast': ['Michael Madsen',
#    'Lynette Walden',
#    'Garrett Morris',
#    'Gale Mayron'],
#   'rating': 4.9},
#  {'title': 'Pelli Sandadi',
#   'year': 1996,
#   'genres': ['Musical', 'Romance'],
#   'duration': 129,
#   'directors': ['K. Raghavendra Rao'],
#   'cast': ['Srikanth', 'Meka Srikanth', 'Ravali', 'Deepti Bhatnagar'],
#   'rating': 7.1},
#  {'title': 'Rakshak',
#   'year': 1996,
#   'genres': ['Action', 'Thriller'],
#   'duration': 164,
#   'directors': ['Ashok Honda'],
#   'cast': ['Suniel Shetty', 'Karisma Kapoor', 'Sonali Bendre', 'Raghuvaran'],
#   'rating': 5.0},
#  {'title': 'Romeo + Juliet',
#   'year': 1996,
#   'genres': ['Drama', 'Romance'],
#   'duration': 120,
#   'directors': ['Baz Luhrmann'],
#   'cast': ['Leonardo DiCaprio',
#    'Claire Danes',
#    'John Leguizamo',
#    'Harold Perrineau'],
#   'rating': 6.7},
#  {'title': 'Snakes and Ladders',
#   'year': 1996,
#   'genres': ['Comedy', 'Romance'],
#   'duration': 93,
#   'directors': ['Trish McAdam'],
#   'cast': ['Gina Moxley', 'Sean Hughes', 'Rosaleen Linehan'],
#   'rating': 6.3},
#  {'title': 'Chameleon',
#   'year': 1996,
#   'genres': ['Thriller'],
#   'duration': 92,
#   'directors': ['Benoît Cohen'],
#   'cast': ['Chiara Mastroianni',
#    'Jackie Berroyer',
#    'Seymour Cassel',
#    'Antoine Chappey'],
#   'rating': 5.7},
#  {'title': 'Jingle All the Way',
#   'year': 1996,
#   'genres': ['Adventure', 'Comedy', 'Family'],
#   'duration': 89,
#   'directors': ['Brian Levant'],
#   'cast': ['Arnold Schwarzenegger', 'Sinbad', 'Phil Hartman', 'Rita Wilson'],
#   'rating': 5.7},
#  {'title': 'The War Within: A Portrait of Virginia Woolf',
#   'year': 1996,
#   'genres': ['Documentary'],
#   'duration': 52,
#   'directors': ['Morten Bruus', 'John Fuegi'],
#   'cast': ['Anna Massey', 'Juliet Nicolson'],
#   'rating': 7.5},
#  {'title': 'The Rock',
#   'year': 1996,
#   'genres': ['Action', 'Adventure', 'Thriller'],
#   'duration': 136,
#   'directors': ['Michael Bay'],
#   'cast': ['Sean Connery', 'Nicolas Cage', 'Ed Harris', 'John Spencer'],
#   'rating': 7.4},
#  {'title': 'Beaumarchais the Scoundrel',
#   'year': 1996,
#   'genres': ['Adventure', 'Comedy', 'History'],
#   'duration': 100,
#   'directors': ['Édouard Molinaro'],
#   'cast': ['Fabrice Luchini',
#    'Manuel Blanc',
#    'Sandrine Kiberlain',
#    'Michel Aumont'],
#   'rating': 6.8},
#  {'title': 'Abunai Deka Returns',
#   'year': 1996,
#   'genres': ['Action'],
#   'duration': 108,
#   'directors': ['Tôru Murakawa'],
#   'cast': ['Hiroshi Tachi', 'Kyôhei Shibata', 'Tôru Nakamura', 'Atsuko Asano'],
#   'rating': 5.1},
#  {'title': 'Unknowingly',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 148,
#   'directors': ['Dilip Biswas'],
#   'cast': ['Alamgir', 'Shabana', 'Sohel Rana', 'Suchorita'],
#   'rating': 7.2},
#  {'title': 'The Survivors',
#   'year': 1996,
#   'genres': ['War'],
#   'duration': 81,
#   'directors': ['Rasool Mollagholi Poor'],
#   'cast': ['Atefeh Razavi',
#    'Ali Yaghoob Zadeh',
#    'Jamshid Esmailkhani',
#    'Peyman Sanandaji Zadeh'],
#   'rating': 6.3},
#  {'title': 'Albatross',
#   'year': 1996,
#   'genres': ['Action', 'Drama'],
#   'duration': 104,
#   'directors': ['Hyeok-su Lee'],
#   'cast': ['In-pyo Cha', 'Lee Jung-jae', 'Hwi-Jae Lee', 'Ri-na Kang'],
#   'rating': 5.7},
#  {'title': 'Istanbul Beneath My Wings',
#   'year': 1996,
#   'genres': ['Adventure', 'Drama', 'History'],
#   'duration': 119,
#   'directors': ['Mustafa Altioklar'],
#   'cast': ['Akasya Asiltürkmen',
#    'Ege Aydan',
#    'Okan Bayülgen',
#    'Beatriz Rico',
#    'Savas Ay',
#    'Burak Sergen'],
#   'rating': 7.0},
#  {'title': 'The Winner',
#   'year': 1996,
#   'genres': ['Comedy', 'Crime', 'Thriller'],
#   'duration': 92,
#   'directors': ['Alex Cox'],
#   'cast': ['Rebecca De Mornay',
#    "Vincent D'Onofrio",
#    'Richard Edson',
#    'Saverio Guerra'],
#   'rating': 4.7},
#  {'title': 'Tokyo Mafia: Wrath of the Yakuza',
#   'year': 1996,
#   'genres': ['Action', 'Crime', 'Drama'],
#   'duration': 90,
#   'directors': ['Seiichi Shirai'],
#   'cast': ['Shôhei Yamamoto',
#    'Riki Takeuchi',
#    'Masayuki Imai',
#    'Hiroshi Miyauchi',
#    'Kôjirô Hongô',
#    'Hidemi Maruyama',
#    'Kazuyoshi Ozawa'],
#   'rating': 6.2},
#  {'title': 'Wake Up Love',
#   'year': 1996,
#   'genres': ['Comedy', 'Romance'],
#   'duration': 98,
#   'directors': ['Eliseo Subiela'],
#   'cast': ['Juan Leyrado',
#    'Darío Grandinetti',
#    'Soledad Silveyra',
#    'Laura Azcurra'],
#   'rating': 6.9},
#  {'title': 'Dog Run',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 104,
#   'directors': ["D. Ze'ev Gilad"],
#   'cast': ['Brian Marc Zimberg',
#    'Craig DuPlessis',
#    'Lisa Ristorucci',
#    'Michele Santopietro'],
#   'rating': 6.8},
#  {'title': 'Terminal Rush',
#   'year': 1996,
#   'genres': ['Action', 'Drama', 'Thriller'],
#   'duration': 94,
#   'directors': ['Damian Lee'],
#   'cast': ['Don Wilson',
#    'Michael Anderson Jr.',
#    'Roddy Piper',
#    'Brian Warren'],
#   'rating': 3.6},
#  {'title': 'Profile for Murder',
#   'year': 1996,
#   'genres': ['Drama', 'Thriller'],
#   'duration': 95,
#   'directors': ['David Winning'],
#   'cast': ['Lance Henriksen', 'Jason Nash', 'Joan Severance', 'Fawnia Mondey'],
#   'rating': 5.0},
#  {'title': 'The Italians Are Coming',
#   'year': 1996,
#   'genres': ['Drama', 'Romance', 'Sport'],
#   'duration': 100,
#   'directors': ['Eyal Halfon'],
#   'cast': ['Franco Nero', 'Yona Elian', 'Asher Tzarfati', 'Avraham Mor'],
#   'rating': 6.7},
#  {'title': 'White Feast',
#   'year': 1996,
#   'genres': ['Drama'],
#   'duration': 102,
#   'directors': ['Vladimir Naumov'],
#   'cast': ['Innokentiy Smoktunovskiy',
#    'Armen Dzhigarkhanyan',
#    'Natalya Belokhvostikova',
#    'Natalya Naumova'],
#   'rating': 7.4},
#  {'title': 'Oui',
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 89,
#   'directors': ['Alexandre Jardin'],
#   'cast': ['Sylvie Loeillet',
#    'Miguel Bosé',
#    'Chiara Caselli',
#    'Pierre Palmade',
#    'Jean-Marie Bigard',
#    'Catherine Jacob',
#    'Daniel Russo',
#    'Roland Marchisio'],
#   'rating': 4.0},
#  {'title': 'Asphalt Tango',
#   'year': 1996,
#   'genres': ['Comedy'],
#   'duration': 100,
#   'directors': ['Nae Caranfil'],
#   'cast': ['Charlotte Rampling',
#    'Mircea Diaconu',
#    'Florin Calinescu',
#    'Constantin Cotimanis'],
#   'rating': 8.0},
#  {'title': 'Aatank',
#   'year': 1996,
#   'genres': ['Action', 'Thriller'],
#   'duration': 113,
#   'directors': ['Prem Lalwani', 'Desh Mukherjee'],
#   'cast': ['Nafisa Ali', 'Ranjeet Bedi', 'Dharmendra', 'Girish Karnad'],
#   'rating': 3.6},
#  ...]

# %%
# first compute and store the dictionary in the variable 'decade_mapping', then display it
decade_mapping = {}
for year in year_buckets:
    decade = year_to_decade(year)
    movies_in_year = len(year_buckets[year])
    if decade not in decade_mapping:
        decade_mapping[decade] = 0
    decade_mapping[decade] += movies_in_year
decade_mapping
# Out:
# {'1991 to 2000': 18496,
#  '2021 to 2030': 9173,
#  '1961 to 1970': 14216,
#  '1951 to 1960': 10981,
#  '2011 to 2020': 59249,
#  '2001 to 2010': 33658,
#  '1941 to 1950': 7807,
#  '1971 to 1980': 15556,
#  '1981 to 1990': 17181,
#  '1921 to 1930': 3014,
#  '1931 to 1940': 8201,
#  '1911 to 1920': 1068,
#  '1901 to 1910': 9,
#  '1891 to 1900': 1}

# %%
# now plot 'decade_mapping' with the y-axis labelled 'movies released'
plot_dict(decade_mapping, label='movies released')

# %%
grader.check("q6")
# Out:
# q6 results: All test cases passed!

# %% [markdown]
# **Food for thought:** Can you explain the shape of this plot? Why do you think there was a dip between the decades `1931 to 1940` and `1941 to 1950`? Can you explain why the number of movies appears to plateau around `1991 to 2000` before increasing drastically?

# %%
# this is an entirely OPTIONAL exercise
# you may leave your thoughts here as a comment if you wish to

# %% [markdown]
# **Question 7:** **Plot** the **median** `rating` of movies in each *genre* as a **bar graph**.
#
# You **must** first compute a **dictionary** which maps each **genre** to the **median** `rating` of all movies in that **genre**. Then, you may use `plot_dict` to plot the data in that dictionary.
#
# **Important Warning:** `p9_test.py` can check that the **dictionary** has the correct key/value pairs, but it **cannot** check if your plot appears on the screen, or whether the axes are correctly labelled. Your plots will be **manually graded**, and you will **lose points** if your plot is not visible, or if it is not properly labelled.
#
# Your plot should look like this:
# <div><img src="attachment:median_rating.PNG" width="400"/></div>

# %%
# first compute and store the dictionary in the variable 'median_genres', then display it
median_genres = {}
rating_total = 0
for genre in genre_buckets:
    rating = []
    for movie in genre_buckets[genre]:
        rating.append(movie["rating"])
        rating_total += len(rating)
    median_genres[genre] = median(rating)
median_genres
# Out:
# {'Drama': 6.3,
#  'Horror': 5.0,
#  'Sport': 6.4,
#  'Family': 6.2,
#  'Comedy': 6.0,
#  'Adventure': 6.0,
#  'Thriller': 5.6,
#  'Crime': 6.1,
#  'Action': 5.8,
#  'Fantasy': 6.0,
#  'History': 6.7,
#  'Romance': 6.2,
#  'Biography': 6.8,
#  'Sci-Fi': 5.4,
#  'Mystery': 5.9,
#  'Documentary': 7.3,
#  'Western': 6.0,
#  'Musical': 6.2,
#  'Animation': 6.5,
#  'Music': 6.5,
#  'War': 6.5,
#  'News': 7.4,
#  'Film-Noir': 6.5,
#  'Short': 7.0,
#  'Reality-TV': 6.6,
#  'Game-Show': 3.3,
#  'Talk-Show': 2.8}

# %%
# now plot 'median_genres' with the y-axis labelled 'median rating'
plot_dict(median_genres, label = 'median_rating')

# %%
grader.check("q7")
# Out:
# q7 results: All test cases passed!

# %% [markdown]
# **Food for thought:** Do you spot any outliers in this graph? Can you explain why they are such outliers?

# %%
# this is an entirely OPTIONAL exercise
# you may leave your thoughts here as a comment if you wish to

# %% [markdown]
# The visualization in q7 immediately tells us that the **median** *Documentary* movie is rated higher than the **median** *Crime* movie. However, it is a little hard to tell how the **median** *Action* movie fares against the **median** *Fantasy* movie. In order to compare the `genres`, it would be useful to **sort** the `genres` by their **median** `rating`.

# %% [markdown]
# **Question 8:** Produce a **list** of `genres` sorted in **decreasing order** of their **median** `rating`.

# %%
# compute and store the answer in the variable 'genres_desc', then display it
genres_desc =

# %%
grader.check("q8")

# %% [markdown]
# **Question 9:** Produce a **list** of *Animation* movies from the *Shrek* franchise sorted in **increasing** order of their `year` of release.
#
# Your output **must** be a **list** of **dictionaries** of movies having *Shrek* as a **substring** of the `title` and *Animation* as one of their `genres`, that are **sorted** in **increasing** order of their `year`.

# %%
# compute and store the answer in the variable 'shrek_inc', then display it

# %%
grader.check("q9")

# %% [markdown]
# **Question 10:** Produce a **list** of `directors` who have directed movies in which *Denzel Washington* was `cast` in, **sorted** in **decreasing** order of the number of times they have worked with *Denzel Washington*.
#
# Your output **must** be a **list** of **strings** of the names of the `directors` who have directed movies in which *Denzel Washington* was a `cast` member, and the **list** should be sorted in **decreasing** order of the number of times that director has worked with *Denzel Washington*.
#
# **Hint:** If you use your `bucketize` function cleverly, you can easily organize the movies that *Denzel Washington* was `cast` in, by their director(s).

# %%
# compute and store the answer in the variable 'denzel_directors', then display it
washington_movies = cast_buckets["Denzel Washington"]
wash_directors = bucketize(washington_movies, "directors")
num_wash_directors = {director: len(wash_directors[director]) for director in wash_directors}
denzel_directors = sorted(num_wash_directors, key=lambda director: num_wash_directors[director], reverse=True) 
denzel_directors
# Out:
# ['Tony Scott',
#  'Antoine Fuqua',
#  'Edward Zwick',
#  'Carl Franklin',
#  'Jonathan Demme',
#  'Spike Lee',
#  'Penny Marshall',
#  'Ridley Scott',
#  'Mira Nair',
#  'Albert Hughes',
#  'Allen Hughes',
#  'John Scheinfeld',
#  'Gregory Hoblit',
#  'Norman Jewison',
#  'Carl Schenkel',
#  'Baltasar Kormákur',
#  'Robert Zemeckis',
#  'Joel Coen',
#  'Boaz Yakin',
#  'Phillip Noyce',
#  'Nick Cassavetes',
#  'Martin Stellman',
#  'Daniel Espinosa',
#  'Brett Leonard',
#  'Russell Mulcahy',
#  'James D. Parriott',
#  'Richard Attenborough',
#  'John Lee Hancock',
#  'Alan J. Pakula']

# %%
grader.check("q10")
# Out:
# q10 results: All test cases passed!

# %% [markdown]
# ## Submission
# Make sure you have run all cells in your notebook in order before running the following cells, so that all images/graphs appear in the output.
# It is recommended that at this stage, you Restart and Run all Cells in your notebook.
# That will automatically save your work and generate a zip file for you to submit.
#
# **SUBMISSION INSTRUCTIONS**:
# 1. **Upload** the zipfile to Gradescope.
# 2. Check **Gradescope otter** results as soon as the auto-grader execution gets completed. Don't worry about the score showing up as -/100.0. You only need to check that the test cases passed.

# %%
# running this cell will create a new save checkpoint for your notebook
from IPython.display import display, Javascript
display(Javascript('IPython.notebook.save_checkpoint();'))

# %%
# !jupytext --to py p9.ipynb

# %%
p9_test.check_file_size("p9.ipynb")
grader.export(pdf=False, run_tests=True, files=[py_filename])
